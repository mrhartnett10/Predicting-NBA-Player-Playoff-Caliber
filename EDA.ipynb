# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('merged.csv', index_col = 0)

# %%
df
# Out:
#                          name                team  year   mpg    fg%  3pfg%  \
# 0                LeBron James  Los Angeles Lakers  2020  34.6  0.493  0.348
# 1               Anthony Davis  Los Angeles Lakers  2020  34.4  0.503  0.330
# 2    Kentavious Caldwell-Pope  Los Angeles Lakers  2020  25.5  0.467  0.385
# 3                  Kyle Kuzma  Los Angeles Lakers  2020  25.0  0.436  0.316
# 4                 Danny Green  Los Angeles Lakers  2020  24.8  0.416  0.367
# ..                        ...                 ...   ...   ...    ...    ...
# 637                  Don Ford  Los Angeles Lakers  1980  11.2  0.508  0.000
# 638              Marty Byrnes  Los Angeles Lakers  1980   6.1  0.500    NaN
# 639                Ollie Mack  Los Angeles Lakers  1980   5.7  0.420  0.000
# 640              Brad Holland  Los Angeles Lakers  1980   5.2  0.423  0.200
# 641                 Butch Lee  Los Angeles Lakers  1980   2.8  0.308    NaN
#
# ...

# %%
plt.hist(df.mpg)
plt.xticks(range(0,41,5));

# %%
plt.hist(df.player_efficiency);

# %%
plt.figure(figsize=(12, 12))
sns.heatmap(df.corr(),
            annot=True,
            cmap='coolwarm',
            vmin=-1,
            vmax=1)
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#               year         mpg         fg%       3pfg%    rebounds  \
# count   642.000000  642.000000  640.000000  524.000000  642.000000
# mean   2001.099688   19.408100    0.455730    0.263324    3.544704
# std      11.877273   10.797631    0.100734    0.179343    2.802953
# min    1980.000000    1.000000    0.000000    0.000000    0.000000
# 25%    1991.000000    9.900000    0.415750    0.125000    1.500000
# 50%    2001.500000   18.250000    0.463000    0.313000    2.700000
# 75%    2012.000000   28.875000    0.506000    0.376250    4.800000
# max    2020.000000   42.000000    1.000000    1.000000   16.100000
#
#           assists      steals      blocks   turnovers  points_per_game  \
# count  642.000000  642.000000  642.000000  642.000000       642.000000
# mean     1.919470    0.648287    0.455919    1.194860         8.276324
# std      1.949193    0.520804    0.567259    0.842322         6.881466
# min      0.000000    0.000000    0.000000    0.000000         0.000000
# ...

# %%
df[df['mpg'] >34].describe()
# Out:
#               year        mpg        fg%      3pfg%   rebounds    assists  \
# count    79.000000  79.000000  79.000000  77.000000  79.000000  79.000000
# mean   1996.810127  36.892405   0.501405   0.250870   7.332911   5.021519
# std      11.178133   1.851941   0.045276   0.141201   3.291119   2.429027
# min    1980.000000  34.100000   0.389000   0.000000   2.100000   1.300000
# 25%    1988.000000  35.400000   0.468500   0.174000   5.050000   3.150000
# 50%    1996.000000  36.800000   0.501000   0.270000   6.600000   4.900000
# 75%    2004.500000  38.300000   0.530500   0.357000   9.700000   6.150000
# max    2020.000000  42.000000   0.604000   0.500000  16.100000  12.600000
#
#           steals     blocks  turnovers  points_per_game  player_efficiency
# count  79.000000  79.000000  79.000000        79.000000          79.000000
# mean    1.417722   0.996203   2.675949        21.118987          21.740506
# std     0.574849   0.926593   0.733662         5.688519           5.070769
# ...

# %%
df[(df['mpg'] >34) & (df['position']=='PG')].describe()
# Out:
#               year        mpg        fg%      3pfg%   rebounds    assists  \
# count    13.000000  13.000000  13.000000  12.000000  13.000000  13.000000
# mean   1996.230769  37.600000   0.543846   0.112083  11.469231   3.084615
# std      10.786982   2.034289   0.046813   0.175753   1.727418   0.945909
# min    1980.000000  34.100000   0.421000   0.000000   8.700000   1.300000
# 25%    1984.000000  36.100000   0.528000   0.000000  10.700000   3.000000
# 50%    2000.000000  37.500000   0.546000   0.000000  10.800000   3.400000
# 75%    2004.000000  39.500000   0.574000   0.140750  12.400000   3.600000
# max    2010.000000  41.000000   0.604000   0.500000  15.300000   4.500000
#
#           steals     blocks  turnovers  points_per_game  player_efficiency
# count  13.000000  13.000000  13.000000        13.000000          13.000000
# mean    0.961538   2.507692   2.746154        23.046154          24.869231
# std     0.473530   0.821037   0.630629         5.693361           3.983379
# ...

# %%
df[(df['mpg'] >34) & (df['position']=='SG')].describe()
# Out:
#               year        mpg       fg%      3pfg%   rebounds    assists  \
# count    23.000000  23.000000  23.00000  23.000000  23.000000  23.000000
# mean   1998.086957  37.117391   0.48700   0.320696   5.404348   5.082609
# std       9.732388   1.843330   0.03517   0.079054   1.686707   1.446517
# min    1980.000000  34.300000   0.38900   0.171000   2.500000   2.500000
# 25%    1991.500000  35.700000   0.46600   0.261500   3.950000   4.300000
# 50%    1997.000000  37.600000   0.48800   0.319000   5.700000   5.000000
# 75%    2005.000000  38.450000   0.51250   0.365500   6.350000   5.500000
# max    2018.000000  40.900000   0.53900   0.483000   9.600000   9.500000
#
#           steals     blocks  turnovers  points_per_game  player_efficiency
# count  23.000000  23.000000  23.000000        23.000000          23.000000
# mean    1.747826   0.508696   2.643478        23.678261          22.573913
# std     0.586879   0.271215   0.596067         5.595774           5.086812
# ...

# %%
df[(df['mpg'] >34) & (df['position']=='SF')].describe()
# Out:
#               year        mpg        fg%      3pfg%   rebounds    assists  \
# count    16.000000  16.000000  16.000000  16.000000  16.000000  16.000000
# mean   1997.500000  37.012500   0.498062   0.282000   6.543750   5.000000
# std      12.649111   1.931105   0.034891   0.147641   1.388989   1.776513
# min    1980.000000  34.200000   0.429000   0.000000   4.800000   1.700000
# 25%    1987.750000  35.550000   0.470750   0.194000   5.175000   3.675000
# 50%    1994.500000  37.150000   0.511000   0.313500   6.450000   5.750000
# 75%    2009.000000  37.925000   0.526500   0.378500   7.475000   6.225000
# max    2018.000000  42.000000   0.539000   0.500000   9.800000   7.000000
#
#          steals     blocks  turnovers  points_per_game  player_efficiency
# count  16.00000  16.000000  16.000000        16.000000          16.000000
# mean    1.56875   0.868750   2.525000        20.843750          20.900000
# std     0.47289   0.477101   0.828251         3.665509           4.825626
# ...

# %%
df[(df['mpg'] >34) & (df['position']=='PF')].describe()
# Out:
#               year        mpg        fg%      3pfg%   rebounds    assists  \
# count    14.000000  14.000000  14.000000  13.000000  14.000000  14.000000
# mean   1998.785714  36.500000   0.510714   0.229615  10.485714   3.542857
# std      11.761597   1.908685   0.045266   0.126791   2.663386   1.692388
# min    1981.000000  34.300000   0.431000   0.000000   7.000000   1.800000
# 25%    1992.250000  35.300000   0.488250   0.174000   8.400000   2.600000
# 50%    1997.500000  35.550000   0.505500   0.263000  10.050000   2.800000
# 75%    2009.000000  38.200000   0.550000   0.286000  11.275000   3.725000
# max    2020.000000  39.500000   0.578000   0.406000  16.100000   7.300000
#
#           steals     blocks  turnovers  points_per_game  player_efficiency
# count  14.000000  14.000000  14.000000        14.000000          14.000000
# mean    1.057143   1.235714   2.350000        18.385714          21.257143
# std     0.518451   0.879342   0.679083         7.065502           5.369531
# ...

# %%
df[(df['mpg'] >34) & (df['position']=='C')].describe()
# Out:
#               year        mpg        fg%      3pfg%   rebounds    assists  \
# count    13.000000  13.000000  13.000000  12.000000  13.000000  13.000000
# mean   1996.230769  37.600000   0.543846   0.112083  11.469231   3.084615
# std      10.786982   2.034289   0.046813   0.175753   1.727418   0.945909
# min    1980.000000  34.100000   0.421000   0.000000   8.700000   1.300000
# 25%    1984.000000  36.100000   0.528000   0.000000  10.700000   3.000000
# 50%    2000.000000  37.500000   0.546000   0.000000  10.800000   3.400000
# 75%    2004.000000  39.500000   0.574000   0.140750  12.400000   3.600000
# max    2010.000000  41.000000   0.604000   0.500000  15.300000   4.500000
#
#           steals     blocks  turnovers  points_per_game  player_efficiency
# count  13.000000  13.000000  13.000000        13.000000          13.000000
# mean    0.961538   2.507692   2.746154        23.046154          24.869231
# std     0.473530   0.821037   0.630629         5.693361           3.983379
# ...

# %%
df.mpg.value_counts(normalize=True)
# Out:
# 7.3     0.009346
# 6.6     0.009346
# 18.8    0.007788
# 13.1    0.007788
# 8.2     0.007788
#           ...
# 5.7     0.001558
# 39.6    0.001558
# 4.6     0.001558
# 19.6    0.001558
# 15.4    0.001558
# Name: mpg, Length: 299, dtype: float64
