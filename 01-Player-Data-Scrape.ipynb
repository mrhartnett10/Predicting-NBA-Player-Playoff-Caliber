# %% [markdown]
# **Library Imports**|

# %%
import requests
import pandas as pd
import numpy as np
import time
from bs4 import BeautifulSoup

from sklearn.linear_model import LogisticRegression, LogisticRegressionCV, Ridge, RidgeCV, Lasso, LassoCV
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# Before scrapping I wanted to create a dictionary by year of all the teams that qualified for the playoffs for that given year. Unforutnately it wasn't easily scrapable so I had to build out the dictionary manually (below):

# %%
playoff_teams = {'2020': ['LAL', 'MIA', 'BOS', 'DEN', 'MIL', 'TOR', 'LAC', 'HOU',
                         'ORL', 'BRK', 'PHI', 'IND', 'POR', 'DAL', 'UTA', 'OKC'],
           '2019': ['MIL', 'TOR', 'PHI', 'BOS', 'GSW', 'DEN', 'POR', 'HOU',
                   'DET', 'ORL', 'BRK', 'IND', 'LAC', 'SAS', 'OKC', 'UTA'],
           '2018': ['TOR', 'BOS', 'PHI', 'CLE', 'HOU', 'GSW', 'NOP', 'UTA',
                   'WAS', 'MIL', 'MIA', 'IND', 'MIN', 'SAS', 'POR', 'OKC'],
           '2017': ['BOS', 'CLE', 'TOR', 'WAS', 'SAS', 'HOU', 'UTA', 'GSW',
                   'CHI', 'IND', 'MIL', 'ATL', 'POR', 'MEM', 'OKC', 'LAC'],
           '2016': ['CLE', 'TOR', 'MIA', 'ATL', 'GSW', 'SAS', 'OKC', 'POR',
                   'DET', 'IND', 'CHA', 'BOS', 'HOU', 'MEM', 'DAL', 'LAC'],
           '2015': ['ATL', 'CLE', 'CHI', 'WAS', 'GSW', 'HOU', 'LAC', 'MEM',
                   'BRK', 'BOS', 'MIL', 'TOR', 'NOP', 'DAL', 'SAS', 'POR'],
           '2014': ['IND', 'MIA', 'BRK', 'WAS', 'SAS', 'OKC', 'LAC', 'POR',
                   'ATL', 'CHO', 'TOR', 'CHI', 'DAL', 'MEM', 'GSW', 'HOU'],
           '2013': ['MIA', 'NYK', 'IND', 'CHI', 'OKC', 'SAS', 'GSW', 'MEM',
                   'MIL', 'BOS', 'ATL', 'BRK', 'HOU', 'LAL', 'DEN', 'LAC'],
           '2012': ['PHI', 'MIA', 'IND', 'BOS', 'SAS', 'OKC', 'LAL', 'LAC',
                   'CHI', 'NYK', 'ORL', 'ATL', 'UTA', 'DAL', 'DEN', 'MEM'],
           '2011': ['CHI', 'MIA', 'BOS', 'ATL', 'MEM', 'LAL', 'DAL', 'OKC',
                   'IND', 'PHI', 'NYK', 'ORL', 'SAS', 'NOP', 'POR', 'DEN'],
           '2010': ['CLE', 'ORL', 'ATL', 'BOS', 'LAL', 'SAS', 'PHO', 'UTA',
                   'CHI', 'CHA', 'MIL', 'MIA', 'OKC', 'DAL', 'POR', 'DEN'],
           '2009': ['CLE', 'BOS', 'ATL', 'LAL', 'DEN', 'DAL', 'HOU', 'LAL',
                   'DET', 'CHI', 'PHI', 'MIA', 'UTA', 'NOP', 'SAS', 'POR'],
           '2008': ['BOS', 'DET', 'ORL', 'CLE', 'LAL', 'NOH', 'SAS', 'UTA',
                   'ATL', 'PHI', 'TOR', 'WAS', 'DEN', 'DAL', 'PHO', 'HOU'],
           '2007': ['CHI', 'CLE', 'DET', 'NJN', 'GWS', 'PHO', 'SAS', 'UTA',
                   'MIA', 'WAS', 'ORL', 'TOR', 'DAL', 'LAL', 'DEN', 'HOU'],
           '2006': ['CLE', 'DET', 'MIA', 'NJN', 'DAL', 'LAC', 'PHO', 'SAS',
                   'WAS', 'MIL', 'CHI', 'IND', 'MEM', 'DEN', 'LAL', 'SAC'],
           '2005': ['DET', 'IND', 'MIA', 'WAS', 'DAL', 'PHO', 'SAS', 'SEA',
                   'PHI', 'BOS', 'NJN', 'CHI', 'HOU', 'MEM', 'DEN', 'SAC'],
           '2004': ['DET', 'IND', 'MIA', 'NJN', 'LAL', 'MIN', 'SAC', 'SAS',
                   'MIL', 'BOS', 'NOH', 'NYK', 'HOU', 'DEN', 'DAL', 'MEM'],
           '2003': ['BOS', 'DET', 'NJN', 'PHI', 'DAL', 'LAL', 'SAC', 'SAS',
                   'IND', 'ORL', 'MIL', 'NOH', 'POR', 'MIN', 'UTA', 'PHO'],
           '2002': ['BOS', 'CHH', 'DET', 'NJN', 'DAL', 'LAL', 'SAC', 'SAS',
                   'PHI', 'ORL', 'TOR', 'IND', 'MIN', 'POR', 'UTA', 'SEA'],
           '2001': ['CHH', 'MIL', 'PHI', 'TOR', 'DAL', 'LAL', 'SAC', 'SAS',
                   'MIA', 'ORL', 'IND', 'NYK', 'UTA', 'POR', 'PHO', 'MIN'],
           '2000': ['IND', 'MIA', 'NYK', 'PHI', 'LAL', 'PHO', 'POR', 'UTA',
                   'MIL', 'DET', 'TOR', 'CHH', 'SAC', 'SAS', 'MIN', 'SEA'],
           '1999': ['ATL', 'IND', 'NYK', 'PHI', 'LAL', 'POR', 'SAS', 'UTA',
                   'DET', 'MIL', 'MIA', 'ORL', 'HOU', 'PHO', 'MIN', 'SAC'],
           '1998': ['CHH', 'CHI', 'IND', 'NYK', 'LAL', 'SAS', 'SEA', 'UTA',
                   'ATL', 'NJN', 'CLE', 'MIA', 'POR', 'PHO', 'MIN', 'HOU'],
           '1997': ['ATL', 'CHI', 'MIA', 'NYK', 'HOU', 'LAL', 'SEA', 'UTA',
                   'DET', 'WAS', 'ORL', 'CHH', 'MIN', 'POR', 'PHO', 'LAC'],
           '1996': ['ATL', 'CHI', 'NYK', 'ORL', 'HOU', 'SAS', 'SEA', 'UTA',
                   'IND', 'MIA', 'CLE', 'DET', 'LAL', 'PHO', 'SAC', 'POR'],
           '1995': ['CHI', 'IND', 'NYK', 'ORL', 'HOU', 'LAL', 'PHO', 'SAS',
                   'CHH', 'ATL', 'CLE', 'BOS', 'UTA', 'SEA', 'POR', 'DEN'],
           '1994': ['ATL', 'CHI', 'IND', 'NYK', 'DEN', 'HOU', 'PHO', 'UTA',
                   'MIA', 'CLE', 'ORL', 'NJN', 'SEA', 'POR', 'GSW', 'SAS'],
           '1993': ['CHH', 'CHI', 'CLE', 'NYK', 'HOU', 'PHO', 'SAS', 'SEA',
                   'BOS', 'ATL', 'NJN', 'IND', 'LAC', 'LAL', 'POR', 'UTA'],
           '1992': ['BOS', 'CHI', 'CLE', 'NYK', 'PHO', 'POR', 'SEA', 'UTA',
                   'IND', 'MIA', 'NJN', 'DET', 'SAS', 'LAL', 'GSW', 'LAC'],
           '1991': ['BOS', 'CHI', 'DET', 'PHI', 'GSW', 'LAL', 'POR', 'UTA',
                   'IND', 'NYK', 'ATL', 'MIL', 'SAS', 'HOU', 'SEA', 'PHO'],
           '1990': ['CHI', 'DET', 'NYK', 'PHI', 'LAL', 'PHO', 'POR', 'SAS',
                   'MIL', 'IND', 'BOS', 'CLE', 'HOU', 'UTA', 'DAL', 'DEN']}

# %% [markdown]
# Next I built a for loop for my basic stats for players over the past 30 seasons (1990-2020). These stats are your tpyical old fashion stats associated with basketball: FG%, 3PFG%, rebounds, assists, steals, blocks, and point per game. I also wanted to make sure I included the team and year along with the players name so I will know what set of statistics are associated with which player and what year of their career. Also this will allow easier joining of dataframes further on.

# %%
#basic stats ALL YEARS
players = []
for i in reversed(range(1990, 2021)):
    year = i
    url = f'https://www.basketball-reference.com/leagues/NBA_{year}_per_game.html'
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'lxml')
    table = soup.find('table', {'id': 'per_game_stats'})
    for row in table.find('tbody').find_all('tr', {'class':'full_table'}):
        player = {}
        player['name'] = row.find('td', {'data-stat': 'player'}).text
        player['team'] = row.find('td', {'data-stat': 'team_id'}).text
        player['year'] = i
        player['games_played'] = row.find('td', {'data-stat': 'g'}).text
        player['mpg'] = row.find('td', {'data-stat': 'mp_per_g'}).text
        player['fg%'] = row.find('td', {'data-stat': 'fg_pct'}).text
        player['3pfg%'] = row.find('td', {'data-stat': 'fg3_pct'}).text
        player['rebounds'] = row.find('td', {'data-stat': 'trb_per_g'}).text
        player['assists'] = row.find('td', {'data-stat': 'ast_per_g'}).text
        player['steals'] = row.find('td', {'data-stat': 'stl_per_g'}).text
        player['blocks'] = row.find('td', {'data-stat': 'blk_per_g'}).text
        player['points_per_game'] = row.find('td', {'data-stat': 'pts_per_g'}).text
        players.append(player)

time.sleep(5)        
players
# Out:
# [{'name': 'Steven Adams',
#   'team': 'OKC',
#   'year': 2020,
#   'games_played': '63',
#   'mpg': '26.7',
#   'fg%': '.592',
#   '3pfg%': '.333',
#   'rebounds': '9.3',
#   'assists': '2.3',
#   'steals': '0.8',
#   'blocks': '1.1',
#   'points_per_game': '10.9'},
#  {'name': 'Bam Adebayo',
#   'team': 'MIA',
#   'year': 2020,
#   'games_played': '72',
#   'mpg': '33.6',
#   'fg%': '.557',
#   '3pfg%': '.143',
#   'rebounds': '10.2',
#   'assists': '5.1',
#   'steals': '1.1',
#   'blocks': '1.3',
#   'points_per_game': '15.9'},
#  {'name': 'LaMarcus Aldridge',
#   'team': 'SAS',
#   'year': 2020,
#   'games_played': '53',
#   'mpg': '33.1',
#   'fg%': '.493',
#   '3pfg%': '.389',
#   'rebounds': '7.4',
#   'assists': '2.4',
#   'steals': '0.7',
#   'blocks': '1.6',
#   'points_per_game': '18.9'},
#  {'name': 'Kyle Alexander',
#   'team': 'MIA',
#   'year': 2020,
#   'games_played': '2',
#   'mpg': '6.5',
#   'fg%': '.500',
#   '3pfg%': '',
#   'rebounds': '1.5',
#   'assists': '0.0',
#   'steals': '0.0',
#   'blocks': '0.0',
#   'points_per_game': '1.0'},
#  {'name': 'Nickeil Alexander-Walker',
#   'team': 'NOP',
#   'year': 2020,
#   'games_played': '47',
#   'mpg': '12.6',
#   'fg%': '.368',
#   '3pfg%': '.346',
#   'rebounds': '1.8',
#   'assists': '1.9',
#   'steals': '0.4',
#   'blocks': '0.2',
#   'points_per_game': '5.7'},
#  {'name': 'Grayson Allen',
#   'team': 'MEM',
#   'year': 2020,
#   'games_played': '38',
#   'mpg': '18.9',
#   'fg%': '.466',
#   '3pfg%': '.404',
#   'rebounds': '2.2',
#   'assists': '1.4',
#   'steals': '0.3',
#   'blocks': '0.1',
#   'points_per_game': '8.7'},
#  {'name': 'Jarrett Allen',
#   'team': 'BRK',
#   'year': 2020,
#   'games_played': '70',
#   'mpg': '26.5',
#   'fg%': '.649',
#   '3pfg%': '.000',
#   'rebounds': '9.6',
#   'assists': '1.6',
#   'steals': '0.6',
#   'blocks': '1.3',
#   'points_per_game': '11.1'},
#  {'name': 'Kadeem Allen',
#   'team': 'NYK',
#   'year': 2020,
#   'games_played': '10',
#   'mpg': '11.7',
#   'fg%': '.432',
#   '3pfg%': '.313',
#   'rebounds': '0.9',
#   'assists': '2.1',
#   'steals': '0.5',
#   'blocks': '0.2',
#   'points_per_game': '5.0'},
#  {'name': 'Al-Farouq Aminu',
#   'team': 'ORL',
#   'year': 2020,
#   'games_played': '18',
#   'mpg': '21.1',
#   'fg%': '.291',
#   '3pfg%': '.250',
#   'rebounds': '4.8',
#   'assists': '1.2',
#   'steals': '1.0',
#   'blocks': '0.4',
#   'points_per_game': '4.3'},
#  {'name': 'Justin Anderson',
#   'team': 'BRK',
#   'year': 2020,
#   'games_played': '10',
#   'mpg': '10.7',
#   'fg%': '.263',
#   '3pfg%': '.207',
#   'rebounds': '2.1',
#   'assists': '0.8',
#   'steals': '0.0',
#   'blocks': '0.6',
#   'points_per_game': '2.8'},
#  {'name': 'Kyle Anderson',
#   'team': 'MEM',
#   'year': 2020,
#   'games_played': '67',
#   'mpg': '19.9',
#   'fg%': '.474',
#   '3pfg%': '.282',
#   'rebounds': '4.3',
#   'assists': '2.4',
#   'steals': '0.8',
#   'blocks': '0.6',
#   'points_per_game': '5.8'},
#  {'name': 'Ryan Anderson',
#   'team': 'HOU',
#   'year': 2020,
#   'games_played': '2',
#   'mpg': '7.0',
#   'fg%': '.286',
#   '3pfg%': '.200',
#   'rebounds': '3.5',
#   'assists': '1.0',
#   'steals': '0.5',
#   'blocks': '0.0',
#   'points_per_game': '2.5'},
#  {'name': 'Giannis Antetokounmpo',
#   'team': 'MIL',
#   'year': 2020,
#   'games_played': '63',
#   'mpg': '30.4',
#   'fg%': '.553',
#   '3pfg%': '.304',
#   'rebounds': '13.6',
#   'assists': '5.6',
#   'steals': '1.0',
#   'blocks': '1.0',
#   'points_per_game': '29.5'},
#  {'name': 'Kostas Antetokounmpo',
#   'team': 'LAL',
#   'year': 2020,
#   'games_played': '5',
#   'mpg': '4.0',
#   'fg%': '1.000',
#   '3pfg%': '',
#   'rebounds': '0.6',
#   'assists': '0.4',
#   'steals': '0.0',
#   'blocks': '0.0',
#   'points_per_game': '1.4'},
#  {'name': 'Thanasis Antetokounmpo',
#   'team': 'MIL',
#   'year': 2020,
#   'games_played': '20',
#   'mpg': '6.5',
#   'fg%': '.500',
#   '3pfg%': '.000',
#   'rebounds': '1.2',
#   'assists': '0.8',
#   'steals': '0.4',
#   'blocks': '0.1',
#   'points_per_game': '2.8'},
#  {'name': 'Carmelo Anthony',
#   'team': 'POR',
#   'year': 2020,
#   'games_played': '58',
#   'mpg': '32.8',
#   'fg%': '.430',
#   '3pfg%': '.385',
#   'rebounds': '6.3',
#   'assists': '1.5',
#   'steals': '0.8',
#   'blocks': '0.5',
#   'points_per_game': '15.4'},
#  {'name': 'OG Anunoby',
#   'team': 'TOR',
#   'year': 2020,
#   'games_played': '69',
#   'mpg': '29.9',
#   'fg%': '.505',
#   '3pfg%': '.390',
#   'rebounds': '5.3',
#   'assists': '1.6',
#   'steals': '1.4',
#   'blocks': '0.7',
#   'points_per_game': '10.6'},
#  {'name': 'Ryan Arcidiacono',
#   'team': 'CHI',
#   'year': 2020,
#   'games_played': '58',
#   'mpg': '16.0',
#   'fg%': '.409',
#   '3pfg%': '.391',
#   'rebounds': '1.9',
#   'assists': '1.7',
#   'steals': '0.5',
#   'blocks': '0.1',
#   'points_per_game': '4.5'},
#  {'name': 'Trevor Ariza',
#   'team': 'TOT',
#   'year': 2020,
#   'games_played': '53',
#   'mpg': '28.2',
#   'fg%': '.438',
#   '3pfg%': '.372',
#   'rebounds': '4.6',
#   'assists': '1.7',
#   'steals': '1.3',
#   'blocks': '0.3',
#   'points_per_game': '8.0'},
#  {'name': 'D.J. Augustin',
#   'team': 'ORL',
#   'year': 2020,
#   'games_played': '57',
#   'mpg': '24.9',
#   'fg%': '.399',
#   '3pfg%': '.348',
#   'rebounds': '2.1',
#   'assists': '4.6',
#   'steals': '0.6',
#   'blocks': '0.0',
#   'points_per_game': '10.5'},
#  {'name': 'Deandre Ayton',
#   'team': 'PHO',
#   'year': 2020,
#   'games_played': '38',
#   'mpg': '32.5',
#   'fg%': '.546',
#   '3pfg%': '.231',
#   'rebounds': '11.5',
#   'assists': '1.9',
#   'steals': '0.7',
#   'blocks': '1.5',
#   'points_per_game': '18.2'},
#  {'name': 'Dwayne Bacon',
#   'team': 'CHO',
#   'year': 2020,
#   'games_played': '39',
#   'mpg': '17.6',
#   'fg%': '.348',
#   '3pfg%': '.284',
#   'rebounds': '2.6',
#   'assists': '1.3',
#   'steals': '0.6',
#   'blocks': '0.1',
#   'points_per_game': '5.7'},
#  {'name': 'Marvin Bagley III',
#   'team': 'SAC',
#   'year': 2020,
#   'games_played': '13',
#   'mpg': '25.7',
#   'fg%': '.467',
#   '3pfg%': '.182',
#   'rebounds': '7.5',
#   'assists': '0.8',
#   'steals': '0.5',
#   'blocks': '0.9',
#   'points_per_game': '14.2'},
#  {'name': 'Lonzo Ball',
#   'team': 'NOP',
#   'year': 2020,
#   'games_played': '63',
#   'mpg': '32.1',
#   'fg%': '.403',
#   '3pfg%': '.375',
#   'rebounds': '6.1',
#   'assists': '7.0',
#   'steals': '1.4',
#   'blocks': '0.6',
#   'points_per_game': '11.8'},
#  {'name': 'Mo Bamba',
#   'team': 'ORL',
#   'year': 2020,
#   'games_played': '62',
#   'mpg': '14.2',
#   'fg%': '.462',
#   '3pfg%': '.346',
#   'rebounds': '4.9',
#   'assists': '0.7',
#   'steals': '0.4',
#   'blocks': '1.4',
#   'points_per_game': '5.4'},
#  {'name': 'J.J. Barea',
#   'team': 'DAL',
#   'year': 2020,
#   'games_played': '29',
#   'mpg': '15.5',
#   'fg%': '.411',
#   '3pfg%': '.376',
#   'rebounds': '1.8',
#   'assists': '3.9',
#   'steals': '0.2',
#   'blocks': '0.1',
#   'points_per_game': '7.7'},
#  {'name': 'Harrison Barnes',
#   'team': 'SAC',
#   'year': 2020,
#   'games_played': '72',
#   'mpg': '34.5',
#   'fg%': '.460',
#   '3pfg%': '.381',
#   'rebounds': '4.9',
#   'assists': '2.2',
#   'steals': '0.6',
#   'blocks': '0.2',
#   'points_per_game': '14.5'},
#  {'name': 'RJ Barrett',
#   'team': 'NYK',
#   'year': 2020,
#   'games_played': '56',
#   'mpg': '30.4',
#   'fg%': '.402',
#   '3pfg%': '.320',
#   'rebounds': '5.0',
#   'assists': '2.6',
#   'steals': '1.0',
#   'blocks': '0.3',
#   'points_per_game': '14.3'},
#  {'name': 'Will Barton',
#   'team': 'DEN',
#   'year': 2020,
#   'games_played': '58',
#   'mpg': '33.0',
#   'fg%': '.450',
#   '3pfg%': '.375',
#   'rebounds': '6.3',
#   'assists': '3.7',
#   'steals': '1.1',
#   'blocks': '0.5',
#   'points_per_game': '15.1'},
#  {'name': 'Keita Bates-Diop',
#   'team': 'TOT',
#   'year': 2020,
#   'games_played': '44',
#   'mpg': '16.9',
#   'fg%': '.427',
#   '3pfg%': '.330',
#   'rebounds': '2.9',
#   'assists': '0.7',
#   'steals': '0.4',
#   'blocks': '0.5',
#   'points_per_game': '6.5'},
#  {'name': 'Nicolas Batum',
#   'team': 'CHO',
#   'year': 2020,
#   'games_played': '22',
#   'mpg': '23.0',
#   'fg%': '.346',
#   '3pfg%': '.286',
#   'rebounds': '4.5',
#   'assists': '3.0',
#   'steals': '0.8',
#   'blocks': '0.4',
#   'points_per_game': '3.6'},
#  {'name': 'Aron Baynes',
#   'team': 'PHO',
#   'year': 2020,
#   'games_played': '42',
#   'mpg': '22.2',
#   'fg%': '.480',
#   '3pfg%': '.351',
#   'rebounds': '5.6',
#   'assists': '1.6',
#   'steals': '0.2',
#   'blocks': '0.5',
#   'points_per_game': '11.5'},
#  {'name': 'Kent Bazemore',
#   'team': 'TOT',
#   'year': 2020,
#   'games_played': '68',
#   'mpg': '24.8',
#   'fg%': '.375',
#   '3pfg%': '.344',
#   'rebounds': '4.3',
#   'assists': '1.4',
#   'steals': '1.1',
#   'blocks': '0.6',
#   'points_per_game': '8.8'},
#  {'name': 'Darius Bazley',
#   'team': 'OKC',
#   'year': 2020,
#   'games_played': '61',
#   'mpg': '18.5',
#   'fg%': '.394',
#   '3pfg%': '.348',
#   'rebounds': '4.0',
#   'assists': '0.7',
#   'steals': '0.4',
#   'blocks': '0.7',
#   'points_per_game': '5.6'},
#  {'name': 'Bradley Beal',
#   'team': 'WAS',
#   'year': 2020,
#   'games_played': '57',
#   'mpg': '36.0',
#   'fg%': '.455',
#   '3pfg%': '.353',
#   'rebounds': '4.2',
#   'assists': '6.1',
#   'steals': '1.2',
#   'blocks': '0.4',
#   'points_per_game': '30.5'},
#  {'name': 'Malik Beasley',
#   'team': 'TOT',
#   'year': 2020,
#   'games_played': '55',
#   'mpg': '22.0',
#   'fg%': '.425',
#   '3pfg%': '.388',
#   'rebounds': '2.7',
#   'assists': '1.4',
#   'steals': '0.7',
#   'blocks': '0.1',
#   'points_per_game': '11.2'},
#  {'name': 'Marco Belinelli',
#   'team': 'SAS',
#   'year': 2020,
#   'games_played': '57',
#   'mpg': '15.5',
#   'fg%': '.392',
#   '3pfg%': '.376',
#   'rebounds': '1.7',
#   'assists': '1.2',
#   'steals': '0.2',
#   'blocks': '0.0',
#   'points_per_game': '6.3'},
#  {'name': 'Jordan Bell',
#   'team': 'TOT',
#   'year': 2020,
#   'games_played': '29',
#   'mpg': '8.8',
#   'fg%': '.522',
#   '3pfg%': '.333',
#   'rebounds': '2.8',
#   'assists': '0.6',
#   'steals': '0.1',
#   'blocks': '0.3',
#   'points_per_game': '3.2'},
#  {'name': "DeAndre' Bembry",
#   'team': 'ATL',
#   'year': 2020,
#   'games_played': '43',
#   'mpg': '21.3',
#   'fg%': '.456',
#   '3pfg%': '.231',
#   'rebounds': '3.5',
#   'assists': '1.9',
#   'steals': '1.3',
#   'blocks': '0.4',
#   'points_per_game': '5.8'},
#  {'name': 'Dragan Bender',
#   'team': 'TOT',
#   'year': 2020,
#   'games_played': '16',
#   'mpg': '17.9',
#   'fg%': '.446',
#   '3pfg%': '.349',
#   'rebounds': '4.6',
#   'assists': '1.8',
#   'steals': '0.3',
#   'blocks': '0.6',
#   'points_per_game': '6.7'},
#  {'name': 'Dāvis Bertāns',
#   'team': 'WAS',
#   'year': 2020,
#   'games_played': '54',
#   'mpg': '29.3',
#   'fg%': '.434',
#   '3pfg%': '.424',
#   'rebounds': '4.5',
#   'assists': '1.7',
#   'steals': '0.7',
#   'blocks': '0.6',
#   'points_per_game': '15.4'},
#  {'name': 'Patrick Beverley',
#   'team': 'LAC',
#   'year': 2020,
#   'games_played': '51',
#   'mpg': '26.3',
#   'fg%': '.431',
#   '3pfg%': '.388',
#   'rebounds': '5.2',
#   'assists': '3.6',
#   'steals': '1.1',
#   'blocks': '0.5',
#   'points_per_game': '7.9'},
#  {'name': 'Khem Birch',
#   'team': 'ORL',
#   'year': 2020,
#   'games_played': '48',
#   'mpg': '19.2',
#   'fg%': '.510',
#   '3pfg%': '.000',
#   'rebounds': '4.6',
#   'assists': '1.0',
#   'steals': '0.4',
#   'blocks': '0.5',
#   'points_per_game': '4.4'},
#  {'name': 'Goga Bitadze',
#   'team': 'IND',
#   'year': 2020,
#   'games_played': '54',
#   'mpg': '8.7',
#   'fg%': '.467',
#   '3pfg%': '.190',
#   'rebounds': '2.0',
#   'assists': '0.4',
#   'steals': '0.2',
#   'blocks': '0.7',
#   'points_per_game': '3.2'},
#  {'name': 'Bismack Biyombo',
#   'team': 'CHO',
#   'year': 2020,
#   'games_played': '53',
#   'mpg': '19.4',
#   'fg%': '.543',
#   '3pfg%': '',
#   'rebounds': '5.8',
#   'assists': '0.9',
#   'steals': '0.2',
#   'blocks': '0.9',
#   'points_per_game': '7.4'},
#  {'name': 'Nemanja Bjelica',
#   'team': 'SAC',
#   'year': 2020,
#   'games_played': '72',
#   'mpg': '27.9',
#   'fg%': '.481',
#   '3pfg%': '.419',
#   'rebounds': '6.4',
#   'assists': '2.8',
#   'steals': '0.9',
#   'blocks': '0.6',
#   'points_per_game': '11.5'},
#  {'name': 'Eric Bledsoe',
#   'team': 'MIL',
#   'year': 2020,
#   'games_played': '61',
#   'mpg': '27.0',
#   'fg%': '.475',
#   '3pfg%': '.344',
#   'rebounds': '4.6',
#   'assists': '5.4',
#   'steals': '0.9',
#   'blocks': '0.4',
#   'points_per_game': '14.9'},
#  {'name': 'Bogdan Bogdanović',
#   'team': 'SAC',
#   'year': 2020,
#   'games_played': '61',
#   'mpg': '29.0',
#   'fg%': '.440',
#   '3pfg%': '.372',
#   'rebounds': '3.4',
#   'assists': '3.4',
#   'steals': '1.0',
#   'blocks': '0.2',
#   'points_per_game': '15.1'},
#  {'name': 'Bojan Bogdanović',
#   'team': 'UTA',
#   'year': 2020,
#   'games_played': '63',
#   'mpg': '33.1',
#   'fg%': '.447',
#   '3pfg%': '.414',
#   'rebounds': '4.1',
#   'assists': '2.1',
#   'steals': '0.5',
#   'blocks': '0.1',
#   'points_per_game': '20.2'},
#  {'name': 'Bol Bol',
#   'team': 'DEN',
#   'year': 2020,
#   'games_played': '7',
#   'mpg': '12.4',
#   'fg%': '.500',
#   '3pfg%': '.444',
#   'rebounds': '2.7',
#   'assists': '0.9',
#   'steals': '0.3',
#   'blocks': '0.9',
#   'points_per_game': '5.7'},
#  {'name': 'Jonah Bolden',
#   'team': 'TOT',
#   'year': 2020,
#   'games_played': '7',
#   'mpg': '6.7',
#   'fg%': '.364',
#   '3pfg%': '.000',
#   'rebounds': '1.3',
#   'assists': '0.0',
#   'steals': '0.4',
#   'blocks': '0.3',
#   'points_per_game': '1.4'},
#  {'name': 'Marques Bolden',
#   'team': 'CLE',
#   'year': 2020,
#   'games_played': '1',
#   'mpg': '3.0',
#   'fg%': '',
#   '3pfg%': '',
#   'rebounds': '2.0',
#   'assists': '0.0',
#   'steals': '1.0',
#   'blocks': '0.0',
#   'points_per_game': '0.0'},
#  {'name': 'Jordan Bone',
#   'team': 'DET',
#   'year': 2020,
#   'games_played': '10',
#   'mpg': '5.3',
#   'fg%': '.250',
#   '3pfg%': '.200',
#   'rebounds': '0.4',
#   'assists': '0.8',
#   'steals': '0.1',
#   'blocks': '0.0',
#   'points_per_game': '1.2'},
#  {'name': 'Isaac Bonga',
#   'team': 'WAS',
#   'year': 2020,
#   'games_played': '66',
#   'mpg': '18.9',
#   'fg%': '.504',
#   '3pfg%': '.352',
#   'rebounds': '3.4',
#   'assists': '1.2',
#   'steals': '0.7',
#   'blocks': '0.3',
#   'points_per_game': '5.0'},
#  {'name': 'Devin Booker',
#   'team': 'PHO',
#   'year': 2020,
#   'games_played': '70',
#   'mpg': '35.9',
#   'fg%': '.489',
#   '3pfg%': '.354',
#   'rebounds': '4.2',
#   'assists': '6.5',
#   'steals': '0.7',
#   'blocks': '0.3',
#   'points_per_game': '26.6'},
#  {'name': 'Chris Boucher',
#   'team': 'TOR',
#   'year': 2020,
#   'games_played': '62',
#   'mpg': '13.2',
#   'fg%': '.472',
#   '3pfg%': '.322',
#   'rebounds': '4.5',
#   'assists': '0.4',
#   'steals': '0.4',
#   'blocks': '1.0',
#   'points_per_game': '6.6'},
#  {'name': 'Brian Bowen',
#   'team': 'IND',
#   'year': 2020,
#   'games_played': '6',
#   'mpg': '5.2',
#   'fg%': '.300',
#   '3pfg%': '.000',
#   'rebounds': '1.2',
#   'assists': '0.0',
#   'steals': '0.0',
#   'blocks': '0.2',
#   'points_per_game': '1.0'},
#  {'name': 'Ky Bowman',
#   'team': 'GSW',
#   'year': 2020,
#   'games_played': '45',
#   'mpg': '22.6',
#   'fg%': '.417',
#   '3pfg%': '.308',
#   'rebounds': '2.7',
#   'assists': '2.9',
#   'steals': '1.0',
#   'blocks': '0.2',
#   'points_per_game': '7.4'},
#  {'name': 'Avery Bradley',
#   'team': 'LAL',
#   'year': 2020,
#   'games_played': '49',
#   'mpg': '24.2',
#   'fg%': '.444',
#   '3pfg%': '.364',
#   'rebounds': '2.3',
#   'assists': '1.3',
#   'steals': '0.9',
#   'blocks': '0.1',
#   'points_per_game': '8.6'},
#  {'name': 'Tony Bradley',
#   'team': 'UTA',
#   'year': 2020,
#   'games_played': '58',
#   'mpg': '11.4',
#   'fg%': '.667',
#   '3pfg%': '1.000',
#   'rebounds': '4.6',
#   'assists': '0.4',
#   'steals': '0.2',
#   'blocks': '0.6',
#   'points_per_game': '4.9'},
#  {'name': 'Jarrell Brantley',
#   'team': 'UTA',
#   'year': 2020,
#   'games_played': '9',
#   'mpg': '10.7',
#   'fg%': '.357',
#   '3pfg%': '.231',
#   'rebounds': '2.2',
#   'assists': '1.2',
#   'steals': '0.3',
#   'blocks': '0.6',
#   'points_per_game': '2.7'},
#  {'name': 'Ignas Brazdeikis',
#   'team': 'NYK',
#   'year': 2020,
#   'games_played': '9',
#   'mpg': '5.9',
#   'fg%': '.273',
#   '3pfg%': '.111',
#   'rebounds': '0.6',
#   'assists': '0.4',
#   'steals': '0.0',
#   'blocks': '0.1',
#   'points_per_game': '1.9'},
#  {'name': 'Corey Brewer',
#   'team': 'SAC',
#   'year': 2020,
#   'games_played': '5',
#   'mpg': '6.6',
#   'fg%': '.500',
#   '3pfg%': '.000',
#   'rebounds': '1.6',
#   'assists': '0.4',
#   'steals': '0.8',
#   'blocks': '0.0',
#   'points_per_game': '1.0'},
#  {'name': 'Mikal Bridges',
#   'team': 'PHO',
#   'year': 2020,
#   'games_played': '73',
#   'mpg': '28.0',
#   'fg%': '.510',
#   '3pfg%': '.361',
#   'rebounds': '4.0',
#   'assists': '1.8',
#   'steals': '1.4',
#   'blocks': '0.6',
#   'points_per_game': '9.1'},
#  {'name': 'Miles Bridges',
#   'team': 'CHO',
#   'year': 2020,
#   'games_played': '65',
#   'mpg': '30.7',
#   'fg%': '.424',
#   '3pfg%': '.330',
#   'rebounds': '5.6',
#   'assists': '1.8',
#   'steals': '0.6',
#   'blocks': '0.7',
#   'points_per_game': '13.0'},
#  {'name': 'Oshae Brissett',
#   'team': 'TOR',
#   'year': 2020,
#   'games_played': '19',
#   'mpg': '7.1',
#   'fg%': '.361',
#   '3pfg%': '.200',
#   'rebounds': '1.4',
#   'assists': '0.4',
#   'steals': '0.2',
#   'blocks': '0.1',
#   'points_per_game': '1.9'},
#  {'name': 'Ryan Broekhoff',
#   'team': 'DAL',
#   'year': 2020,
#   'games_played': '17',
#   'mpg': '10.6',
#   'fg%': '.373',
#   '3pfg%': '.392',
#   'rebounds': '2.5',
#   'assists': '0.6',
#   'steals': '0.3',
#   'blocks': '0.2',
#   'points_per_game': '4.2'},
#  {'name': 'Malcolm Brogdon',
#   'team': 'IND',
#   'year': 2020,
#   'games_played': '54',
#   'mpg': '30.9',
#   'fg%': '.438',
#   '3pfg%': '.326',
#   'rebounds': '4.9',
#   'assists': '7.1',
#   'steals': '0.6',
#   'blocks': '0.2',
#   'points_per_game': '16.5'},
#  {'name': 'Dillon Brooks',
#   'team': 'MEM',
#   'year': 2020,
#   'games_played': '73',
#   'mpg': '28.9',
#   'fg%': '.407',
#   '3pfg%': '.358',
#   'rebounds': '3.3',
#   'assists': '2.1',
#   'steals': '0.9',
#   'blocks': '0.4',
#   'points_per_game': '16.2'},
#  {'name': 'Bruce Brown',
#   'team': 'DET',
#   'year': 2020,
#   'games_played': '58',
#   'mpg': '28.2',
#   'fg%': '.443',
#   '3pfg%': '.344',
#   'rebounds': '4.7',
#   'assists': '4.0',
#   'steals': '1.1',
#   'blocks': '0.5',
#   'points_per_game': '8.9'},
#  {'name': 'Charlie Brown',
#   'team': 'ATL',
#   'year': 2020,
#   'games_played': '10',
#   'mpg': '4.0',
#   'fg%': '.316',
#   '3pfg%': '.333',
#   'rebounds': '0.4',
#   'assists': '0.2',
#   'steals': '0.2',
#   'blocks': '0.2',
#   'points_per_game': '2.0'},
#  {'name': 'Jaylen Brown',
#   'team': 'BOS',
#   'year': 2020,
#   'games_played': '57',
#   'mpg': '33.9',
#   'fg%': '.481',
#   '3pfg%': '.382',
#   'rebounds': '6.4',
#   'assists': '2.1',
#   'steals': '1.1',
#   'blocks': '0.4',
#   'points_per_game': '20.3'},
#  {'name': 'Moses Brown',
#   'team': 'POR',
#   'year': 2020,
#   'games_played': '9',
#   'mpg': '3.7',
#   'fg%': '.400',
#   '3pfg%': '',
#   'rebounds': '1.6',
#   'assists': '0.1',
#   'steals': '0.1',
#   'blocks': '0.1',
#   'points_per_game': '1.2'},
#  {'name': 'Sterling Brown',
#   'team': 'MIL',
#   'year': 2020,
#   'games_played': '52',
#   'mpg': '14.8',
#   'fg%': '.371',
#   '3pfg%': '.324',
#   'rebounds': '3.5',
#   'assists': '1.0',
#   'steals': '0.6',
#   'blocks': '0.1',
#   'points_per_game': '5.1'},
#  {'name': 'Troy Brown Jr.',
#   'team': 'WAS',
#   'year': 2020,
#   'games_played': '69',
#   'mpg': '25.8',
#   'fg%': '.439',
#   '3pfg%': '.341',
#   'rebounds': '5.6',
#   'assists': '2.6',
#   'steals': '1.2',
#   'blocks': '0.1',
#   'points_per_game': '10.4'},
#  {'name': 'Jalen Brunson',
#   'team': 'DAL',
#   'year': 2020,
#   'games_played': '57',
#   'mpg': '17.9',
#   'fg%': '.466',
#   '3pfg%': '.358',
#   'rebounds': '2.4',
#   'assists': '3.3',
#   'steals': '0.4',
#   'blocks': '0.1',
#   'points_per_game': '8.2'},
#  {'name': 'Thomas Bryant',
#   'team': 'WAS',
#   'year': 2020,
#   'games_played': '46',
#   'mpg': '24.9',
#   'fg%': '.581',
#   '3pfg%': '.407',
#   'rebounds': '7.2',
#   'assists': '1.8',
#   'steals': '0.5',
#   'blocks': '1.1',
#   'points_per_game': '13.2'},
#  {'name': 'Reggie Bullock',
#   'team': 'NYK',
#   'year': 2020,
#   'games_played': '29',
#   'mpg': '23.6',
#   'fg%': '.402',
#   '3pfg%': '.333',
#   'rebounds': '2.3',
#   'assists': '1.4',
#   'steals': '0.9',
#   'blocks': '0.1',
#   'points_per_game': '8.1'},
#  {'name': 'Trey Burke',
#   'team': 'TOT',
#   'year': 2020,
#   'games_played': '33',
#   'mpg': '15.8',
#   'fg%': '.450',
#   '3pfg%': '.427',
#   'rebounds': '1.5',
#   'assists': '2.5',
#   'steals': '0.5',
#   'blocks': '0.1',
#   'points_per_game': '7.4'},
#  {'name': 'Alec Burks',
#   'team': 'TOT',
#   'year': 2020,
#   'games_played': '66',
#   'mpg': '26.6',
#   'fg%': '.418',
#   '3pfg%': '.385',
#   'rebounds': '4.3',
#   'assists': '2.9',
#   'steals': '0.9',
#   'blocks': '0.3',
#   'points_per_game': '15.0'},
#  {'name': 'Deonte Burton',
#   'team': 'OKC',
#   'year': 2020,
#   'games_played': '39',
#   'mpg': '9.1',
#   'fg%': '.344',
#   '3pfg%': '.189',
#   'rebounds': '1.5',
#   'assists': '0.4',
#   'steals': '0.2',
#   'blocks': '0.3',
#   'points_per_game': '2.7'},
#  {'name': 'Jimmy Butler',
#   'team': 'MIA',
#   'year': 2020,
#   'games_played': '58',
#   'mpg': '33.8',
#   'fg%': '.455',
#   '3pfg%': '.244',
#   'rebounds': '6.7',
#   'assists': '6.0',
#   'steals': '1.8',
#   'blocks': '0.6',
#   'points_per_game': '19.9'},
#  {'name': 'Bruno Caboclo',
#   'team': 'TOT',
#   'year': 2020,
#   'games_played': '30',
#   'mpg': '8.1',
#   'fg%': '.427',
#   '3pfg%': '.182',
#   'rebounds': '2.0',
#   'assists': '0.4',
#   'steals': '0.5',
#   'blocks': '0.6',
#   'points_per_game': '3.0'},
#  {'name': 'Devontae Cacok',
#   'team': 'LAL',
#   'year': 2020,
#   'games_played': '1',
#   'mpg': '9.0',
#   'fg%': '.500',
#   '3pfg%': '',
#   'rebounds': '5.0',
#   'assists': '1.0',
#   'steals': '0.0',
#   'blocks': '0.0',
#   'points_per_game': '6.0'},
#  {'name': 'Kentavious Caldwell-Pope',
#   'team': 'LAL',
#   'year': 2020,
#   'games_played': '69',
#   'mpg': '25.5',
#   'fg%': '.467',
#   '3pfg%': '.385',
#   'rebounds': '2.1',
#   'assists': '1.6',
#   'steals': '0.8',
#   'blocks': '0.2',
#   'points_per_game': '9.3'},
#  {'name': 'Vlatko Čančar',
#   'team': 'DEN',
#   'year': 2020,
#   'games_played': '14',
#   'mpg': '3.2',
#   'fg%': '.400',
#   '3pfg%': '.167',
#   'rebounds': '0.7',
#   'assists': '0.2',
#   'steals': '0.1',
#   'blocks': '0.1',
#   'points_per_game': '1.2'},
#  {'name': 'Clint Capela',
#   'team': 'HOU',
#   'year': 2020,
#   'games_played': '39',
#   'mpg': '32.8',
#   'fg%': '.629',
#   '3pfg%': '',
#   'rebounds': '13.8',
#   'assists': '1.2',
#   'steals': '0.8',
#   'blocks': '1.8',
#   'points_per_game': '13.9'},
#  {'name': 'DeMarre Carroll',
#   'team': 'TOT',
#   'year': 2020,
#   'games_played': '24',
#   'mpg': '12.1',
#   'fg%': '.379',
#   '3pfg%': '.242',
#   'rebounds': '2.3',
#   'assists': '1.0',
#   'steals': '0.3',
#   'blocks': '0.2',
#   'points_per_game': '3.6'},
#  {'name': 'Jevon Carter',
#   'team': 'PHO',
#   'year': 2020,
#   'games_played': '58',
#   'mpg': '16.3',
#   'fg%': '.416',
#   '3pfg%': '.425',
#   'rebounds': '2.0',
#   'assists': '1.4',
#   'steals': '0.8',
#   'blocks': '0.3',
#   'points_per_game': '4.9'},
#  {'name': 'Vince Carter',
#   'team': 'ATL',
#   'year': 2020,
#   'games_played': '60',
#   'mpg': '14.6',
#   'fg%': '.352',
#   '3pfg%': '.302',
#   'rebounds': '2.1',
#   'assists': '0.8',
#   'steals': '0.4',
#   'blocks': '0.4',
#   'points_per_game': '5.0'},
#  {'name': 'Wendell Carter Jr.',
#   'team': 'CHI',
#   'year': 2020,
#   'games_played': '43',
#   'mpg': '29.2',
#   'fg%': '.534',
#   '3pfg%': '.207',
#   'rebounds': '9.4',
#   'assists': '1.2',
#   'steals': '0.8',
#   'blocks': '0.8',
#   'points_per_game': '11.3'},
#  {'name': 'Michael Carter-Williams',
#   'team': 'ORL',
#   'year': 2020,
#   'games_played': '45',
#   'mpg': '18.5',
#   'fg%': '.427',
#   '3pfg%': '.293',
#   'rebounds': '3.3',
#   'assists': '2.4',
#   'steals': '1.1',
#   'blocks': '0.5',
#   'points_per_game': '7.2'},
#  {'name': 'Alex Caruso',
#   'team': 'LAL',
#   'year': 2020,
#   'games_played': '64',
#   'mpg': '18.4',
#   'fg%': '.412',
#   '3pfg%': '.333',
#   'rebounds': '1.9',
#   'assists': '1.9',
#   'steals': '1.1',
#   'blocks': '0.3',
#   'points_per_game': '5.5'},
#  {'name': 'Willie Cauley-Stein',
#   'team': 'TOT',
#   'year': 2020,
#   'games_played': '54',
#   'mpg': '20.3',
#   'fg%': '.579',
#   '3pfg%': '.000',
#   'rebounds': '5.8',
#   'assists': '1.3',
#   'steals': '0.9',
#   'blocks': '1.1',
#   'points_per_game': '7.2'},
#  {'name': 'Tyson Chandler',
#   'team': 'HOU',
#   'year': 2020,
#   'games_played': '26',
#   'mpg': '8.4',
#   'fg%': '.778',
#   '3pfg%': '',
#   'rebounds': '2.5',
#   'assists': '0.2',
#   'steals': '0.2',
#   'blocks': '0.3',
#   'points_per_game': '1.3'},
#  {'name': 'Wilson Chandler',
#   'team': 'BRK',
#   'year': 2020,
#   'games_played': '35',
#   'mpg': '21.0',
#   'fg%': '.404',
#   '3pfg%': '.306',
#   'rebounds': '4.1',
#   'assists': '1.1',
#   'steals': '0.5',
#   'blocks': '0.3',
#   'points_per_game': '5.9'},
#  {'name': 'Joe Chealey',
#   'team': 'CHO',
#   'year': 2020,
#   'games_played': '4',
#   'mpg': '8.3',
#   'fg%': '.000',
#   '3pfg%': '.000',
#   'rebounds': '0.0',
#   'assists': '0.3',
#   'steals': '1.0',
#   'blocks': '0.0',
#   'points_per_game': '0.5'},
#  {'name': 'Zylan Cheatham',
#   'team': 'NOP',
#   'year': 2020,
#   'games_played': '4',
#   'mpg': '12.8',
#   'fg%': '.667',
#   '3pfg%': '.000',
#   'rebounds': '2.3',
#   'assists': '0.8',
#   'steals': '0.3',
#   'blocks': '0.3',
#   'points_per_game': '3.0'},
#  {'name': 'Chris Chiozza',
#   'team': 'TOT',
#   'year': 2020,
#   'games_played': '28',
#   'mpg': '14.3',
#   'fg%': '.393',
#   '3pfg%': '.375',
#   'rebounds': '1.9',
#   'assists': '3.0',
#   'steals': '0.8',
#   'blocks': '0.1',
#   'points_per_game': '5.1'},
#  {'name': 'Marquese Chriss',
#   'team': 'GSW',
#   'year': 2020,
#   'games_played': '59',
#   'mpg': '20.3',
#   'fg%': '.545',
#   '3pfg%': '.205',
#   'rebounds': '6.2',
#   'assists': '1.9',
#   'steals': '0.7',
#   'blocks': '1.1',
#   'points_per_game': '9.3'},
#  {'name': 'Gary Clark',
#   'team': 'TOT',
#   'year': 2020,
#   'games_played': '42',
#   'mpg': '13.5',
#   'fg%': '.406',
#   '3pfg%': '.351',
#   'rebounds': '2.6',
#   'assists': '0.4',
#   'steals': '0.1',
#   'blocks': '0.5',
#   'points_per_game': '3.7'},
#  {'name': 'Brandon Clarke',
#   'team': 'MEM',
#   'year': 2020,
#   'games_played': '58',
#   'mpg': '22.4',
#   'fg%': '.618',
#   '3pfg%': '.359',
#   'rebounds': '5.9',
#   'assists': '1.4',
#   'steals': '0.6',
#   'blocks': '0.8',
#   'points_per_game': '12.1'},
#  {'name': 'Jordan Clarkson',
#   'team': 'TOT',
#   'year': 2020,
#   'games_played': '71',
#   'mpg': '24.0',
#   'fg%': '.454',
#   '3pfg%': '.368',
#   'rebounds': '2.6',
#   'assists': '1.9',
#   'steals': '0.6',
#   'blocks': '0.2',
#   'points_per_game': '15.2'},
#  {'name': 'Nicolas Claxton',
#   'team': 'BRK',
#   'year': 2020,
#   'games_played': '15',
#   'mpg': '12.5',
#   'fg%': '.563',
#   '3pfg%': '.143',
#   'rebounds': '2.9',
#   'assists': '1.1',
#   'steals': '0.1',
#   'blocks': '0.5',
#   'points_per_game': '4.4'},
#  {'name': 'Chris Clemons',
#   'team': 'HOU',
#   'year': 2020,
#   'games_played': '33',
#   'mpg': '8.8',
#   'fg%': '.401',
#   '3pfg%': '.346',
#   'rebounds': '0.9',
#   'assists': '0.8',
#   'steals': '0.3',
#   'blocks': '0.2',
#   'points_per_game': '4.9'},
#  {'name': 'Antonius Cleveland',
#   'team': 'DAL',
#   'year': 2020,
#   'games_played': '11',
#   'mpg': '4.2',
#   'fg%': '.286',
#   '3pfg%': '.000',
#   'rebounds': '0.6',
#   'assists': '0.1',
#   'steals': '0.1',
#   'blocks': '0.3',
#   'points_per_game': '1.0'},
#  {'name': 'Amir Coffey',
#   'team': 'LAC',
#   'year': 2020,
#   'games_played': '18',
#   'mpg': '8.8',
#   'fg%': '.426',
#   '3pfg%': '.316',
#   'rebounds': '0.9',
#   'assists': '0.8',
#   'steals': '0.3',
#   'blocks': '0.1',
#   'points_per_game': '3.2'},
#  {'name': 'John Collins',
#   'team': 'ATL',
#   'year': 2020,
#   'games_played': '41',
#   'mpg': '33.2',
#   'fg%': '.583',
#   '3pfg%': '.401',
#   'rebounds': '10.1',
#   'assists': '1.5',
#   'steals': '0.8',
#   'blocks': '1.6',
#   'points_per_game': '21.6'},
#  {'name': 'Zach Collins',
#   'team': 'POR',
#   'year': 2020,
#   'games_played': '11',
#   'mpg': '26.4',
#   'fg%': '.471',
#   '3pfg%': '.368',
#   'rebounds': '6.3',
#   'assists': '1.5',
#   'steals': '0.5',
#   'blocks': '0.5',
#   'points_per_game': '7.0'},
#  {'name': 'Mike Conley',
#   'team': 'UTA',
#   'year': 2020,
#   'games_played': '47',
#   'mpg': '29.0',
#   'fg%': '.409',
#   '3pfg%': '.375',
#   'rebounds': '3.2',
#   'assists': '4.4',
#   'steals': '0.8',
#   'blocks': '0.1',
#   'points_per_game': '14.4'},
#  {'name': 'Pat Connaughton',
#   'team': 'MIL',
#   'year': 2020,
#   'games_played': '67',
#   'mpg': '18.6',
#   'fg%': '.455',
#   '3pfg%': '.331',
#   'rebounds': '4.2',
#   'assists': '1.6',
#   'steals': '0.4',
#   'blocks': '0.5',
#   'points_per_game': '5.4'},
#  {'name': 'Quinn Cook',
#   'team': 'LAL',
#   'year': 2020,
#   'games_played': '44',
#   'mpg': '11.5',
#   'fg%': '.425',
#   '3pfg%': '.365',
#   'rebounds': '1.2',
#   'assists': '1.1',
#   'steals': '0.3',
#   'blocks': '0.0',
#   'points_per_game': '5.1'},
#  {'name': 'Tyler Cook',
#   'team': 'TOT',
#   'year': 2020,
#   'games_played': '13',
#   'mpg': '4.2',
#   'fg%': '.667',
#   '3pfg%': '',
#   'rebounds': '1.1',
#   'assists': '0.1',
#   'steals': '0.2',
#   'blocks': '0.0',
#   'points_per_game': '1.8'},
#  {'name': 'Robert Covington',
#   'team': 'TOT',
#   'year': 2020,
#   'games_played': '70',
#   'mpg': '30.5',
#   'fg%': '.422',
#   '3pfg%': '.335',
#   'rebounds': '6.6',
#   'assists': '1.3',
#   'steals': '1.6',
#   'blocks': '1.3',
#   'points_per_game': '12.4'},
#  {'name': 'Allen Crabbe',
#   'team': 'TOT',
#   'year': 2020,
#   'games_played': '37',
#   'mpg': '17.6',
#   'fg%': '.356',
#   '3pfg%': '.303',
#   'rebounds': '2.1',
#   'assists': '0.9',
#   'steals': '0.4',
#   'blocks': '0.1',
#   'points_per_game': '4.6'},
#  {'name': 'Torrey Craig',
#   'team': 'DEN',
#   'year': 2020,
#   'games_played': '58',
#   'mpg': '18.5',
#   'fg%': '.461',
#   '3pfg%': '.326',
#   'rebounds': '3.3',
#   'assists': '0.8',
#   'steals': '0.4',
#   'blocks': '0.6',
#   'points_per_game': '5.4'},
#  {'name': 'Jamal Crawford',
#   'team': 'BRK',
#   'year': 2020,
#   'games_played': '1',
#   'mpg': '6.0',
#   'fg%': '.500',
#   '3pfg%': '.500',
#   'rebounds': '0.0',
#   'assists': '3.0',
#   'steals': '0.0',
#   'blocks': '0.0',
#   'points_per_game': '5.0'},
#  {'name': 'Jae Crowder',
#   'team': 'TOT',
#   'year': 2020,
#   'games_played': '65',
#   'mpg': '28.8',
#   'fg%': '.401',
#   '3pfg%': '.343',
#   'rebounds': '5.9',
#   'assists': '2.5',
#   'steals': '1.1',
#   'blocks': '0.4',
#   'points_per_game': '10.5'},
#  {'name': 'Jarrett Culver',
#   'team': 'MIN',
#   'year': 2020,
#   'games_played': '63',
#   'mpg': '23.9',
#   'fg%': '.404',
#   '3pfg%': '.299',
#   'rebounds': '3.4',
#   'assists': '1.7',
#   'steals': '0.9',
#   'blocks': '0.6',
#   'points_per_game': '9.2'},
#  {'name': 'Seth Curry',
#   'team': 'DAL',
#   'year': 2020,
#   'games_played': '64',
#   'mpg': '24.6',
#   'fg%': '.495',
#   '3pfg%': '.452',
#   'rebounds': '2.3',
#   'assists': '1.9',
#   'steals': '0.6',
#   'blocks': '0.1',
#   'points_per_game': '12.4'},
#  {'name': 'Stephen Curry',
#   'team': 'GSW',
#   'year': 2020,
#   'games_played': '5',
#   'mpg': '27.8',
#   'fg%': '.402',
#   '3pfg%': '.245',
#   'rebounds': '5.2',
#   'assists': '6.6',
#   'steals': '1.0',
#   'blocks': '0.4',
#   'points_per_game': '20.8'},
#  {'name': 'Troy Daniels',
#   'team': 'TOT',
#   'year': 2020,
#   'games_played': '47',
#   'mpg': '11.3',
#   'fg%': '.387',
#   '3pfg%': '.348',
#   'rebounds': '1.1',
#   'assists': '0.4',
#   'steals': '0.2',
#   'blocks': '0.1',
#   'points_per_game': '4.3'},
#  {'name': 'Anthony Davis',
#   'team': 'LAL',
#   'year': 2020,
#   'games_played': '62',
#   'mpg': '34.4',
#   'fg%': '.503',
#   '3pfg%': '.330',
#   'rebounds': '9.3',
#   'assists': '3.2',
#   'steals': '1.5',
#   'blocks': '2.3',
#   'points_per_game': '26.1'},
#  {'name': 'Ed Davis',
#   'team': 'UTA',
#   'year': 2020,
#   'games_played': '28',
#   'mpg': '10.8',
#   'fg%': '.478',
#   '3pfg%': '',
#   'rebounds': '3.8',
#   'assists': '0.4',
#   'steals': '0.4',
#   'blocks': '0.3',
#   'points_per_game': '1.8'},
#  {'name': 'Terence Davis',
#   'team': 'TOR',
#   'year': 2020,
#   'games_played': '72',
#   'mpg': '16.8',
#   'fg%': '.456',
#   '3pfg%': '.388',
#   'rebounds': '3.3',
#   'assists': '1.6',
#   'steals': '0.5',
#   'blocks': '0.2',
#   'points_per_game': '7.5'},
#  {'name': 'Dewayne Dedmon',
#   'team': 'TOT',
#   'year': 2020,
#   'games_played': '44',
#   'mpg': '17.6',
#   'fg%': '.400',
#   '3pfg%': '.206',
#   'rebounds': '5.7',
#   'assists': '0.5',
#   'steals': '0.6',
#   'blocks': '0.9',
#   'points_per_game': '5.8'},
#  {'name': 'Matthew Dellavedova',
#   'team': 'CLE',
#   'year': 2020,
#   'games_played': '57',
#   'mpg': '14.4',
#   'fg%': '.354',
#   '3pfg%': '.231',
#   'rebounds': '1.3',
#   'assists': '3.2',
#   'steals': '0.4',
#   'blocks': '0.0',
#   'points_per_game': '3.1'},
#  {'name': 'DeMar DeRozan',
#   'team': 'SAS',
#   'year': 2020,
#   'games_played': '68',
#   'mpg': '34.1',
#   'fg%': '.531',
#   '3pfg%': '.257',
#   'rebounds': '5.5',
#   'assists': '5.6',
#   'steals': '1.0',
#   'blocks': '0.3',
#   'points_per_game': '22.1'},
#  {'name': 'Cheick Diallo',
#   'team': 'PHO',
#   'year': 2020,
#   'games_played': '47',
#   'mpg': '10.2',
#   'fg%': '.648',
#   '3pfg%': '.333',
#   'rebounds': '2.8',
#   'assists': '0.5',
#   'steals': '0.2',
#   'blocks': '0.3',
#   'points_per_game': '4.7'},
#  {'name': 'Hamidou Diallo',
#   'team': 'OKC',
#   'year': 2020,
#   'games_played': '46',
#   'mpg': '19.5',
#   'fg%': '.446',
#   '3pfg%': '.281',
#   'rebounds': '3.6',
#   'assists': '0.8',
#   'steals': '0.8',
#   'blocks': '0.2',
#   'points_per_game': '6.9'},
#  {'name': 'Gorgui Dieng',
#   'team': 'TOT',
#   'year': 2020,
#   'games_played': '63',
#   'mpg': '17.4',
#   'fg%': '.456',
#   '3pfg%': '.355',
#   'rebounds': '5.6',
#   'assists': '1.2',
#   'steals': '0.8',
#   'blocks': '0.9',
#   'points_per_game': '7.4'},
#  {'name': 'Spencer Dinwiddie',
#   'team': 'BRK',
#   'year': 2020,
#   'games_played': '64',
#   'mpg': '31.2',
#   'fg%': '.415',
#   '3pfg%': '.308',
#   'rebounds': '3.5',
#   'assists': '6.8',
#   'steals': '0.6',
#   'blocks': '0.3',
#   'points_per_game': '20.6'},
#  {'name': 'Donte DiVincenzo',
#   'team': 'MIL',
#   'year': 2020,
#   'games_played': '66',
#   'mpg': '23.0',
#   'fg%': '.455',
#   '3pfg%': '.336',
#   'rebounds': '4.8',
#   'assists': '2.3',
#   'steals': '1.3',
#   'blocks': '0.3',
#   'points_per_game': '9.2'},
#  {'name': 'Luka Dončić',
#   'team': 'DAL',
#   'year': 2020,
#   'games_played': '61',
#   'mpg': '33.6',
#   'fg%': '.463',
#   '3pfg%': '.316',
#   'rebounds': '9.4',
#   'assists': '8.8',
#   'steals': '1.0',
#   'blocks': '0.2',
#   'points_per_game': '28.8'},
#  {'name': 'Luguentz Dort',
#   'team': 'OKC',
#   'year': 2020,
#   'games_played': '36',
#   'mpg': '22.8',
#   'fg%': '.394',
#   '3pfg%': '.297',
#   'rebounds': '2.3',
#   'assists': '0.8',
#   'steals': '0.9',
#   'blocks': '0.1',
#   'points_per_game': '6.8'},
#  {'name': 'Damyean Dotson',
#   'team': 'NYK',
#   'year': 2020,
#   'games_played': '48',
#   'mpg': '17.4',
#   'fg%': '.414',
#   '3pfg%': '.362',
#   'rebounds': '1.9',
#   'assists': '1.2',
#   'steals': '0.5',
#   'blocks': '0.1',
#   'points_per_game': '6.7'},
#  {'name': 'Sekou Doumbouya',
#   'team': 'DET',
#   'year': 2020,
#   'games_played': '38',
#   'mpg': '19.8',
#   'fg%': '.390',
#   '3pfg%': '.286',
#   'rebounds': '3.1',
#   'assists': '0.5',
#   'steals': '0.5',
#   'blocks': '0.2',
#   'points_per_game': '6.4'},
#  {'name': 'PJ Dozier',
#   'team': 'DEN',
#   'year': 2020,
#   'games_played': '29',
#   'mpg': '14.2',
#   'fg%': '.414',
#   '3pfg%': '.347',
#   'rebounds': '1.9',
#   'assists': '2.2',
#   'steals': '0.5',
#   'blocks': '0.2',
#   'points_per_game': '5.8'},
#  {'name': 'Goran Dragić',
#   'team': 'MIA',
#   'year': 2020,
#   'games_played': '59',
#   'mpg': '28.2',
#   'fg%': '.441',
#   '3pfg%': '.367',
#   'rebounds': '3.2',
#   'assists': '5.1',
#   'steals': '0.7',
#   'blocks': '0.2',
#   'points_per_game': '16.2'},
#  {'name': 'Andre Drummond',
#   'team': 'TOT',
#   'year': 2020,
#   'games_played': '57',
#   'mpg': '33.0',
#   'fg%': '.533',
#   '3pfg%': '.143',
#   'rebounds': '15.2',
#   'assists': '2.7',
#   'steals': '1.9',
#   'blocks': '1.6',
#   'points_per_game': '17.7'},
#  {'name': 'Jared Dudley',
#   'team': 'LAL',
#   'year': 2020,
#   'games_played': '45',
#   'mpg': '8.1',
#   'fg%': '.400',
#   '3pfg%': '.429',
#   'rebounds': '1.2',
#   'assists': '0.6',
#   'steals': '0.3',
#   'blocks': '0.1',
#   'points_per_game': '1.5'},
#  {'name': 'Kris Dunn',
#   'team': 'CHI',
#   'year': 2020,
#   'games_played': '51',
#   'mpg': '24.9',
#   'fg%': '.444',
#   '3pfg%': '.259',
#   'rebounds': '3.6',
#   'assists': '3.4',
#   'steals': '2.0',
#   'blocks': '0.3',
#   'points_per_game': '7.3'},
#  {'name': 'Carsen Edwards',
#   'team': 'BOS',
#   'year': 2020,
#   'games_played': '37',
#   'mpg': '9.5',
#   'fg%': '.328',
#   '3pfg%': '.316',
#   'rebounds': '1.3',
#   'assists': '0.6',
#   'steals': '0.3',
#   'blocks': '0.1',
#   'points_per_game': '3.3'},
#  {'name': 'Henry Ellenson',
#   'team': 'BRK',
#   'year': 2020,
#   'games_played': '5',
#   'mpg': '3.0',
#   'fg%': '.143',
#   '3pfg%': '.000',
#   'rebounds': '1.2',
#   'assists': '0.2',
#   'steals': '0.0',
#   'blocks': '0.0',
#   'points_per_game': '0.4'},
#  {'name': 'Wayne Ellington',
#   'team': 'NYK',
#   'year': 2020,
#   'games_played': '36',
#   'mpg': '15.5',
#   'fg%': '.351',
#   '3pfg%': '.350',
#   'rebounds': '1.8',
#   'assists': '1.2',
#   'steals': '0.4',
#   'blocks': '0.1',
#   'points_per_game': '5.1'},
#  {'name': 'Joel Embiid',
#   'team': 'PHI',
#   'year': 2020,
#   'games_played': '51',
#   'mpg': '29.5',
#   'fg%': '.477',
#   '3pfg%': '.331',
#   'rebounds': '11.6',
#   'assists': '3.0',
#   'steals': '0.9',
#   'blocks': '1.3',
#   'points_per_game': '23.0'},
#  {'name': 'James Ennis',
#   'team': 'TOT',
#   'year': 2020,
#   'games_played': '69',
#   'mpg': '18.3',
#   'fg%': '.446',
#   '3pfg%': '.325',
#   'rebounds': '3.6',
#   'assists': '0.9',
#   'steals': '0.5',
#   'blocks': '0.3',
#   'points_per_game': '6.6'},
#  {'name': 'Drew Eubanks',
#   'team': 'SAS',
#   'year': 2020,
#   'games_played': '22',
#   'mpg': '12.4',
#   'fg%': '.642',
#   '3pfg%': '1.000',
#   'rebounds': '3.9',
#   'assists': '0.7',
#   'steals': '0.2',
#   'blocks': '0.8',
#   'points_per_game': '4.9'},
#  {'name': 'Jacob Evans',
#   'team': 'TOT',
#   'year': 2020,
#   'games_played': '29',
#   'mpg': '14.4',
#   'fg%': '.336',
#   '3pfg%': '.333',
#   'rebounds': '1.4',
#   'assists': '1.1',
#   'steals': '0.4',
#   'blocks': '0.4',
#   'points_per_game': '4.4'},
#  {'name': 'Dante Exum',
#   'team': 'TOT',
#   'year': 2020,
#   'games_played': '35',
#   'mpg': '13.9',
#   'fg%': '.471',
#   '3pfg%': '.349',
#   'rebounds': '1.9',
#   'assists': '1.1',
#   'steals': '0.4',
#   'blocks': '0.2',
#   'points_per_game': '4.5'},
#  {'name': 'Tacko Fall',
#   'team': 'BOS',
#   'year': 2020,
#   'games_played': '7',
#   'mpg': '4.7',
#   'fg%': '.786',
#   '3pfg%': '',
#   'rebounds': '2.1',
#   'assists': '0.1',
#   'steals': '0.1',
#   'blocks': '0.6',
#   'points_per_game': '3.3'},
#  {'name': 'Derrick Favors',
#   'team': 'NOP',
#   'year': 2020,
#   'games_played': '51',
#   'mpg': '24.4',
#   'fg%': '.617',
#   '3pfg%': '.143',
#   'rebounds': '9.8',
#   'assists': '1.6',
#   'steals': '0.6',
#   'blocks': '0.9',
#   'points_per_game': '9.0'},
#  {'name': 'Cristiano Felício',
#   'team': 'CHI',
#   'year': 2020,
#   'games_played': '22',
#   'mpg': '17.5',
#   'fg%': '.630',
#   '3pfg%': '.000',
#   'rebounds': '4.6',
#   'assists': '0.7',
#   'steals': '0.5',
#   'blocks': '0.1',
#   'points_per_game': '3.9'},
#  {'name': 'Terrance Ferguson',
#   'team': 'OKC',
#   'year': 2020,
#   'games_played': '56',
#   'mpg': '22.4',
#   'fg%': '.355',
#   '3pfg%': '.292',
#   'rebounds': '1.3',
#   'assists': '0.9',
#   'steals': '0.5',
#   'blocks': '0.3',
#   'points_per_game': '3.9'},
#  {'name': 'Bruno Fernando',
#   'team': 'ATL',
#   'year': 2020,
#   'games_played': '56',
#   'mpg': '12.7',
#   'fg%': '.518',
#   '3pfg%': '.135',
#   'rebounds': '3.5',
#   'assists': '0.9',
#   'steals': '0.3',
#   'blocks': '0.3',
#   'points_per_game': '4.3'},
#  {'name': 'Yogi Ferrell',
#   'team': 'SAC',
#   'year': 2020,
#   'games_played': '50',
#   'mpg': '10.6',
#   'fg%': '.420',
#   '3pfg%': '.304',
#   'rebounds': '1.0',
#   'assists': '1.4',
#   'steals': '0.4',
#   'blocks': '0.1',
#   'points_per_game': '4.4'},
#  {'name': 'Dorian Finney-Smith',
#   'team': 'DAL',
#   'year': 2020,
#   'games_played': '71',
#   'mpg': '29.9',
#   'fg%': '.466',
#   '3pfg%': '.376',
#   'rebounds': '5.7',
#   'assists': '1.6',
#   'steals': '0.6',
#   'blocks': '0.5',
#   'points_per_game': '9.5'},
#  {'name': 'Bryn Forbes',
#   'team': 'SAS',
#   'year': 2020,
#   'games_played': '63',
#   'mpg': '25.1',
#   'fg%': '.417',
#   '3pfg%': '.388',
#   'rebounds': '2.0',
#   'assists': '1.7',
#   'steals': '0.5',
#   'blocks': '0.0',
#   'points_per_game': '11.2'},
#  {'name': 'Evan Fournier',
#   'team': 'ORL',
#   'year': 2020,
#   'games_played': '66',
#   'mpg': '31.5',
#   'fg%': '.467',
#   '3pfg%': '.399',
#   'rebounds': '2.6',
#   'assists': '3.2',
#   'steals': '1.1',
#   'blocks': '0.2',
#   'points_per_game': '18.5'},
#  {'name': "De'Aaron Fox",
#   'team': 'SAC',
#   'year': 2020,
#   'games_played': '51',
#   'mpg': '32.0',
#   'fg%': '.480',
#   '3pfg%': '.292',
#   'rebounds': '3.8',
#   'assists': '6.8',
#   'steals': '1.5',
#   'blocks': '0.5',
#   'points_per_game': '21.1'},
#  {'name': 'Melvin Frazier',
#   'team': 'ORL',
#   'year': 2020,
#   'games_played': '19',
#   'mpg': '6.6',
#   'fg%': '.441',
#   '3pfg%': '.500',
#   'rebounds': '0.5',
#   'assists': '0.2',
#   'steals': '0.5',
#   'blocks': '0.1',
#   'points_per_game': '2.1'},
#  {'name': 'Michael Frazier',
#   'team': 'HOU',
#   'year': 2020,
#   'games_played': '13',
#   'mpg': '11.2',
#   'fg%': '.241',
#   '3pfg%': '.174',
#   'rebounds': '0.8',
#   'assists': '0.2',
#   'steals': '0.2',
#   'blocks': '0.0',
#   'points_per_game': '2.1'},
#  {'name': 'Tim Frazier',
#   'team': 'DET',
#   'year': 2020,
#   'games_played': '27',
#   'mpg': '13.1',
#   'fg%': '.362',
#   '3pfg%': '.333',
#   'rebounds': '1.2',
#   'assists': '3.4',
#   'steals': '0.5',
#   'blocks': '0.1',
#   'points_per_game': '3.6'},
#  {'name': 'Markelle Fultz',
#   'team': 'ORL',
#   'year': 2020,
#   'games_played': '72',
#   'mpg': '27.7',
#   'fg%': '.465',
#   '3pfg%': '.267',
#   'rebounds': '3.3',
#   'assists': '5.1',
#   'steals': '1.3',
#   'blocks': '0.2',
#   'points_per_game': '12.1'},
#  {'name': 'Wenyen Gabriel',
#   'team': 'TOT',
#   'year': 2020,
#   'games_played': '30',
#   'mpg': '7.8',
#   'fg%': '.438',
#   '3pfg%': '.300',
#   'rebounds': '1.7',
#   'assists': '0.3',
#   'steals': '0.4',
#   'blocks': '0.2',
#   'points_per_game': '2.1'},
#  {'name': 'Daniel Gafford',
#   'team': 'CHI',
#   'year': 2020,
#   'games_played': '43',
#   'mpg': '14.2',
#   'fg%': '.701',
#   '3pfg%': '',
#   'rebounds': '2.5',
#   'assists': '0.5',
#   'steals': '0.3',
#   'blocks': '1.3',
#   'points_per_game': '5.1'},
#  {'name': 'Danilo Gallinari',
#   'team': 'OKC',
#   'year': 2020,
#   'games_played': '62',
#   'mpg': '29.6',
#   'fg%': '.438',
#   '3pfg%': '.405',
#   'rebounds': '5.2',
#   'assists': '1.9',
#   'steals': '0.7',
#   'blocks': '0.1',
#   'points_per_game': '18.7'},
#  {'name': 'Langston Galloway',
#   'team': 'DET',
#   'year': 2020,
#   'games_played': '66',
#   'mpg': '25.8',
#   'fg%': '.435',
#   '3pfg%': '.399',
#   'rebounds': '2.3',
#   'assists': '1.5',
#   'steals': '0.7',
#   'blocks': '0.2',
#   'points_per_game': '10.3'},
#  {'name': 'Darius Garland',
#   'team': 'CLE',
#   'year': 2020,
#   'games_played': '59',
#   'mpg': '30.9',
#   'fg%': '.401',
#   '3pfg%': '.355',
#   'rebounds': '1.9',
#   'assists': '3.9',
#   'steals': '0.7',
#   'blocks': '0.1',
#   'points_per_game': '12.3'},
#  {'name': 'Marc Gasol',
#   'team': 'TOR',
#   'year': 2020,
#   'games_played': '44',
#   'mpg': '26.4',
#   'fg%': '.427',
#   '3pfg%': '.385',
#   'rebounds': '6.3',
#   'assists': '3.3',
#   'steals': '0.8',
#   'blocks': '0.9',
#   'points_per_game': '7.5'},
#  {'name': 'Rudy Gay',
#   'team': 'SAS',
#   'year': 2020,
#   'games_played': '67',
#   'mpg': '21.8',
#   'fg%': '.446',
#   '3pfg%': '.336',
#   'rebounds': '5.4',
#   'assists': '1.7',
#   'steals': '0.5',
#   'blocks': '0.5',
#   'points_per_game': '10.8'},
#  {'name': 'Paul George',
#   'team': 'LAC',
#   'year': 2020,
#   'games_played': '48',
#   'mpg': '29.6',
#   'fg%': '.439',
#   '3pfg%': '.412',
#   'rebounds': '5.7',
#   'assists': '3.9',
#   'steals': '1.4',
#   'blocks': '0.4',
#   'points_per_game': '21.5'},
#  {'name': 'Taj Gibson',
#   'team': 'NYK',
#   'year': 2020,
#   'games_played': '62',
#   'mpg': '16.5',
#   'fg%': '.584',
#   '3pfg%': '.286',
#   'rebounds': '4.3',
#   'assists': '0.8',
#   'steals': '0.4',
#   'blocks': '0.5',
#   'points_per_game': '6.1'},
#  {'name': 'Harry Giles',
#   'team': 'SAC',
#   'year': 2020,
#   'games_played': '46',
#   'mpg': '14.5',
#   'fg%': '.554',
#   '3pfg%': '.000',
#   'rebounds': '4.1',
#   'assists': '1.3',
#   'steals': '0.5',
#   'blocks': '0.4',
#   'points_per_game': '6.9'},
#  {'name': 'Shai Gilgeous-Alexander',
#   'team': 'OKC',
#   'year': 2020,
#   'games_played': '70',
#   'mpg': '34.7',
#   'fg%': '.471',
#   '3pfg%': '.347',
#   'rebounds': '5.9',
#   'assists': '3.3',
#   'steals': '1.1',
#   'blocks': '0.7',
#   'points_per_game': '19.0'},
#  {'name': 'Rudy Gobert',
#   'team': 'UTA',
#   'year': 2020,
#   'games_played': '68',
#   'mpg': '34.3',
#   'fg%': '.693',
#   '3pfg%': '',
#   'rebounds': '13.5',
#   'assists': '1.5',
#   'steals': '0.8',
#   'blocks': '2.0',
#   'points_per_game': '15.1'},
#  {'name': 'Brandon Goodwin',
#   'team': 'ATL',
#   'year': 2020,
#   'games_played': '34',
#   'mpg': '12.6',
#   'fg%': '.400',
#   '3pfg%': '.299',
#   'rebounds': '2.1',
#   'assists': '1.5',
#   'steals': '0.4',
#   'blocks': '0.1',
#   'points_per_game': '6.1'},
#  {'name': 'Aaron Gordon',
#   'team': 'ORL',
#   'year': 2020,
#   'games_played': '62',
#   'mpg': '32.5',
#   'fg%': '.437',
#   '3pfg%': '.308',
#   'rebounds': '7.7',
#   'assists': '3.7',
#   'steals': '0.8',
#   'blocks': '0.6',
#   'points_per_game': '14.4'},
#  {'name': 'Eric Gordon',
#   'team': 'HOU',
#   'year': 2020,
#   'games_played': '36',
#   'mpg': '28.2',
#   'fg%': '.369',
#   '3pfg%': '.317',
#   'rebounds': '2.0',
#   'assists': '1.5',
#   'steals': '0.6',
#   'blocks': '0.4',
#   'points_per_game': '14.4'},
#  {'name': "Devonte' Graham",
#   'team': 'CHO',
#   'year': 2020,
#   'games_played': '63',
#   'mpg': '35.1',
#   'fg%': '.382',
#   '3pfg%': '.373',
#   'rebounds': '3.4',
#   'assists': '7.5',
#   'steals': '1.0',
#   'blocks': '0.2',
#   'points_per_game': '18.2'},
#  {'name': 'Treveon Graham',
#   'team': 'TOT',
#   'year': 2020,
#   'games_played': '55',
#   'mpg': '16.9',
#   'fg%': '.360',
#   '3pfg%': '.275',
#   'rebounds': '2.7',
#   'assists': '0.8',
#   'steals': '0.4',
#   'blocks': '0.1',
#   'points_per_game': '4.4'},
#  {'name': 'Jerami Grant',
#   'team': 'DEN',
#   'year': 2020,
#   'games_played': '71',
#   'mpg': '26.6',
#   'fg%': '.478',
#   '3pfg%': '.389',
#   'rebounds': '3.5',
#   'assists': '1.2',
#   'steals': '0.7',
#   'blocks': '0.8',
#   'points_per_game': '12.0'},
#  {'name': 'Jerian Grant',
#   'team': 'WAS',
#   'year': 2020,
#   'games_played': '6',
#   'mpg': '13.3',
#   'fg%': '.370',
#   '3pfg%': '.250',
#   'rebounds': '1.0',
#   'assists': '1.5',
#   'steals': '0.2',
#   'blocks': '0.2',
#   'points_per_game': '4.5'},
#  {'name': 'Josh Gray',
#   'team': 'NOP',
#   'year': 2020,
#   'games_played': '2',
#   'mpg': '11.5',
#   'fg%': '.500',
#   '3pfg%': '',
#   'rebounds': '1.0',
#   'assists': '1.0',
#   'steals': '0.0',
#   'blocks': '0.0',
#   'points_per_game': '1.0'},
#  {'name': 'Danny Green',
#   'team': 'LAL',
#   'year': 2020,
#   'games_played': '68',
#   'mpg': '24.8',
#   'fg%': '.416',
#   '3pfg%': '.367',
#   'rebounds': '3.3',
#   'assists': '1.3',
#   'steals': '1.3',
#   'blocks': '0.5',
#   'points_per_game': '8.0'},
#  {'name': 'Draymond Green',
#   'team': 'GSW',
#   'year': 2020,
#   'games_played': '43',
#   'mpg': '28.4',
#   'fg%': '.389',
#   '3pfg%': '.279',
#   'rebounds': '6.2',
#   'assists': '6.2',
#   'steals': '1.4',
#   'blocks': '0.8',
#   'points_per_game': '8.0'},
#  {'name': 'JaMychal Green',
#   'team': 'LAC',
#   'year': 2020,
#   'games_played': '63',
#   'mpg': '20.7',
#   'fg%': '.429',
#   '3pfg%': '.387',
#   'rebounds': '6.2',
#   'assists': '0.8',
#   'steals': '0.5',
#   'blocks': '0.4',
#   'points_per_game': '6.8'},
#  {'name': 'Javonte Green',
#   'team': 'BOS',
#   'year': 2020,
#   'games_played': '48',
#   'mpg': '9.8',
#   'fg%': '.500',
#   '3pfg%': '.273',
#   'rebounds': '1.9',
#   'assists': '0.5',
#   'steals': '0.5',
#   'blocks': '0.2',
#   'points_per_game': '3.4'},
#  {'name': 'Jeff Green',
#   'team': 'TOT',
#   'year': 2020,
#   'games_played': '48',
#   'mpg': '20.0',
#   'fg%': '.462',
#   '3pfg%': '.339',
#   'rebounds': '2.8',
#   'assists': '1.0',
#   'steals': '0.5',
#   'blocks': '0.4',
#   'points_per_game': '9.4'},
#  {'name': 'Blake Griffin',
#   'team': 'DET',
#   'year': 2020,
#   'games_played': '18',
#   'mpg': '28.4',
#   'fg%': '.352',
#   '3pfg%': '.243',
#   'rebounds': '4.7',
#   'assists': '3.3',
#   'steals': '0.4',
#   'blocks': '0.4',
#   'points_per_game': '15.5'},
#  {'name': 'Marko Guduric',
#   'team': 'MEM',
#   'year': 2020,
#   'games_played': '44',
#   'mpg': '11.0',
#   'fg%': '.395',
#   '3pfg%': '.301',
#   'rebounds': '1.7',
#   'assists': '1.0',
#   'steals': '0.3',
#   'blocks': '0.2',
#   'points_per_game': '3.9'},
#  {'name': 'Kyle Guy',
#   'team': 'SAC',
#   'year': 2020,
#   'games_played': '3',
#   'mpg': '3.3',
#   'fg%': '.400',
#   '3pfg%': '.000',
#   'rebounds': '0.3',
#   'assists': '0.3',
#   'steals': '0.0',
#   'blocks': '0.0',
#   'points_per_game': '1.3'},
#  {'name': 'Rui Hachimura',
#   'team': 'WAS',
#   'year': 2020,
#   'games_played': '48',
#   'mpg': '30.1',
#   'fg%': '.466',
#   '3pfg%': '.287',
#   'rebounds': '6.1',
#   'assists': '1.8',
#   'steals': '0.8',
#   'blocks': '0.2',
#   'points_per_game': '13.5'},
#  {'name': 'Devon Hall',
#   'team': 'OKC',
#   'year': 2020,
#   'games_played': '11',
#   'mpg': '7.4',
#   'fg%': '.200',
#   '3pfg%': '.235',
#   'rebounds': '0.6',
#   'assists': '1.2',
#   'steals': '0.4',
#   'blocks': '0.1',
#   'points_per_game': '1.8'},
#  {'name': 'Donta Hall',
#   'team': 'TOT',
#   'year': 2020,
#   'games_played': '9',
#   'mpg': '14.8',
#   'fg%': '.682',
#   '3pfg%': '',
#   'rebounds': '4.2',
#   'assists': '0.4',
#   'steals': '0.3',
#   'blocks': '0.7',
#   'points_per_game': '4.3'},
#  {'name': 'Dusty Hannahs',
#   'team': 'MEM',
#   'year': 2020,
#   'games_played': '2',
#   'mpg': '6.5',
#   'fg%': '.444',
#   '3pfg%': '.667',
#   'rebounds': '0.5',
#   'assists': '0.0',
#   'steals': '0.0',
#   'blocks': '0.0',
# ...
#   'steals': '0.4',
#   'blocks': '0.9',
#   'points_per_game': '5.5'},
#  {'name': 'Quincy Pondexter',
#   'team': 'SAS',
#   'year': 2019,
#   'games_played': '53',
#   'mpg': '5.5',
#   'fg%': '.500',
#   '3pfg%': '.333',
#   'rebounds': '0.9',
#   'assists': '0.5',
#   'steals': '0.2',
#   'blocks': '0.0',
#   'points_per_game': '1.8'},
#  {'name': 'Otto Porter',
#   'team': 'TOT',
#   'year': 2019,
#   'games_played': '56',
#   'mpg': '30.1',
#   'fg%': '.465',
#   '3pfg%': '.406',
#   'rebounds': '5.6',
#   'assists': '2.1',
#   'steals': '1.5',
#   'blocks': '0.6',
#   'points_per_game': '13.9'},
#  {'name': 'Bobby Portis',
#   'team': 'TOT',
#   'year': 2019,
#   'games_played': '50',
#   'mpg': '26.0',
#   'fg%': '.444',
#   '3pfg%': '.393',
#   'rebounds': '8.1',
#   'assists': '1.4',
#   'steals': '0.7',
#   'blocks': '0.4',
#   'points_per_game': '14.2'},
#  {'name': 'Dwight Powell',
#   'team': 'DAL',
#   'year': 2019,
#   'games_played': '77',
#   'mpg': '21.6',
#   'fg%': '.597',
#   '3pfg%': '.307',
#   'rebounds': '5.3',
#   'assists': '1.5',
#   'steals': '0.6',
#   'blocks': '0.6',
#   'points_per_game': '10.6'},
#  {'name': 'Norman Powell',
#   'team': 'TOR',
#   'year': 2019,
#   'games_played': '60',
#   'mpg': '18.8',
#   'fg%': '.483',
#   '3pfg%': '.400',
#   'rebounds': '2.3',
#   'assists': '1.5',
#   'steals': '0.7',
#   'blocks': '0.2',
#   'points_per_game': '8.6'},
#  {'name': 'Alex Poythress',
#   'team': 'ATL',
#   'year': 2019,
#   'games_played': '21',
#   'mpg': '14.5',
#   'fg%': '.494',
#   '3pfg%': '.391',
#   'rebounds': '3.6',
#   'assists': '0.8',
#   'steals': '0.2',
#   'blocks': '0.5',
#   'points_per_game': '5.1'},
#  {'name': 'Taurean Prince',
#   'team': 'ATL',
#   'year': 2019,
#   'games_played': '55',
#   'mpg': '28.2',
#   'fg%': '.441',
#   '3pfg%': '.390',
#   'rebounds': '3.6',
#   'assists': '2.1',
#   'steals': '1.0',
#   'blocks': '0.3',
#   'points_per_game': '13.5'},
#  {'name': 'Zhou Qi',
#   'team': 'HOU',
#   'year': 2019,
#   'games_played': '1',
#   'mpg': '1.0',
#   'fg%': '1.000',
#   '3pfg%': '',
#   'rebounds': '0.0',
#   'assists': '0.0',
#   'steals': '0.0',
#   'blocks': '0.0',
#   'points_per_game': '2.0'},
#  {'name': 'Ivan Rabb',
#   'team': 'MEM',
#   'year': 2019,
#   'games_played': '49',
#   'mpg': '14.7',
#   'fg%': '.547',
#   '3pfg%': '.200',
#   'rebounds': '4.2',
#   'assists': '1.1',
#   'steals': '0.3',
#   'blocks': '0.3',
#   'points_per_game': '5.8'},
#  {'name': 'Chasson Randle',
#   'team': 'WAS',
#   'year': 2019,
#   'games_played': '49',
#   'mpg': '15.2',
#   'fg%': '.419',
#   '3pfg%': '.400',
#   'rebounds': '1.1',
#   'assists': '2.0',
#   'steals': '0.5',
#   'blocks': '0.1',
#   'points_per_game': '5.5'},
#  {'name': 'Julius Randle',
#   'team': 'NOP',
#   'year': 2019,
#   'games_played': '73',
#   'mpg': '30.6',
#   'fg%': '.524',
#   '3pfg%': '.344',
#   'rebounds': '8.7',
#   'assists': '3.1',
#   'steals': '0.7',
#   'blocks': '0.6',
#   'points_per_game': '21.4'},
#  {'name': 'J.J. Redick',
#   'team': 'PHI',
#   'year': 2019,
#   'games_played': '76',
#   'mpg': '31.3',
#   'fg%': '.440',
#   '3pfg%': '.397',
#   'rebounds': '2.4',
#   'assists': '2.7',
#   'steals': '0.4',
#   'blocks': '0.2',
#   'points_per_game': '18.1'},
#  {'name': 'Davon Reed',
#   'team': 'IND',
#   'year': 2019,
#   'games_played': '10',
#   'mpg': '4.7',
#   'fg%': '.417',
#   '3pfg%': '.500',
#   'rebounds': '0.6',
#   'assists': '0.3',
#   'steals': '0.1',
#   'blocks': '0.0',
#   'points_per_game': '1.2'},
#  {'name': 'Cameron Reynolds',
#   'team': 'MIN',
#   'year': 2019,
#   'games_played': '19',
#   'mpg': '13.6',
#   'fg%': '.423',
#   '3pfg%': '.412',
#   'rebounds': '1.6',
#   'assists': '0.7',
#   'steals': '0.3',
#   'blocks': '0.1',
#   'points_per_game': '5.0'},
#  {'name': 'Josh Richardson',
#   'team': 'MIA',
#   'year': 2019,
#   'games_played': '73',
#   'mpg': '34.8',
#   'fg%': '.412',
#   '3pfg%': '.357',
#   'rebounds': '3.6',
#   'assists': '4.1',
#   'steals': '1.1',
#   'blocks': '0.5',
#   'points_per_game': '16.6'},
#  {'name': 'Malachi Richardson',
#   'team': 'TOR',
#   'year': 2019,
#   'games_played': '22',
#   'mpg': '4.7',
#   'fg%': '.310',
#   '3pfg%': '.320',
#   'rebounds': '0.6',
#   'assists': '0.0',
#   'steals': '0.0',
#   'blocks': '0.0',
#   'points_per_game': '1.4'},
#  {'name': 'Austin Rivers',
#   'team': 'TOT',
#   'year': 2019,
#   'games_played': '76',
#   'mpg': '26.7',
#   'fg%': '.406',
#   '3pfg%': '.318',
#   'rebounds': '2.1',
#   'assists': '2.2',
#   'steals': '0.6',
#   'blocks': '0.3',
#   'points_per_game': '8.1'},
#  {'name': 'Devin Robinson',
#   'team': 'WAS',
#   'year': 2019,
#   'games_played': '7',
#   'mpg': '13.6',
#   'fg%': '.594',
#   '3pfg%': '.000',
#   'rebounds': '2.9',
#   'assists': '0.9',
#   'steals': '0.6',
#   'blocks': '0.9',
#   'points_per_game': '6.7'},
#  {'name': 'Duncan Robinson',
#   'team': 'MIA',
#   'year': 2019,
#   'games_played': '15',
#   'mpg': '10.7',
#   'fg%': '.391',
#   '3pfg%': '.286',
#   'rebounds': '1.3',
#   'assists': '0.3',
#   'steals': '0.3',
#   'blocks': '0.0',
#   'points_per_game': '3.3'},
#  {'name': 'Glenn Robinson III',
#   'team': 'DET',
#   'year': 2019,
#   'games_played': '47',
#   'mpg': '13.0',
#   'fg%': '.420',
#   '3pfg%': '.290',
#   'rebounds': '1.5',
#   'assists': '0.4',
#   'steals': '0.3',
#   'blocks': '0.2',
#   'points_per_game': '4.2'},
#  {'name': 'Jerome Robinson',
#   'team': 'LAC',
#   'year': 2019,
#   'games_played': '33',
#   'mpg': '9.7',
#   'fg%': '.400',
#   '3pfg%': '.316',
#   'rebounds': '1.2',
#   'assists': '0.6',
#   'steals': '0.3',
#   'blocks': '0.1',
#   'points_per_game': '3.4'},
#  {'name': 'Mitchell Robinson',
#   'team': 'NYK',
#   'year': 2019,
#   'games_played': '66',
#   'mpg': '20.6',
#   'fg%': '.694',
#   '3pfg%': '',
#   'rebounds': '6.4',
#   'assists': '0.6',
#   'steals': '0.8',
#   'blocks': '2.4',
#   'points_per_game': '7.3'},
#  {'name': 'Rajon Rondo',
#   'team': 'LAL',
#   'year': 2019,
#   'games_played': '46',
#   'mpg': '29.8',
#   'fg%': '.405',
#   '3pfg%': '.359',
#   'rebounds': '5.3',
#   'assists': '8.0',
#   'steals': '1.2',
#   'blocks': '0.2',
#   'points_per_game': '9.2'},
#  {'name': 'Derrick Rose',
#   'team': 'MIN',
#   'year': 2019,
#   'games_played': '51',
#   'mpg': '27.3',
#   'fg%': '.482',
#   '3pfg%': '.370',
#   'rebounds': '2.7',
#   'assists': '4.3',
#   'steals': '0.6',
#   'blocks': '0.2',
#   'points_per_game': '18.0'},
#  {'name': 'Terrence Ross',
#   'team': 'ORL',
#   'year': 2019,
#   'games_played': '81',
#   'mpg': '26.5',
#   'fg%': '.428',
#   '3pfg%': '.383',
#   'rebounds': '3.5',
#   'assists': '1.7',
#   'steals': '0.9',
#   'blocks': '0.4',
#   'points_per_game': '15.1'},
#  {'name': 'Terry Rozier',
#   'team': 'BOS',
#   'year': 2019,
#   'games_played': '79',
#   'mpg': '22.7',
#   'fg%': '.387',
#   '3pfg%': '.353',
#   'rebounds': '3.9',
#   'assists': '2.9',
#   'steals': '0.9',
#   'blocks': '0.3',
#   'points_per_game': '9.0'},
#  {'name': 'Ricky Rubio',
#   'team': 'UTA',
#   'year': 2019,
#   'games_played': '68',
#   'mpg': '27.9',
#   'fg%': '.404',
#   '3pfg%': '.311',
#   'rebounds': '3.6',
#   'assists': '6.1',
#   'steals': '1.3',
#   'blocks': '0.1',
#   'points_per_game': '12.7'},
#  {'name': "D'Angelo Russell",
#   'team': 'BRK',
#   'year': 2019,
#   'games_played': '81',
#   'mpg': '30.2',
#   'fg%': '.434',
#   '3pfg%': '.369',
#   'rebounds': '3.9',
#   'assists': '7.0',
#   'steals': '1.2',
#   'blocks': '0.2',
#   'points_per_game': '21.1'},
#  {'name': 'Domantas Sabonis',
#   'team': 'IND',
#   'year': 2019,
#   'games_played': '74',
#   'mpg': '24.8',
#   'fg%': '.590',
#   '3pfg%': '.529',
#   'rebounds': '9.3',
#   'assists': '2.9',
#   'steals': '0.6',
#   'blocks': '0.4',
#   'points_per_game': '14.1'},
#  {'name': 'Brandon Sampson',
#   'team': 'CHI',
#   'year': 2019,
#   'games_played': '14',
#   'mpg': '15.3',
#   'fg%': '.467',
#   '3pfg%': '.379',
#   'rebounds': '1.1',
#   'assists': '0.7',
#   'steals': '0.6',
#   'blocks': '0.2',
#   'points_per_game': '5.1'},
#  {'name': 'JaKarr Sampson',
#   'team': 'CHI',
#   'year': 2019,
#   'games_played': '4',
#   'mpg': '31.8',
#   'fg%': '.537',
#   '3pfg%': '.357',
#   'rebounds': '8.0',
#   'assists': '1.0',
#   'steals': '1.0',
#   'blocks': '0.8',
#   'points_per_game': '20.0'},
#  {'name': 'Dario Šarić',
#   'team': 'TOT',
#   'year': 2019,
#   'games_played': '81',
#   'mpg': '25.0',
#   'fg%': '.437',
#   '3pfg%': '.365',
#   'rebounds': '5.6',
#   'assists': '1.6',
#   'steals': '0.6',
#   'blocks': '0.1',
#   'points_per_game': '10.6'},
#  {'name': 'Tomáš Satoranský',
#   'team': 'WAS',
#   'year': 2019,
#   'games_played': '80',
#   'mpg': '27.1',
#   'fg%': '.485',
#   '3pfg%': '.395',
#   'rebounds': '3.5',
#   'assists': '5.0',
#   'steals': '1.0',
#   'blocks': '0.2',
#   'points_per_game': '8.9'},
#  {'name': 'Dennis Schröder',
#   'team': 'OKC',
#   'year': 2019,
#   'games_played': '79',
#   'mpg': '29.3',
#   'fg%': '.414',
#   '3pfg%': '.341',
#   'rebounds': '3.6',
#   'assists': '4.1',
#   'steals': '0.8',
#   'blocks': '0.2',
#   'points_per_game': '15.5'},
#  {'name': 'Mike Scott',
#   'team': 'TOT',
#   'year': 2019,
#   'games_played': '79',
#   'mpg': '17.7',
#   'fg%': '.400',
#   '3pfg%': '.401',
#   'rebounds': '3.5',
#   'assists': '0.8',
#   'steals': '0.3',
#   'blocks': '0.2',
#   'points_per_game': '5.8'},
#  {'name': 'Thabo Sefolosha',
#   'team': 'UTA',
#   'year': 2019,
#   'games_played': '50',
#   'mpg': '12.2',
#   'fg%': '.477',
#   '3pfg%': '.436',
#   'rebounds': '2.5',
#   'assists': '0.5',
#   'steals': '0.9',
#   'blocks': '0.1',
#   'points_per_game': '3.8'},
#  {'name': 'Wayne Selden',
#   'team': 'TOT',
#   'year': 2019,
#   'games_played': '75',
#   'mpg': '19.2',
#   'fg%': '.406',
#   '3pfg%': '.316',
#   'rebounds': '2.4',
#   'assists': '1.5',
#   'steals': '0.4',
#   'blocks': '0.2',
#   'points_per_game': '6.9'},
#  {'name': 'Collin Sexton',
#   'team': 'CLE',
#   'year': 2019,
#   'games_played': '82',
#   'mpg': '31.8',
#   'fg%': '.430',
#   '3pfg%': '.402',
#   'rebounds': '2.9',
#   'assists': '3.0',
#   'steals': '0.5',
#   'blocks': '0.1',
#   'points_per_game': '16.7'},
#  {'name': 'Landry Shamet',
#   'team': 'TOT',
#   'year': 2019,
#   'games_played': '79',
#   'mpg': '22.8',
#   'fg%': '.431',
#   '3pfg%': '.422',
#   'rebounds': '1.7',
#   'assists': '1.5',
#   'steals': '0.5',
#   'blocks': '0.1',
#   'points_per_game': '9.1'},
#  {'name': 'Iman Shumpert',
#   'team': 'TOT',
#   'year': 2019,
#   'games_played': '62',
#   'mpg': '23.9',
#   'fg%': '.374',
#   '3pfg%': '.348',
#   'rebounds': '3.0',
#   'assists': '1.8',
#   'steals': '1.0',
#   'blocks': '0.4',
#   'points_per_game': '7.5'},
#  {'name': 'Pascal Siakam',
#   'team': 'TOR',
#   'year': 2019,
#   'games_played': '80',
#   'mpg': '31.9',
#   'fg%': '.549',
#   '3pfg%': '.369',
#   'rebounds': '6.9',
#   'assists': '3.1',
#   'steals': '0.9',
#   'blocks': '0.7',
#   'points_per_game': '16.9'},
#  {'name': 'Jordan Sibert',
#   'team': 'ATL',
#   'year': 2019,
#   'games_played': '1',
#   'mpg': '4.0',
#   'fg%': '1.000',
#   '3pfg%': '1.000',
#   'rebounds': '0.0',
#   'assists': '0.0',
#   'steals': '0.0',
#   'blocks': '0.0',
#   'points_per_game': '3.0'},
#  {'name': 'Ben Simmons',
#   'team': 'PHI',
#   'year': 2019,
#   'games_played': '79',
#   'mpg': '34.2',
#   'fg%': '.563',
#   '3pfg%': '.000',
#   'rebounds': '8.8',
#   'assists': '7.7',
#   'steals': '1.4',
#   'blocks': '0.8',
#   'points_per_game': '16.9'},
#  {'name': 'Jonathon Simmons',
#   'team': 'TOT',
#   'year': 2019,
#   'games_played': '56',
#   'mpg': '19.0',
#   'fg%': '.380',
#   '3pfg%': '.269',
#   'rebounds': '2.3',
#   'assists': '2.3',
#   'steals': '0.5',
#   'blocks': '0.3',
#   'points_per_game': '6.5'},
#  {'name': 'Kobi Simmons',
#   'team': 'CLE',
#   'year': 2019,
#   'games_played': '1',
#   'mpg': '2.0',
#   'fg%': '',
#   '3pfg%': '',
#   'rebounds': '0.0',
#   'assists': '0.0',
#   'steals': '0.0',
#   'blocks': '0.0',
#   'points_per_game': '0.0'},
#  {'name': 'Anfernee Simons',
#   'team': 'POR',
#   'year': 2019,
#   'games_played': '20',
#   'mpg': '7.1',
#   'fg%': '.444',
#   '3pfg%': '.345',
#   'rebounds': '0.7',
#   'assists': '0.7',
#   'steals': '0.1',
#   'blocks': '0.0',
#   'points_per_game': '3.8'},
#  {'name': 'Marcus Smart',
#   'team': 'BOS',
#   'year': 2019,
#   'games_played': '80',
#   'mpg': '27.5',
#   'fg%': '.422',
#   '3pfg%': '.364',
#   'rebounds': '2.9',
#   'assists': '4.0',
#   'steals': '1.8',
#   'blocks': '0.4',
#   'points_per_game': '8.9'},
#  {'name': 'Dennis Smith Jr.',
#   'team': 'TOT',
#   'year': 2019,
#   'games_played': '53',
#   'mpg': '28.5',
#   'fg%': '.428',
#   '3pfg%': '.322',
#   'rebounds': '2.9',
#   'assists': '4.8',
#   'steals': '1.3',
#   'blocks': '0.4',
#   'points_per_game': '13.6'},
#  {'name': 'Ish Smith',
#   'team': 'DET',
#   'year': 2019,
#   'games_played': '56',
#   'mpg': '22.3',
#   'fg%': '.419',
#   '3pfg%': '.326',
#   'rebounds': '2.6',
#   'assists': '3.6',
#   'steals': '0.5',
#   'blocks': '0.2',
#   'points_per_game': '8.9'},
#  {'name': 'J.R. Smith',
#   'team': 'CLE',
#   'year': 2019,
#   'games_played': '11',
#   'mpg': '20.2',
#   'fg%': '.342',
#   '3pfg%': '.308',
#   'rebounds': '1.6',
#   'assists': '1.9',
#   'steals': '1.0',
#   'blocks': '0.3',
#   'points_per_game': '6.7'},
#  {'name': 'Jason Smith',
#   'team': 'TOT',
#   'year': 2019,
#   'games_played': '20',
#   'mpg': '9.5',
#   'fg%': '.356',
#   '3pfg%': '.346',
#   'rebounds': '2.6',
#   'assists': '0.7',
#   'steals': '0.2',
#   'blocks': '0.4',
#   'points_per_game': '3.3'},
#  {'name': 'Zhaire Smith',
#   'team': 'PHI',
#   'year': 2019,
#   'games_played': '6',
#   'mpg': '18.5',
#   'fg%': '.412',
#   '3pfg%': '.375',
#   'rebounds': '2.2',
#   'assists': '1.7',
#   'steals': '0.3',
#   'blocks': '0.3',
#   'points_per_game': '6.7'},
#  {'name': 'Tony Snell',
#   'team': 'MIL',
#   'year': 2019,
#   'games_played': '74',
#   'mpg': '17.6',
#   'fg%': '.452',
#   '3pfg%': '.397',
#   'rebounds': '2.1',
#   'assists': '0.9',
#   'steals': '0.4',
#   'blocks': '0.2',
#   'points_per_game': '6.0'},
#  {'name': 'Ray Spalding',
#   'team': 'TOT',
#   'year': 2019,
#   'games_played': '14',
#   'mpg': '10.6',
#   'fg%': '.532',
#   '3pfg%': '.000',
#   'rebounds': '3.4',
#   'assists': '0.4',
#   'steals': '0.6',
#   'blocks': '0.6',
#   'points_per_game': '3.9'},
#  {'name': 'Omari Spellman',
#   'team': 'ATL',
#   'year': 2019,
#   'games_played': '46',
#   'mpg': '17.5',
#   'fg%': '.402',
#   '3pfg%': '.344',
#   'rebounds': '4.2',
#   'assists': '1.0',
#   'steals': '0.6',
#   'blocks': '0.5',
#   'points_per_game': '5.9'},
#  {'name': 'Nik Stauskas',
#   'team': 'TOT',
#   'year': 2019,
#   'games_played': '68',
#   'mpg': '14.9',
#   'fg%': '.402',
#   '3pfg%': '.372',
#   'rebounds': '1.9',
#   'assists': '1.2',
#   'steals': '0.3',
#   'blocks': '0.1',
#   'points_per_game': '5.9'},
#  {'name': 'D.J. Stephens',
#   'team': 'MEM',
#   'year': 2019,
#   'games_played': '1',
#   'mpg': '7.0',
#   'fg%': '.500',
#   '3pfg%': '',
#   'rebounds': '0.0',
#   'assists': '0.0',
#   'steals': '1.0',
#   'blocks': '0.0',
#   'points_per_game': '2.0'},
#  {'name': 'Lance Stephenson',
#   'team': 'LAL',
#   'year': 2019,
#   'games_played': '68',
#   'mpg': '16.5',
#   'fg%': '.426',
#   '3pfg%': '.371',
#   'rebounds': '3.2',
#   'assists': '2.1',
#   'steals': '0.6',
#   'blocks': '0.1',
#   'points_per_game': '7.2'},
#  {'name': 'Edmond Sumner',
#   'team': 'IND',
#   'year': 2019,
#   'games_played': '23',
#   'mpg': '9.1',
#   'fg%': '.344',
#   '3pfg%': '.259',
#   'rebounds': '1.0',
#   'assists': '0.4',
#   'steals': '0.5',
#   'blocks': '0.2',
#   'points_per_game': '2.9'},
#  {'name': 'Caleb Swanigan',
#   'team': 'TOT',
#   'year': 2019,
#   'games_played': '21',
#   'mpg': '8.5',
#   'fg%': '.340',
#   '3pfg%': '.143',
#   'rebounds': '3.0',
#   'assists': '0.5',
#   'steals': '0.3',
#   'blocks': '0.0',
#   'points_per_game': '2.0'},
#  {'name': 'Jayson Tatum',
#   'team': 'BOS',
#   'year': 2019,
#   'games_played': '79',
#   'mpg': '31.1',
#   'fg%': '.450',
#   '3pfg%': '.373',
#   'rebounds': '6.0',
#   'assists': '2.1',
#   'steals': '1.1',
#   'blocks': '0.7',
#   'points_per_game': '15.7'},
#  {'name': 'Jeff Teague',
#   'team': 'MIN',
#   'year': 2019,
#   'games_played': '42',
#   'mpg': '30.1',
#   'fg%': '.423',
#   '3pfg%': '.333',
#   'rebounds': '2.5',
#   'assists': '8.2',
#   'steals': '1.0',
#   'blocks': '0.4',
#   'points_per_game': '12.1'},
#  {'name': 'Garrett Temple',
#   'team': 'TOT',
#   'year': 2019,
#   'games_played': '75',
#   'mpg': '27.2',
#   'fg%': '.422',
#   '3pfg%': '.341',
#   'rebounds': '2.9',
#   'assists': '1.4',
#   'steals': '1.0',
#   'blocks': '0.4',
#   'points_per_game': '7.8'},
#  {'name': 'Miloš Teodosić',
#   'team': 'LAC',
#   'year': 2019,
#   'games_played': '15',
#   'mpg': '10.0',
#   'fg%': '.425',
#   '3pfg%': '.370',
#   'rebounds': '1.1',
#   'assists': '2.1',
#   'steals': '0.2',
#   'blocks': '0.1',
#   'points_per_game': '3.2'},
#  {'name': 'Jared Terrell',
#   'team': 'MIN',
#   'year': 2019,
#   'games_played': '14',
#   'mpg': '7.9',
#   'fg%': '.308',
#   '3pfg%': '.235',
#   'rebounds': '0.4',
#   'assists': '0.9',
#   'steals': '0.2',
#   'blocks': '0.1',
#   'points_per_game': '2.2'},
#  ...]

# %% [markdown]
# Since we will want to use this scrape for modeling, it's a good idea to save it to a pandas df and then save it to a csv for further usage in our modeling notebook:

# %%
df_basic = pd.DataFrame(players)
df_basic
# Out:
#                            name team  year games_played   mpg   fg% 3pfg%  \
# 0                  Steven Adams  OKC  2020           63  26.7  .592  .333
# 1                   Bam Adebayo  MIA  2020           72  33.6  .557  .143
# 2             LaMarcus Aldridge  SAS  2020           53  33.1  .493  .389
# 3                Kyle Alexander  MIA  2020            2   6.5  .500
# 4      Nickeil Alexander-Walker  NOP  2020           47  12.6  .368  .346
# ...                         ...  ...   ...          ...   ...   ...   ...
# 13940         Orlando Woolridge  LAL  1990           62  22.9  .556  .000
# 13941          Haywoode Workman  ATL  1990            6   2.7  .667
# 13942             James Worthy*  LAL  1990           80  37.0  .548  .306
# 13943               Danny Young  POR  1990           82  17.0  .421  .271
# 13944             Michael Young  LAC  1990           45  10.2  .474  .308
#
#       rebounds assists steals blocks points_per_game
# 0          9.3     2.3    0.8    1.1            10.9
# 1         10.2     5.1    1.1    1.3            15.9
# 2          7.4     2.4    0.7    1.6            18.9
# 3          1.5     0.0    0.0    0.0             1.0
# 4          1.8     1.9    0.4    0.2             5.7
# ...        ...     ...    ...    ...             ...
# 13940      3.0     1.5    0.6    0.7            12.7
# 13941      0.5     0.3    0.5    0.0             1.0
# 13942      6.0     3.6    1.2    0.6            21.1
# 13943      1.5     2.8    1.0    0.0             4.7
# 13944      1.9     0.5    0.6    0.1             4.9
#
# [13945 rows x 12 columns]

# %% [markdown]
# Performing same basic stats scrape for the players for this current (2021). These are the players we will be analyzing and using our models to predict if they are having a "playoff caliber" season.

# %%
#2021 basic
players_2021_basic = []
year = 2021
url = f'https://www.basketball-reference.com/leagues/NBA_{year}_per_game.html'
res = requests.get(url)
soup = BeautifulSoup(res.content, 'lxml')
table = soup.find('table', {'id': 'per_game_stats'})
for row in table.find('tbody').find_all('tr', {'class':'full_table'}):
    player = {}
    player['name'] = row.find('td', {'data-stat': 'player'}).text
    player['team'] = row.find('td', {'data-stat': 'team_id'}).text
    player['year'] = year
    player['games_played'] = row.find('td', {'data-stat': 'g'}).text
    player['mpg'] = row.find('td', {'data-stat': 'mp_per_g'}).text
    player['fg%'] = row.find('td', {'data-stat': 'fg_pct'}).text
    player['3pfg%'] = row.find('td', {'data-stat': 'fg3_pct'}).text
    player['rebounds'] = row.find('td', {'data-stat': 'trb_per_g'}).text
    player['assists'] = row.find('td', {'data-stat': 'ast_per_g'}).text
    player['steals'] = row.find('td', {'data-stat': 'stl_per_g'}).text
    player['blocks'] = row.find('td', {'data-stat': 'blk_per_g'}).text
    player['points_per_game'] = row.find('td', {'data-stat': 'pts_per_g'}).text
    players_2021_basic.append(player)

time.sleep(5)        
players_2021_basic
# Out:
# [{'name': 'Precious Achiuwa',
#   'team': 'MIA',
#   'year': 2021,
#   'games_played': '35',
#   'mpg': '14.0',
#   'fg%': '.579',
#   '3pfg%': '',
#   'rebounds': '4.0',
#   'assists': '0.6',
#   'steals': '0.4',
#   'blocks': '0.5',
#   'points_per_game': '6.1'},
#  {'name': 'Jaylen Adams',
#   'team': 'MIL',
#   'year': 2021,
#   'games_played': '7',
#   'mpg': '2.6',
#   'fg%': '.125',
#   '3pfg%': '.000',
#   'rebounds': '0.4',
#   'assists': '0.3',
#   'steals': '0.0',
#   'blocks': '0.0',
#   'points_per_game': '0.3'},
#  {'name': 'Steven Adams',
#   'team': 'NOP',
#   'year': 2021,
#   'games_played': '33',
#   'mpg': '27.8',
#   'fg%': '.615',
#   '3pfg%': '.000',
#   'rebounds': '8.9',
#   'assists': '2.1',
#   'steals': '0.9',
#   'blocks': '0.6',
#   'points_per_game': '8.0'},
#  {'name': 'Bam Adebayo',
#   'team': 'MIA',
#   'year': 2021,
#   'games_played': '33',
#   'mpg': '33.9',
#   'fg%': '.563',
#   '3pfg%': '.333',
#   'rebounds': '9.5',
#   'assists': '5.4',
#   'steals': '0.9',
#   'blocks': '1.0',
#   'points_per_game': '19.2'},
#  {'name': 'LaMarcus Aldridge',
#   'team': 'SAS',
#   'year': 2021,
#   'games_played': '21',
#   'mpg': '25.9',
#   'fg%': '.464',
#   '3pfg%': '.360',
#   'rebounds': '4.5',
#   'assists': '1.7',
#   'steals': '0.4',
#   'blocks': '0.9',
#   'points_per_game': '13.7'},
#  {'name': 'Ty-Shon Alexander',
#   'team': 'PHO',
#   'year': 2021,
#   'games_played': '3',
#   'mpg': '2.7',
#   'fg%': '.000',
#   '3pfg%': '.000',
#   'rebounds': '0.3',
#   'assists': '0.3',
#   'steals': '0.0',
#   'blocks': '0.0',
#   'points_per_game': '0.0'},
#  {'name': 'Nickeil Alexander-Walker',
#   'team': 'NOP',
#   'year': 2021,
#   'games_played': '28',
#   'mpg': '17.7',
#   'fg%': '.408',
#   '3pfg%': '.306',
#   'rebounds': '2.4',
#   'assists': '1.9',
#   'steals': '1.0',
#   'blocks': '0.3',
#   'points_per_game': '8.2'},
#  {'name': 'Grayson Allen',
#   'team': 'MEM',
#   'year': 2021,
#   'games_played': '23',
#   'mpg': '24.0',
#   'fg%': '.409',
#   '3pfg%': '.407',
#   'rebounds': '2.8',
#   'assists': '2.2',
#   'steals': '1.0',
#   'blocks': '0.1',
#   'points_per_game': '9.3'},
#  {'name': 'Jarrett Allen',
#   'team': 'TOT',
#   'year': 2021,
#   'games_played': '35',
#   'mpg': '27.9',
#   'fg%': '.669',
#   '3pfg%': '.500',
#   'rebounds': '9.9',
#   'assists': '1.7',
#   'steals': '0.5',
#   'blocks': '1.7',
#   'points_per_game': '13.5'},
#  {'name': 'Al-Farouq Aminu',
#   'team': 'ORL',
#   'year': 2021,
#   'games_played': '9',
#   'mpg': '18.1',
#   'fg%': '.395',
#   '3pfg%': '.400',
#   'rebounds': '4.1',
#   'assists': '1.7',
#   'steals': '0.9',
#   'blocks': '0.6',
#   'points_per_game': '5.2'},
#  {'name': 'Kyle Anderson',
#   'team': 'MEM',
#   'year': 2021,
#   'games_played': '31',
#   'mpg': '27.5',
#   'fg%': '.476',
#   '3pfg%': '.376',
#   'rebounds': '6.1',
#   'assists': '3.5',
#   'steals': '1.2',
#   'blocks': '0.7',
#   'points_per_game': '13.4'},
#  {'name': 'Giannis Antetokounmpo',
#   'team': 'MIL',
#   'year': 2021,
#   'games_played': '35',
#   'mpg': '34.0',
#   'fg%': '.557',
#   '3pfg%': '.285',
#   'rebounds': '11.7',
#   'assists': '5.9',
#   'steals': '1.3',
#   'blocks': '1.4',
#   'points_per_game': '29.0'},
#  {'name': 'Kostas Antetokounmpo',
#   'team': 'LAL',
#   'year': 2021,
#   'games_played': '3',
#   'mpg': '6.3',
#   'fg%': '.333',
#   '3pfg%': '',
#   'rebounds': '2.7',
#   'assists': '0.0',
#   'steals': '0.3',
#   'blocks': '0.7',
#   'points_per_game': '1.0'},
#  {'name': 'Thanasis Antetokounmpo',
#   'team': 'MIL',
#   'year': 2021,
#   'games_played': '26',
#   'mpg': '8.7',
#   'fg%': '.605',
#   '3pfg%': '.222',
#   'rebounds': '2.1',
#   'assists': '0.7',
#   'steals': '0.3',
#   'blocks': '0.2',
#   'points_per_game': '2.3'},
#  {'name': 'Carmelo Anthony',
#   'team': 'POR',
#   'year': 2021,
#   'games_played': '34',
#   'mpg': '25.6',
#   'fg%': '.413',
#   '3pfg%': '.387',
#   'rebounds': '3.3',
#   'assists': '1.5',
#   'steals': '0.9',
#   'blocks': '0.8',
#   'points_per_game': '13.9'},
#  {'name': 'Cole Anthony',
#   'team': 'ORL',
#   'year': 2021,
#   'games_played': '25',
#   'mpg': '26.7',
#   'fg%': '.375',
#   '3pfg%': '.325',
#   'rebounds': '4.4',
#   'assists': '3.8',
#   'steals': '0.7',
#   'blocks': '0.4',
#   'points_per_game': '11.0'},
#  {'name': 'OG Anunoby',
#   'team': 'TOR',
#   'year': 2021,
#   'games_played': '23',
#   'mpg': '33.4',
#   'fg%': '.479',
#   '3pfg%': '.395',
#   'rebounds': '5.7',
#   'assists': '1.7',
#   'steals': '1.6',
#   'blocks': '0.7',
#   'points_per_game': '13.8'},
#  {'name': 'Ryan Arcidiacono',
#   'team': 'CHI',
#   'year': 2021,
#   'games_played': '18',
#   'mpg': '11.0',
#   'fg%': '.420',
#   '3pfg%': '.344',
#   'rebounds': '1.8',
#   'assists': '1.3',
#   'steals': '0.3',
#   'blocks': '0.0',
#   'points_per_game': '3.4'},
#  {'name': 'D.J. Augustin',
#   'team': 'MIL',
#   'year': 2021,
#   'games_played': '34',
#   'mpg': '19.5',
#   'fg%': '.350',
#   '3pfg%': '.366',
#   'rebounds': '1.4',
#   'assists': '3.0',
#   'steals': '0.6',
#   'blocks': '0.0',
#   'points_per_game': '6.1'},
#  {'name': 'Deni Avdija',
#   'team': 'WAS',
#   'year': 2021,
#   'games_played': '31',
#   'mpg': '21.6',
#   'fg%': '.442',
#   '3pfg%': '.370',
#   'rebounds': '4.7',
#   'assists': '1.3',
#   'steals': '0.7',
#   'blocks': '0.2',
#   'points_per_game': '6.2'},
#  {'name': 'Deandre Ayton',
#   'team': 'PHO',
#   'year': 2021,
#   'games_played': '35',
#   'mpg': '31.1',
#   'fg%': '.594',
#   '3pfg%': '.235',
#   'rebounds': '11.4',
#   'assists': '1.7',
#   'steals': '0.3',
#   'blocks': '1.1',
#   'points_per_game': '14.5'},
#  {'name': 'Udoka Azubuike',
#   'team': 'UTA',
#   'year': 2021,
#   'games_played': '12',
#   'mpg': '4.1',
#   'fg%': '.571',
#   '3pfg%': '',
#   'rebounds': '1.1',
#   'assists': '0.0',
#   'steals': '0.1',
#   'blocks': '0.3',
#   'points_per_game': '1.0'},
#  {'name': 'Dwayne Bacon',
#   'team': 'ORL',
#   'year': 2021,
#   'games_played': '36',
#   'mpg': '24.6',
#   'fg%': '.413',
#   '3pfg%': '.333',
#   'rebounds': '2.9',
#   'assists': '1.0',
#   'steals': '0.6',
#   'blocks': '0.1',
#   'points_per_game': '10.1'},
#  {'name': 'Marvin Bagley III',
#   'team': 'SAC',
#   'year': 2021,
#   'games_played': '34',
#   'mpg': '26.1',
#   'fg%': '.500',
#   '3pfg%': '.370',
#   'rebounds': '7.6',
#   'assists': '1.0',
#   'steals': '0.5',
#   'blocks': '0.5',
#   'points_per_game': '14.1'},
#  {'name': 'LaMelo Ball',
#   'team': 'CHO',
#   'year': 2021,
#   'games_played': '35',
#   'mpg': '28.9',
#   'fg%': '.449',
#   '3pfg%': '.378',
#   'rebounds': '6.0',
#   'assists': '6.3',
#   'steals': '1.6',
#   'blocks': '0.4',
#   'points_per_game': '15.8'},
#  {'name': 'Lonzo Ball',
#   'team': 'NOP',
#   'year': 2021,
#   'games_played': '33',
#   'mpg': '31.8',
#   'fg%': '.428',
#   '3pfg%': '.387',
#   'rebounds': '4.2',
#   'assists': '5.1',
#   'steals': '1.3',
#   'blocks': '0.5',
#   'points_per_game': '14.5'},
#  {'name': 'Mo Bamba',
#   'team': 'ORL',
#   'year': 2021,
#   'games_played': '17',
#   'mpg': '9.5',
#   'fg%': '.522',
#   '3pfg%': '.368',
#   'rebounds': '3.8',
#   'assists': '0.2',
#   'steals': '0.2',
#   'blocks': '0.8',
#   'points_per_game': '4.8'},
#  {'name': 'Desmond Bane',
#   'team': 'MEM',
#   'year': 2021,
#   'games_played': '29',
#   'mpg': '23.1',
#   'fg%': '.482',
#   '3pfg%': '.456',
#   'rebounds': '2.9',
#   'assists': '1.3',
#   'steals': '0.7',
#   'blocks': '0.1',
#   'points_per_game': '9.9'},
#  {'name': 'Harrison Barnes',
#   'team': 'SAC',
#   'year': 2021,
#   'games_played': '33',
#   'mpg': '35.7',
#   'fg%': '.492',
#   '3pfg%': '.392',
#   'rebounds': '6.1',
#   'assists': '3.6',
#   'steals': '0.8',
#   'blocks': '0.2',
#   'points_per_game': '16.7'},
#  {'name': 'RJ Barrett',
#   'team': 'NYK',
#   'year': 2021,
#   'games_played': '37',
#   'mpg': '33.2',
#   'fg%': '.443',
#   '3pfg%': '.350',
#   'rebounds': '6.0',
#   'assists': '2.9',
#   'steals': '0.6',
#   'blocks': '0.2',
#   'points_per_game': '16.5'},
#  {'name': 'Will Barton',
#   'team': 'DEN',
#   'year': 2021,
#   'games_played': '33',
#   'mpg': '29.9',
#   'fg%': '.442',
#   '3pfg%': '.388',
#   'rebounds': '4.1',
#   'assists': '3.1',
#   'steals': '0.8',
#   'blocks': '0.4',
#   'points_per_game': '11.6'},
#  {'name': 'Keita Bates-Diop',
#   'team': 'SAS',
#   'year': 2021,
#   'games_played': '14',
#   'mpg': '7.6',
#   'fg%': '.355',
#   '3pfg%': '.357',
#   'rebounds': '1.4',
#   'assists': '0.5',
#   'steals': '0.4',
#   'blocks': '0.1',
#   'points_per_game': '2.4'},
#  {'name': 'Nicolas Batum',
#   'team': 'LAC',
#   'year': 2021,
#   'games_played': '35',
#   'mpg': '29.5',
#   'fg%': '.472',
#   '3pfg%': '.439',
#   'rebounds': '4.8',
#   'assists': '2.4',
#   'steals': '1.2',
#   'blocks': '0.4',
#   'points_per_game': '9.0'},
#  {'name': 'Aron Baynes',
#   'team': 'TOR',
#   'year': 2021,
#   'games_played': '33',
#   'mpg': '19.7',
#   'fg%': '.440',
#   '3pfg%': '.243',
#   'rebounds': '5.4',
#   'assists': '1.1',
#   'steals': '0.3',
#   'blocks': '0.3',
#   'points_per_game': '6.3'},
#  {'name': 'Kent Bazemore',
#   'team': 'GSW',
#   'year': 2021,
#   'games_played': '35',
#   'mpg': '16.8',
#   'fg%': '.480',
#   '3pfg%': '.438',
#   'rebounds': '3.0',
#   'assists': '1.6',
#   'steals': '0.9',
#   'blocks': '0.5',
#   'points_per_game': '6.6'},
#  {'name': 'Darius Bazley',
#   'team': 'OKC',
#   'year': 2021,
#   'games_played': '36',
#   'mpg': '30.7',
#   'fg%': '.392',
#   '3pfg%': '.290',
#   'rebounds': '7.5',
#   'assists': '1.5',
#   'steals': '0.5',
#   'blocks': '0.6',
#   'points_per_game': '11.9'},
#  {'name': 'Bradley Beal',
#   'team': 'WAS',
#   'year': 2021,
#   'games_played': '33',
#   'mpg': '35.7',
#   'fg%': '.476',
#   '3pfg%': '.328',
#   'rebounds': '5.4',
#   'assists': '4.7',
#   'steals': '1.4',
#   'blocks': '0.5',
#   'points_per_game': '32.5'},
#  {'name': 'Malik Beasley',
#   'team': 'MIN',
#   'year': 2021,
#   'games_played': '33',
#   'mpg': '33.1',
#   'fg%': '.455',
#   '3pfg%': '.406',
#   'rebounds': '4.6',
#   'assists': '2.5',
#   'steals': '0.8',
#   'blocks': '0.2',
#   'points_per_game': '20.5'},
#  {'name': 'Jordan Bell',
#   'team': 'WAS',
#   'year': 2021,
#   'games_played': '3',
#   'mpg': '16.7',
#   'fg%': '.333',
#   '3pfg%': '.000',
#   'rebounds': '5.3',
#   'assists': '1.7',
#   'steals': '0.3',
#   'blocks': '1.0',
#   'points_per_game': '3.3'},
#  {'name': "DeAndre' Bembry",
#   'team': 'TOR',
#   'year': 2021,
#   'games_played': '27',
#   'mpg': '16.4',
#   'fg%': '.570',
#   '3pfg%': '.364',
#   'rebounds': '2.0',
#   'assists': '2.0',
#   'steals': '0.6',
#   'blocks': '0.3',
#   'points_per_game': '4.4'},
#  {'name': 'Dāvis Bertāns',
#   'team': 'WAS',
#   'year': 2021,
#   'games_played': '31',
#   'mpg': '25.9',
#   'fg%': '.392',
#   '3pfg%': '.386',
#   'rebounds': '3.1',
#   'assists': '0.9',
#   'steals': '0.6',
#   'blocks': '0.2',
#   'points_per_game': '11.6'},
#  {'name': 'Patrick Beverley',
#   'team': 'LAC',
#   'year': 2021,
#   'games_played': '28',
#   'mpg': '24.2',
#   'fg%': '.446',
#   '3pfg%': '.422',
#   'rebounds': '3.8',
#   'assists': '2.1',
#   'steals': '0.9',
#   'blocks': '0.8',
#   'points_per_game': '8.5'},
#  {'name': 'Saddiq Bey',
#   'team': 'DET',
#   'year': 2021,
#   'games_played': '34',
#   'mpg': '22.9',
#   'fg%': '.409',
#   '3pfg%': '.393',
#   'rebounds': '3.9',
#   'assists': '1.1',
#   'steals': '0.6',
#   'blocks': '0.0',
#   'points_per_game': '9.9'},
#  {'name': 'Tyler Bey',
#   'team': 'DAL',
#   'year': 2021,
#   'games_played': '4',
#   'mpg': '3.3',
#   'fg%': '.400',
#   '3pfg%': '',
#   'rebounds': '0.8',
#   'assists': '0.0',
#   'steals': '0.0',
#   'blocks': '0.3',
#   'points_per_game': '1.5'},
#  {'name': 'Khem Birch',
#   'team': 'ORL',
#   'year': 2021,
#   'games_played': '35',
#   'mpg': '20.1',
#   'fg%': '.497',
#   '3pfg%': '.308',
#   'rebounds': '5.3',
#   'assists': '1.1',
#   'steals': '0.6',
#   'blocks': '0.7',
#   'points_per_game': '5.9'},
#  {'name': 'Goga Bitadze',
#   'team': 'IND',
#   'year': 2021,
#   'games_played': '16',
#   'mpg': '9.3',
#   'fg%': '.511',
#   '3pfg%': '.133',
#   'rebounds': '2.0',
#   'assists': '0.3',
#   'steals': '0.2',
#   'blocks': '0.9',
#   'points_per_game': '3.8'},
#  {'name': 'Bismack Biyombo',
#   'team': 'CHO',
#   'year': 2021,
#   'games_played': '33',
#   'mpg': '22.3',
#   'fg%': '.569',
#   '3pfg%': '.000',
#   'rebounds': '5.6',
#   'assists': '1.5',
#   'steals': '0.3',
#   'blocks': '1.2',
#   'points_per_game': '5.6'},
#  {'name': 'Nemanja Bjelica',
#   'team': 'SAC',
#   'year': 2021,
#   'games_played': '19',
#   'mpg': '18.0',
#   'fg%': '.483',
#   '3pfg%': '.333',
#   'rebounds': '4.2',
#   'assists': '2.2',
#   'steals': '0.3',
#   'blocks': '0.1',
#   'points_per_game': '8.5'},
#  {'name': 'Eric Bledsoe',
#   'team': 'NOP',
#   'year': 2021,
#   'games_played': '35',
#   'mpg': '29.7',
#   'fg%': '.435',
#   '3pfg%': '.385',
#   'rebounds': '3.5',
#   'assists': '3.8',
#   'steals': '0.8',
#   'blocks': '0.3',
#   'points_per_game': '12.6'},
#  {'name': 'Keljin Blevins',
#   'team': 'POR',
#   'year': 2021,
#   'games_played': '9',
#   'mpg': '5.2',
#   'fg%': '.182',
#   '3pfg%': '.000',
#   'rebounds': '0.2',
#   'assists': '0.4',
#   'steals': '0.2',
#   'blocks': '0.0',
#   'points_per_game': '0.4'},
#  {'name': 'Bogdan Bogdanović',
#   'team': 'ATL',
#   'year': 2021,
#   'games_played': '11',
#   'mpg': '22.6',
#   'fg%': '.385',
#   '3pfg%': '.343',
#   'rebounds': '3.5',
#   'assists': '2.2',
#   'steals': '0.4',
#   'blocks': '0.2',
#   'points_per_game': '9.4'},
#  {'name': 'Bojan Bogdanović',
#   'team': 'UTA',
#   'year': 2021,
#   'games_played': '36',
#   'mpg': '30.6',
#   'fg%': '.432',
#   '3pfg%': '.405',
#   'rebounds': '3.9',
#   'assists': '1.9',
#   'steals': '0.5',
#   'blocks': '0.1',
#   'points_per_game': '15.7'},
#  {'name': 'Bol Bol',
#   'team': 'DEN',
#   'year': 2021,
#   'games_played': '15',
#   'mpg': '5.6',
#   'fg%': '.500',
#   '3pfg%': '.500',
#   'rebounds': '0.7',
#   'assists': '0.3',
#   'steals': '0.1',
#   'blocks': '0.3',
#   'points_per_game': '1.9'},
#  {'name': 'Marques Bolden',
#   'team': 'CLE',
#   'year': 2021,
#   'games_played': '6',
#   'mpg': '4.8',
#   'fg%': '.333',
#   '3pfg%': '',
#   'rebounds': '1.0',
#   'assists': '0.0',
#   'steals': '0.3',
#   'blocks': '0.3',
#   'points_per_game': '1.2'},
#  {'name': 'Jordan Bone',
#   'team': 'ORL',
#   'year': 2021,
#   'games_played': '14',
#   'mpg': '14.0',
#   'fg%': '.426',
#   '3pfg%': '.313',
#   'rebounds': '1.7',
#   'assists': '1.3',
#   'steals': '0.1',
#   'blocks': '0.0',
#   'points_per_game': '4.0'},
#  {'name': 'Isaac Bonga',
#   'team': 'WAS',
#   'year': 2021,
#   'games_played': '22',
#   'mpg': '12.3',
#   'fg%': '.378',
#   '3pfg%': '.345',
#   'rebounds': '2.0',
#   'assists': '0.6',
#   'steals': '0.3',
#   'blocks': '0.2',
#   'points_per_game': '2.1'},
#  {'name': 'Devin Booker',
#   'team': 'PHO',
#   'year': 2021,
#   'games_played': '31',
#   'mpg': '33.9',
#   'fg%': '.496',
#   '3pfg%': '.362',
#   'rebounds': '3.6',
#   'assists': '4.4',
#   'steals': '0.9',
#   'blocks': '0.3',
#   'points_per_game': '24.9'},
#  {'name': 'Chris Boucher',
#   'team': 'TOR',
#   'year': 2021,
#   'games_played': '36',
#   'mpg': '23.6',
#   'fg%': '.534',
#   '3pfg%': '.445',
#   'rebounds': '6.5',
#   'assists': '1.0',
#   'steals': '0.6',
#   'blocks': '1.9',
#   'points_per_game': '13.6'},
#  {'name': 'Brian Bowen',
#   'team': 'IND',
#   'year': 2021,
#   'games_played': '1',
#   'mpg': '5.0',
#   'fg%': '.500',
#   '3pfg%': '',
#   'rebounds': '1.0',
#   'assists': '0.0',
#   'steals': '0.0',
#   'blocks': '0.0',
#   'points_per_game': '3.0'},
#  {'name': 'Avery Bradley',
#   'team': 'MIA',
#   'year': 2021,
#   'games_played': '10',
#   'mpg': '21.1',
#   'fg%': '.470',
#   '3pfg%': '.421',
#   'rebounds': '1.8',
#   'assists': '1.4',
#   'steals': '0.7',
#   'blocks': '0.1',
#   'points_per_game': '8.5'},
#  {'name': 'Tony Bradley',
#   'team': 'PHI',
#   'year': 2021,
#   'games_played': '12',
#   'mpg': '10.6',
#   'fg%': '.564',
#   '3pfg%': '.000',
#   'rebounds': '4.2',
#   'assists': '0.5',
#   'steals': '0.3',
#   'blocks': '0.6',
#   'points_per_game': '3.9'},
#  {'name': 'Jarrell Brantley',
#   'team': 'UTA',
#   'year': 2021,
#   'games_played': '10',
#   'mpg': '2.8',
#   'fg%': '.400',
#   '3pfg%': '.429',
#   'rebounds': '0.7',
#   'assists': '0.0',
#   'steals': '0.1',
#   'blocks': '0.1',
#   'points_per_game': '1.1'},
#  {'name': 'Ignas Brazdeikis',
#   'team': 'NYK',
#   'year': 2021,
#   'games_played': '4',
#   'mpg': '1.8',
#   'fg%': '.000',
#   '3pfg%': '',
#   'rebounds': '0.5',
#   'assists': '0.3',
#   'steals': '0.0',
#   'blocks': '0.0',
#   'points_per_game': '0.5'},
#  {'name': 'Mikal Bridges',
#   'team': 'PHO',
#   'year': 2021,
#   'games_played': '35',
#   'mpg': '32.3',
#   'fg%': '.524',
#   '3pfg%': '.420',
#   'rebounds': '5.1',
#   'assists': '2.2',
#   'steals': '0.7',
#   'blocks': '0.9',
#   'points_per_game': '13.7'},
#  {'name': 'Miles Bridges',
#   'team': 'CHO',
#   'year': 2021,
#   'games_played': '35',
#   'mpg': '26.8',
#   'fg%': '.491',
#   '3pfg%': '.383',
#   'rebounds': '5.7',
#   'assists': '2.1',
#   'steals': '0.7',
#   'blocks': '0.7',
#   'points_per_game': '10.0'},
#  {'name': 'Malcolm Brogdon',
#   'team': 'IND',
#   'year': 2021,
#   'games_played': '34',
#   'mpg': '35.6',
#   'fg%': '.447',
#   '3pfg%': '.378',
#   'rebounds': '4.6',
#   'assists': '6.2',
#   'steals': '1.2',
#   'blocks': '0.2',
#   'points_per_game': '21.2'},
#  {'name': 'Dillon Brooks',
#   'team': 'MEM',
#   'year': 2021,
#   'games_played': '30',
#   'mpg': '29.0',
#   'fg%': '.399',
#   '3pfg%': '.322',
#   'rebounds': '3.1',
#   'assists': '2.6',
#   'steals': '1.4',
#   'blocks': '0.5',
#   'points_per_game': '15.7'},
#  {'name': 'Bruce Brown',
#   'team': 'BRK',
#   'year': 2021,
#   'games_played': '33',
#   'mpg': '21.2',
#   'fg%': '.590',
#   '3pfg%': '.273',
#   'rebounds': '4.7',
#   'assists': '1.4',
#   'steals': '0.8',
#   'blocks': '0.3',
#   'points_per_game': '8.6'},
#  {'name': 'Jaylen Brown',
#   'team': 'BOS',
#   'year': 2021,
#   'games_played': '33',
#   'mpg': '33.8',
#   'fg%': '.495',
#   '3pfg%': '.388',
#   'rebounds': '5.6',
#   'assists': '3.9',
#   'steals': '1.1',
#   'blocks': '0.5',
#   'points_per_game': '24.7'},
#  {'name': 'Moses Brown',
#   'team': 'OKC',
#   'year': 2021,
#   'games_played': '7',
#   'mpg': '4.4',
#   'fg%': '.700',
#   '3pfg%': '',
#   'rebounds': '2.1',
#   'assists': '0.4',
#   'steals': '0.1',
#   'blocks': '0.6',
#   'points_per_game': '3.0'},
#  {'name': 'Sterling Brown',
#   'team': 'HOU',
#   'year': 2021,
#   'games_played': '32',
#   'mpg': '22.3',
#   'fg%': '.439',
#   '3pfg%': '.402',
#   'rebounds': '4.2',
#   'assists': '1.7',
#   'steals': '1.0',
#   'blocks': '0.2',
#   'points_per_game': '7.4'},
#  {'name': 'Troy Brown Jr.',
#   'team': 'WAS',
#   'year': 2021,
#   'games_played': '18',
#   'mpg': '13.6',
#   'fg%': '.365',
#   '3pfg%': '.275',
#   'rebounds': '2.9',
#   'assists': '0.9',
#   'steals': '0.1',
#   'blocks': '0.2',
#   'points_per_game': '4.2'},
#  {'name': 'Jalen Brunson',
#   'team': 'DAL',
#   'year': 2021,
#   'games_played': '31',
#   'mpg': '24.8',
#   'fg%': '.534',
#   '3pfg%': '.404',
#   'rebounds': '3.5',
#   'assists': '3.4',
#   'steals': '0.5',
#   'blocks': '0.0',
#   'points_per_game': '12.5'},
#  {'name': 'Thomas Bryant',
#   'team': 'WAS',
#   'year': 2021,
#   'games_played': '10',
#   'mpg': '27.1',
#   'fg%': '.648',
#   '3pfg%': '.429',
#   'rebounds': '6.1',
#   'assists': '1.5',
#   'steals': '0.4',
#   'blocks': '0.8',
#   'points_per_game': '14.3'},
#  {'name': 'Reggie Bullock',
#   'team': 'NYK',
#   'year': 2021,
#   'games_played': '32',
#   'mpg': '26.3',
#   'fg%': '.406',
#   '3pfg%': '.372',
#   'rebounds': '3.4',
#   'assists': '1.3',
#   'steals': '0.6',
#   'blocks': '0.2',
#   'points_per_game': '8.5'},
#  {'name': 'Trey Burke',
#   'team': 'DAL',
#   'year': 2021,
#   'games_played': '34',
#   'mpg': '16.0',
#   'fg%': '.452',
#   '3pfg%': '.396',
#   'rebounds': '1.0',
#   'assists': '1.6',
#   'steals': '0.6',
#   'blocks': '0.1',
#   'points_per_game': '7.6'},
#  {'name': 'Alec Burks',
#   'team': 'NYK',
#   'year': 2021,
#   'games_played': '25',
#   'mpg': '24.7',
#   'fg%': '.405',
#   '3pfg%': '.402',
#   'rebounds': '4.3',
#   'assists': '2.0',
#   'steals': '0.7',
#   'blocks': '0.2',
#   'points_per_game': '11.1'},
#  {'name': 'Jimmy Butler',
#   'team': 'MIA',
#   'year': 2021,
#   'games_played': '22',
#   'mpg': '33.1',
#   'fg%': '.454',
#   '3pfg%': '.235',
#   'rebounds': '7.5',
#   'assists': '7.8',
#   'steals': '1.9',
#   'blocks': '0.4',
#   'points_per_game': '20.5'},
#  {'name': 'Bruno Caboclo',
#   'team': 'HOU',
#   'year': 2021,
#   'games_played': '6',
#   'mpg': '6.0',
#   'fg%': '.471',
#   '3pfg%': '.000',
#   'rebounds': '2.3',
#   'assists': '0.2',
#   'steals': '0.0',
#   'blocks': '0.3',
#   'points_per_game': '2.8'},
#  {'name': 'Devontae Cacok',
#   'team': 'LAL',
#   'year': 2021,
#   'games_played': '4',
#   'mpg': '4.3',
#   'fg%': '1.000',
#   '3pfg%': '',
#   'rebounds': '1.3',
#   'assists': '0.0',
#   'steals': '0.5',
#   'blocks': '0.0',
#   'points_per_game': '2.0'},
#  {'name': 'Kentavious Caldwell-Pope',
#   'team': 'LAL',
#   'year': 2021,
#   'games_played': '33',
#   'mpg': '26.2',
#   'fg%': '.438',
#   '3pfg%': '.402',
#   'rebounds': '2.4',
#   'assists': '1.4',
#   'steals': '0.8',
#   'blocks': '0.3',
#   'points_per_game': '8.7'},
#  {'name': 'Facundo Campazzo',
#   'team': 'DEN',
#   'year': 2021,
#   'games_played': '30',
#   'mpg': '16.3',
#   'fg%': '.405',
#   '3pfg%': '.379',
#   'rebounds': '1.0',
#   'assists': '2.1',
#   'steals': '1.0',
#   'blocks': '0.2',
#   'points_per_game': '5.5'},
#  {'name': 'Vlatko Čančar',
#   'team': 'DEN',
#   'year': 2021,
#   'games_played': '20',
#   'mpg': '6.1',
#   'fg%': '.393',
#   '3pfg%': '.214',
#   'rebounds': '1.4',
#   'assists': '0.3',
#   'steals': '0.4',
#   'blocks': '0.1',
#   'points_per_game': '1.5'},
#  {'name': 'Clint Capela',
#   'team': 'ATL',
#   'year': 2021,
#   'games_played': '32',
#   'mpg': '29.7',
#   'fg%': '.589',
#   '3pfg%': '',
#   'rebounds': '14.2',
#   'assists': '0.9',
#   'steals': '0.8',
#   'blocks': '2.2',
#   'points_per_game': '14.7'},
#  {'name': 'Vernon Carey Jr.',
#   'team': 'CHO',
#   'year': 2021,
#   'games_played': '3',
#   'mpg': '2.0',
#   'fg%': '.333',
#   '3pfg%': '.000',
#   'rebounds': '1.0',
#   'assists': '0.3',
#   'steals': '0.0',
#   'blocks': '0.3',
#   'points_per_game': '1.0'},
#  {'name': 'Jevon Carter',
#   'team': 'PHO',
#   'year': 2021,
#   'games_played': '29',
#   'mpg': '10.0',
#   'fg%': '.357',
#   '3pfg%': '.298',
#   'rebounds': '1.3',
#   'assists': '1.2',
#   'steals': '0.4',
#   'blocks': '0.2',
#   'points_per_game': '2.7'},
#  {'name': 'Wendell Carter Jr.',
#   'team': 'CHI',
#   'year': 2021,
#   'games_played': '23',
#   'mpg': '26.9',
#   'fg%': '.535',
#   '3pfg%': '.350',
#   'rebounds': '7.8',
#   'assists': '2.3',
#   'steals': '0.7',
#   'blocks': '0.8',
#   'points_per_game': '12.3'},
#  {'name': 'Michael Carter-Williams',
#   'team': 'ORL',
#   'year': 2021,
#   'games_played': '17',
#   'mpg': '26.5',
#   'fg%': '.403',
#   '3pfg%': '.258',
#   'rebounds': '4.8',
#   'assists': '4.1',
#   'steals': '0.6',
#   'blocks': '0.5',
#   'points_per_game': '9.0'},
#  {'name': 'Alex Caruso',
#   'team': 'LAL',
#   'year': 2021,
#   'games_played': '29',
#   'mpg': '19.9',
#   'fg%': '.428',
#   '3pfg%': '.400',
#   'rebounds': '2.8',
#   'assists': '2.4',
#   'steals': '1.0',
#   'blocks': '0.2',
#   'points_per_game': '5.8'},
#  {'name': 'Willie Cauley-Stein',
#   'team': 'DAL',
#   'year': 2021,
#   'games_played': '32',
#   'mpg': '17.2',
#   'fg%': '.636',
#   '3pfg%': '.167',
#   'rebounds': '4.4',
#   'assists': '0.8',
#   'steals': '0.3',
#   'blocks': '0.7',
#   'points_per_game': '5.7'},
#  {'name': 'Chris Chiozza',
#   'team': 'BRK',
#   'year': 2021,
#   'games_played': '15',
#   'mpg': '9.1',
#   'fg%': '.362',
#   '3pfg%': '.391',
#   'rebounds': '1.1',
#   'assists': '2.4',
#   'steals': '0.3',
#   'blocks': '0.3',
#   'points_per_game': '3.5'},
#  {'name': 'Marquese Chriss',
#   'team': 'GSW',
#   'year': 2021,
#   'games_played': '2',
#   'mpg': '13.5',
#   'fg%': '.357',
#   '3pfg%': '.200',
#   'rebounds': '6.5',
#   'assists': '1.0',
#   'steals': '0.0',
#   'blocks': '1.0',
#   'points_per_game': '6.5'},
#  {'name': 'Gary Clark',
#   'team': 'ORL',
#   'year': 2021,
#   'games_played': '30',
#   'mpg': '19.1',
#   'fg%': '.295',
#   '3pfg%': '.274',
#   'rebounds': '3.2',
#   'assists': '0.8',
#   'steals': '0.4',
#   'blocks': '0.2',
#   'points_per_game': '3.3'},
#  {'name': 'Brandon Clarke',
#   'team': 'MEM',
#   'year': 2021,
#   'games_played': '28',
#   'mpg': '26.8',
#   'fg%': '.518',
#   '3pfg%': '.326',
#   'rebounds': '5.9',
#   'assists': '1.6',
#   'steals': '1.2',
#   'blocks': '0.6',
#   'points_per_game': '12.0'},
#  {'name': 'Jordan Clarkson',
#   'team': 'UTA',
#   'year': 2021,
#   'games_played': '36',
#   'mpg': '26.0',
#   'fg%': '.447',
#   '3pfg%': '.370',
#   'rebounds': '4.0',
#   'assists': '2.3',
#   'steals': '0.9',
#   'blocks': '0.2',
#   'points_per_game': '17.9'},
#  {'name': 'Nicolas Claxton',
#   'team': 'BRK',
#   'year': 2021,
#   'games_played': '5',
#   'mpg': '15.2',
#   'fg%': '.690',
#   '3pfg%': '.000',
#   'rebounds': '3.4',
#   'assists': '1.0',
#   'steals': '1.0',
#   'blocks': '1.4',
#   'points_per_game': '10.0'},
#  {'name': 'Amir Coffey',
#   'team': 'LAC',
#   'year': 2021,
#   'games_played': '20',
#   'mpg': '7.7',
#   'fg%': '.525',
#   '3pfg%': '.524',
#   'rebounds': '0.8',
#   'assists': '0.4',
#   'steals': '0.2',
#   'blocks': '0.0',
#   'points_per_game': '2.8'},
#  {'name': 'John Collins',
#   'team': 'ATL',
#   'year': 2021,
#   'games_played': '36',
#   'mpg': '30.7',
#   'fg%': '.536',
#   '3pfg%': '.388',
#   'rebounds': '7.6',
#   'assists': '1.4',
#   'steals': '0.4',
#   'blocks': '1.0',
#   'points_per_game': '18.0'},
#  {'name': 'Mike Conley',
#   'team': 'UTA',
#   'year': 2021,
#   'games_played': '29',
#   'mpg': '29.4',
#   'fg%': '.444',
#   '3pfg%': '.422',
#   'rebounds': '3.5',
#   'assists': '5.7',
#   'steals': '1.4',
#   'blocks': '0.1',
#   'points_per_game': '16.1'},
#  {'name': 'Pat Connaughton',
#   'team': 'MIL',
#   'year': 2021,
#   'games_played': '33',
#   'mpg': '21.1',
#   'fg%': '.443',
#   '3pfg%': '.393',
#   'rebounds': '4.3',
#   'assists': '1.4',
#   'steals': '0.7',
#   'blocks': '0.5',
#   'points_per_game': '6.5'},
#  {'name': 'Quinn Cook',
#   'team': 'LAL',
#   'year': 2021,
#   'games_played': '16',
#   'mpg': '3.9',
#   'fg%': '.462',
#   '3pfg%': '.385',
#   'rebounds': '0.3',
#   'assists': '0.3',
#   'steals': '0.1',
#   'blocks': '0.1',
#   'points_per_game': '2.1'},
#  {'name': 'Tyler Cook',
#   'team': 'BRK',
#   'year': 2021,
#   'games_played': '4',
#   'mpg': '4.3',
#   'fg%': '.333',
#   '3pfg%': '',
#   'rebounds': '0.5',
#   'assists': '0.5',
#   'steals': '0.0',
#   'blocks': '0.0',
#   'points_per_game': '0.5'},
#  {'name': 'DeMarcus Cousins',
#   'team': 'HOU',
#   'year': 2021,
#   'games_played': '25',
#   'mpg': '20.2',
#   'fg%': '.376',
#   '3pfg%': '.336',
#   'rebounds': '7.6',
#   'assists': '2.4',
#   'steals': '0.8',
#   'blocks': '0.7',
#   'points_per_game': '9.6'},
#  {'name': 'Robert Covington',
#   'team': 'POR',
#   'year': 2021,
#   'games_played': '33',
#   'mpg': '31.9',
#   'fg%': '.374',
#   '3pfg%': '.333',
#   'rebounds': '6.6',
#   'assists': '1.7',
#   'steals': '1.6',
#   'blocks': '1.2',
#   'points_per_game': '7.9'},
#  {'name': 'Torrey Craig',
#   'team': 'MIL',
#   'year': 2021,
#   'games_played': '17',
#   'mpg': '11.4',
#   'fg%': '.395',
#   '3pfg%': '.381',
#   'rebounds': '2.5',
#   'assists': '0.8',
#   'steals': '0.5',
#   'blocks': '0.4',
#   'points_per_game': '2.5'},
#  {'name': 'Jae Crowder',
#   'team': 'PHO',
#   'year': 2021,
#   'games_played': '32',
#   'mpg': '27.6',
#   'fg%': '.402',
#   '3pfg%': '.376',
#   'rebounds': '5.0',
#   'assists': '2.1',
#   'steals': '0.8',
#   'blocks': '0.3',
#   'points_per_game': '10.1'},
#  {'name': 'Jarrett Culver',
#   'team': 'MIN',
#   'year': 2021,
#   'games_played': '19',
#   'mpg': '19.8',
#   'fg%': '.422',
#   '3pfg%': '.229',
#   'rebounds': '4.7',
#   'assists': '0.8',
#   'steals': '0.6',
#   'blocks': '0.4',
#   'points_per_game': '7.2'},
#  {'name': 'Seth Curry',
#   'team': 'PHI',
#   'year': 2021,
#   'games_played': '28',
#   'mpg': '29.9',
#   'fg%': '.469',
#   '3pfg%': '.448',
#   'rebounds': '2.0',
#   'assists': '2.8',
#   'steals': '0.9',
#   'blocks': '0.3',
#   'points_per_game': '12.5'},
#  {'name': 'Stephen Curry',
#   'team': 'GSW',
#   'year': 2021,
#   'games_played': '35',
#   'mpg': '34.1',
#   'fg%': '.478',
#   '3pfg%': '.411',
#   'rebounds': '5.5',
#   'assists': '6.3',
#   'steals': '1.3',
#   'blocks': '0.1',
#   'points_per_game': '29.7'},
#  {'name': 'Anthony Davis',
#   'team': 'LAL',
#   'year': 2021,
#   'games_played': '23',
#   'mpg': '32.8',
#   'fg%': '.533',
#   '3pfg%': '.293',
#   'rebounds': '8.4',
#   'assists': '3.0',
#   'steals': '1.3',
#   'blocks': '1.8',
#   'points_per_game': '22.5'},
#  {'name': 'Ed Davis',
#   'team': 'MIN',
#   'year': 2021,
#   'games_played': '19',
#   'mpg': '13.9',
#   'fg%': '.419',
#   '3pfg%': '',
#   'rebounds': '5.1',
#   'assists': '1.0',
#   'steals': '0.5',
#   'blocks': '0.5',
#   'points_per_game': '2.3'},
#  {'name': 'Terence Davis',
#   'team': 'TOR',
#   'year': 2021,
#   'games_played': '30',
#   'mpg': '14.7',
#   'fg%': '.422',
#   '3pfg%': '.364',
#   'rebounds': '1.9',
#   'assists': '1.1',
#   'steals': '0.5',
#   'blocks': '0.2',
#   'points_per_game': '7.1'},
#  {'name': 'DeMar DeRozan',
#   'team': 'SAS',
#   'year': 2021,
#   'games_played': '30',
#   'mpg': '33.9',
#   'fg%': '.490',
#   '3pfg%': '.321',
#   'rebounds': '4.7',
#   'assists': '7.3',
#   'steals': '1.0',
#   'blocks': '0.3',
#   'points_per_game': '20.3'},
#  {'name': 'Hamidou Diallo',
#   'team': 'OKC',
#   'year': 2021,
#   'games_played': '32',
#   'mpg': '23.8',
#   'fg%': '.481',
#   '3pfg%': '.293',
#   'rebounds': '5.2',
#   'assists': '2.4',
#   'steals': '1.0',
#   'blocks': '0.4',
#   'points_per_game': '11.9'},
#  {'name': 'Gorgui Dieng',
#   'team': 'MEM',
#   'year': 2021,
#   'games_played': '22',
#   'mpg': '16.9',
#   'fg%': '.519',
#   '3pfg%': '.479',
#   'rebounds': '4.5',
#   'assists': '1.3',
#   'steals': '0.8',
#   'blocks': '0.6',
#   'points_per_game': '7.9'},
#  {'name': 'Spencer Dinwiddie',
#   'team': 'BRK',
#   'year': 2021,
#   'games_played': '3',
#   'mpg': '21.3',
#   'fg%': '.375',
#   '3pfg%': '.286',
#   'rebounds': '4.3',
#   'assists': '3.0',
#   'steals': '0.7',
#   'blocks': '0.3',
#   'points_per_game': '6.7'},
#  {'name': 'Donte DiVincenzo',
#   'team': 'MIL',
#   'year': 2021,
#   'games_played': '36',
#   'mpg': '26.7',
#   'fg%': '.418',
#   '3pfg%': '.384',
#   'rebounds': '4.7',
#   'assists': '3.0',
#   'steals': '1.1',
#   'blocks': '0.2',
#   'points_per_game': '10.3'},
#  {'name': 'Luka Dončić',
#   'team': 'DAL',
#   'year': 2021,
#   'games_played': '33',
#   'mpg': '35.3',
#   'fg%': '.477',
#   '3pfg%': '.351',
#   'rebounds': '8.5',
#   'assists': '9.1',
#   'steals': '1.0',
#   'blocks': '0.7',
#   'points_per_game': '28.4'},
#  {'name': 'Luguentz Dort',
#   'team': 'OKC',
#   'year': 2021,
#   'games_played': '35',
#   'mpg': '29.7',
#   'fg%': '.388',
#   '3pfg%': '.325',
#   'rebounds': '3.5',
#   'assists': '1.5',
#   'steals': '0.9',
#   'blocks': '0.3',
#   'points_per_game': '12.3'},
#  {'name': 'Damyean Dotson',
#   'team': 'CLE',
#   'year': 2021,
#   'games_played': '30',
#   'mpg': '18.8',
#   'fg%': '.401',
#   '3pfg%': '.279',
#   'rebounds': '1.8',
#   'assists': '2.2',
#   'steals': '0.4',
#   'blocks': '0.1',
#   'points_per_game': '6.8'},
#  {'name': 'Devon Dotson',
#   'team': 'CHI',
#   'year': 2021,
#   'games_played': '1',
#   'mpg': '10.0',
#   'fg%': '.500',
#   '3pfg%': '',
#   'rebounds': '1.0',
#   'assists': '0.0',
#   'steals': '0.0',
#   'blocks': '0.0',
#   'points_per_game': '4.0'},
#  {'name': 'Sekou Doumbouya',
#   'team': 'DET',
#   'year': 2021,
#   'games_played': '32',
#   'mpg': '13.7',
#   'fg%': '.355',
#   '3pfg%': '.250',
#   'rebounds': '2.3',
#   'assists': '0.7',
#   'steals': '0.4',
#   'blocks': '0.1',
#   'points_per_game': '4.2'},
#  {'name': 'PJ Dozier',
#   'team': 'DEN',
#   'year': 2021,
#   'games_played': '21',
#   'mpg': '19.4',
#   'fg%': '.457',
#   '3pfg%': '.392',
#   'rebounds': '3.9',
#   'assists': '1.7',
#   'steals': '0.5',
#   'blocks': '0.6',
#   'points_per_game': '7.6'},
#  {'name': 'Goran Dragić',
#   'team': 'MIA',
#   'year': 2021,
#   'games_played': '22',
#   'mpg': '27.1',
#   'fg%': '.458',
#   '3pfg%': '.361',
#   'rebounds': '3.1',
#   'assists': '4.8',
#   'steals': '0.6',
#   'blocks': '0.2',
#   'points_per_game': '14.8'},
#  {'name': 'Andre Drummond',
#   'team': 'CLE',
#   'year': 2021,
#   'games_played': '25',
#   'mpg': '28.9',
#   'fg%': '.474',
#   '3pfg%': '.000',
#   'rebounds': '13.5',
#   'assists': '2.6',
#   'steals': '1.6',
#   'blocks': '1.2',
#   'points_per_game': '17.5'},
#  {'name': 'Jared Dudley',
#   'team': 'LAL',
#   'year': 2021,
#   'games_played': '11',
#   'mpg': '6.9',
#   'fg%': '.286',
#   '3pfg%': '.400',
#   'rebounds': '1.7',
#   'assists': '0.5',
#   'steals': '0.1',
#   'blocks': '0.1',
#   'points_per_game': '0.5'},
#  {'name': 'Kevin Durant',
#   'team': 'BRK',
#   'year': 2021,
#   'games_played': '19',
#   'mpg': '35.7',
#   'fg%': '.524',
#   '3pfg%': '.434',
#   'rebounds': '7.3',
#   'assists': '5.3',
#   'steals': '0.7',
#   'blocks': '1.4',
#   'points_per_game': '29.0'},
#  {'name': 'Anthony Edwards',
#   'team': 'MIN',
#   'year': 2021,
#   'games_played': '36',
#   'mpg': '29.1',
#   'fg%': '.371',
#   '3pfg%': '.302',
#   'rebounds': '4.0',
#   'assists': '2.5',
#   'steals': '0.9',
#   'blocks': '0.4',
#   'points_per_game': '14.9'},
#  {'name': 'Carsen Edwards',
#   'team': 'BOS',
#   'year': 2021,
#   'games_played': '14',
#   'mpg': '10.5',
#   'fg%': '.460',
#   '3pfg%': '.324',
#   'rebounds': '1.0',
#   'assists': '0.4',
#   'steals': '0.3',
#   'blocks': '0.1',
#   'points_per_game': '5.4'},
#  {'name': 'CJ Elleby',
#   'team': 'POR',
#   'year': 2021,
#   'games_played': '13',
#   'mpg': '8.1',
#   'fg%': '.452',
#   '3pfg%': '.263',
#   'rebounds': '1.1',
#   'assists': '0.2',
#   'steals': '0.3',
#   'blocks': '0.2',
#   'points_per_game': '3.0'},
#  {'name': 'Wayne Ellington',
#   'team': 'DET',
#   'year': 2021,
#   'games_played': '28',
#   'mpg': '23.2',
#   'fg%': '.454',
#   '3pfg%': '.433',
#   'rebounds': '1.7',
#   'assists': '1.4',
#   'steals': '0.5',
#   'blocks': '0.2',
#   'points_per_game': '10.8'},
#  {'name': 'Joel Embiid',
#   'team': 'PHI',
#   'year': 2021,
#   'games_played': '30',
#   'mpg': '33.0',
#   'fg%': '.521',
#   '3pfg%': '.416',
#   'rebounds': '11.6',
#   'assists': '3.3',
#   'steals': '1.2',
#   'blocks': '1.4',
#   'points_per_game': '30.2'},
#  {'name': 'James Ennis',
#   'team': 'ORL',
#   'year': 2021,
#   'games_played': '24',
#   'mpg': '21.4',
#   'fg%': '.500',
#   '3pfg%': '.447',
#   'rebounds': '3.9',
#   'assists': '1.3',
#   'steals': '0.8',
#   'blocks': '0.3',
#   'points_per_game': '7.3'},
#  {'name': 'Drew Eubanks',
#   'team': 'SAS',
#   'year': 2021,
#   'games_played': '16',
#   'mpg': '11.5',
#   'fg%': '.412',
#   '3pfg%': '',
#   'rebounds': '2.9',
#   'assists': '0.6',
#   'steals': '0.1',
#   'blocks': '1.1',
#   'points_per_game': '3.5'},
#  {'name': 'Dante Exum',
#   'team': 'CLE',
#   'year': 2021,
#   'games_played': '6',
#   'mpg': '19.3',
#   'fg%': '.385',
#   '3pfg%': '.182',
#   'rebounds': '2.8',
#   'assists': '2.2',
#   'steals': '0.7',
#   'blocks': '0.3',
#   'points_per_game': '3.8'},
#  {'name': 'Tacko Fall',
#   'team': 'BOS',
#   'year': 2021,
#   'games_played': '8',
#   'mpg': '7.1',
#   'fg%': '.692',
#   '3pfg%': '',
#   'rebounds': '2.6',
#   'assists': '0.1',
#   'steals': '0.0',
#   'blocks': '1.3',
#   'points_per_game': '2.6'},
#  {'name': 'Derrick Favors',
#   'team': 'UTA',
#   'year': 2021,
#   'games_played': '34',
#   'mpg': '16.2',
#   'fg%': '.649',
#   '3pfg%': '.000',
#   'rebounds': '5.5',
#   'assists': '0.8',
#   'steals': '0.5',
#   'blocks': '0.9',
#   'points_per_game': '6.3'},
#  {'name': 'Cristiano Felício',
#   'team': 'CHI',
#   'year': 2021,
#   'games_played': '6',
#   'mpg': '6.3',
#   'fg%': '.750',
#   '3pfg%': '',
#   'rebounds': '2.0',
#   'assists': '0.8',
#   'steals': '0.3',
#   'blocks': '0.0',
#   'points_per_game': '1.8'},
#  {'name': 'Terrance Ferguson',
#   'team': 'PHI',
#   'year': 2021,
#   'games_played': '9',
#   'mpg': '3.8',
#   'fg%': '.200',
#   '3pfg%': '.000',
#   'rebounds': '0.1',
#   'assists': '0.2',
#   'steals': '0.0',
#   'blocks': '0.0',
#   'points_per_game': '0.2'},
#  {'name': 'Bruno Fernando',
#   'team': 'ATL',
#   'year': 2021,
#   'games_played': '18',
#   'mpg': '8.4',
#   'fg%': '.440',
#   '3pfg%': '.000',
#   'rebounds': '3.3',
#   'assists': '0.5',
#   'steals': '0.1',
#   'blocks': '0.1',
#   'points_per_game': '1.7'},
#  {'name': 'Yogi Ferrell',
#   'team': 'CLE',
#   'year': 2021,
#   'games_played': '2',
#   'mpg': '20.0',
#   'fg%': '.381',
#   '3pfg%': '.333',
#   'rebounds': '3.5',
#   'assists': '2.5',
#   'steals': '1.5',
#   'blocks': '0.5',
#   'points_per_game': '9.5'},
#  {'name': 'Dorian Finney-Smith',
#   'team': 'DAL',
#   'year': 2021,
#   'games_played': '26',
#   'mpg': '31.5',
#   'fg%': '.422',
#   '3pfg%': '.341',
#   'rebounds': '5.2',
#   'assists': '1.4',
#   'steals': '1.0',
#   'blocks': '0.4',
#   'points_per_game': '8.2'},
#  {'name': 'Malachi Flynn',
#   'team': 'TOR',
#   'year': 2021,
#   'games_played': '15',
#   'mpg': '8.3',
#   'fg%': '.267',
#   '3pfg%': '.192',
#   'rebounds': '0.7',
#   'assists': '1.1',
#   'steals': '0.3',
#   'blocks': '0.0',
#   'points_per_game': '2.2'},
#  {'name': 'Bryn Forbes',
#   'team': 'MIL',
#   'year': 2021,
#   'games_played': '36',
#   'mpg': '18.8',
#   'fg%': '.467',
#   '3pfg%': '.448',
#   'rebounds': '1.3',
#   'assists': '0.6',
#   'steals': '0.2',
#   'blocks': '0.0',
#   'points_per_game': '9.3'},
#  {'name': 'Trent Forrest',
#   'team': 'UTA',
#   'year': 2021,
#   'games_played': '7',
#   'mpg': '2.9',
#   'fg%': '.000',
#   '3pfg%': '.000',
#   'rebounds': '0.3',
#   'assists': '0.6',
#   'steals': '0.3',
#   'blocks': '0.0',
#   'points_per_game': '0.3'},
#  {'name': 'Evan Fournier',
#   'team': 'ORL',
#   'year': 2021,
#   'games_played': '21',
#   'mpg': '29.2',
#   'fg%': '.450',
#   '3pfg%': '.371',
#   'rebounds': '3.1',
#   'assists': '3.8',
#   'steals': '1.0',
#   'blocks': '0.3',
#   'points_per_game': '18.5'},
#  {'name': "De'Aaron Fox",
#   'team': 'SAC',
#   'year': 2021,
#   'games_played': '35',
#   'mpg': '34.2',
#   'fg%': '.466',
#   '3pfg%': '.342',
#   'rebounds': '3.2',
#   'assists': '7.6',
#   'steals': '1.2',
#   'blocks': '0.5',
#   'points_per_game': '23.0'},
#  {'name': 'Tim Frazier',
#   'team': 'MEM',
#   'year': 2021,
#   'games_played': '3',
#   'mpg': '11.0',
#   'fg%': '.250',
#   '3pfg%': '.000',
#   'rebounds': '1.3',
#   'assists': '2.3',
#   'steals': '0.3',
#   'blocks': '0.0',
#   'points_per_game': '1.3'},
#  {'name': 'Markelle Fultz',
#   'team': 'ORL',
#   'year': 2021,
#   'games_played': '8',
#   'mpg': '26.9',
#   'fg%': '.394',
#   '3pfg%': '.250',
#   'rebounds': '3.1',
#   'assists': '5.4',
#   'steals': '1.0',
#   'blocks': '0.3',
#   'points_per_game': '12.9'},
#  {'name': 'Wenyen Gabriel',
#   'team': 'NOP',
#   'year': 2021,
#   'games_played': '4',
#   'mpg': '3.0',
#   'fg%': '.000',
#   '3pfg%': '.000',
#   'rebounds': '1.3',
#   'assists': '0.3',
#   'steals': '0.0',
#   'blocks': '0.0',
#   'points_per_game': '0.0'},
#  {'name': 'Daniel Gafford',
#   'team': 'CHI',
#   'year': 2021,
#   'games_played': '26',
#   'mpg': '13.2',
#   'fg%': '.667',
#   '3pfg%': '',
#   'rebounds': '3.2',
#   'assists': '0.6',
#   'steals': '0.4',
#   'blocks': '1.2',
#   'points_per_game': '4.8'},
#  {'name': 'Danilo Gallinari',
#   'team': 'ATL',
#   'year': 2021,
#   'games_played': '24',
#   'mpg': '21.9',
#   'fg%': '.391',
#   '3pfg%': '.388',
#   'rebounds': '3.4',
#   'assists': '1.5',
#   'steals': '0.5',
#   'blocks': '0.1',
#   'points_per_game': '11.7'},
#  {'name': 'Langston Galloway',
#   'team': 'PHO',
#   'year': 2021,
#   'games_played': '25',
#   'mpg': '10.5',
#   'fg%': '.463',
#   '3pfg%': '.457',
#   'rebounds': '1.0',
#   'assists': '0.6',
#   'steals': '0.2',
#   'blocks': '0.0',
#   'points_per_game': '4.5'},
#  {'name': 'Darius Garland',
#   'team': 'CLE',
#   'year': 2021,
#   'games_played': '28',
#   'mpg': '32.9',
#   'fg%': '.440',
#   '3pfg%': '.384',
#   'rebounds': '2.2',
#   'assists': '5.9',
#   'steals': '1.2',
#   'blocks': '0.1',
#   'points_per_game': '16.1'},
#  {'name': 'Marc Gasol',
#   'team': 'LAL',
#   'year': 2021,
#   'games_played': '35',
#   'mpg': '20.1',
#   'fg%': '.403',
#   '3pfg%': '.365',
#   'rebounds': '4.1',
#   'assists': '2.0',
#   'steals': '0.5',
#   'blocks': '1.3',
#   'points_per_game': '4.8'},
#  {'name': 'Rudy Gay',
#   'team': 'SAS',
#   'year': 2021,
#   'games_played': '27',
#   'mpg': '22.1',
#   'fg%': '.415',
#   '3pfg%': '.373',
#   'rebounds': '5.3',
#   'assists': '1.5',
#   'steals': '0.8',
#   'blocks': '0.5',
#   'points_per_game': '11.2'},
#  {'name': 'Paul George',
#   'team': 'LAC',
#   'year': 2021,
#   'games_played': '27',
#   'mpg': '33.5',
#   'fg%': '.499',
#   '3pfg%': '.450',
#   'rebounds': '6.1',
#   'assists': '5.4',
#   'steals': '1.1',
#   'blocks': '0.5',
#   'points_per_game': '23.7'},
#  {'name': 'Taj Gibson',
#   'team': 'NYK',
#   'year': 2021,
#   'games_played': '12',
#   'mpg': '15.1',
#   'fg%': '.581',
#   '3pfg%': '.286',
#   'rebounds': '4.3',
#   'assists': '0.5',
#   'steals': '0.4',
#   'blocks': '0.3',
#   'points_per_game': '3.8'},
#  {'name': 'Harry Giles',
#   'team': 'POR',
#   'year': 2021,
#   'games_played': '22',
#   'mpg': '11.8',
#   'fg%': '.419',
#   '3pfg%': '.375',
#   'rebounds': '4.9',
#   'assists': '0.9',
#   'steals': '0.2',
#   'blocks': '0.4',
#   'points_per_game': '3.1'},
#  {'name': 'Shai Gilgeous-Alexander',
#   'team': 'OKC',
#   'year': 2021,
#   'games_played': '30',
#   'mpg': '34.0',
#   'fg%': '.511',
#   '3pfg%': '.412',
#   'rebounds': '5.1',
#   'assists': '6.2',
#   'steals': '0.8',
#   'blocks': '0.7',
#   'points_per_game': '23.2'},
#  {'name': 'Anthony Gill',
#   'team': 'WAS',
#   'year': 2021,
#   'games_played': '12',
#   'mpg': '5.6',
#   'fg%': '.300',
#   '3pfg%': '.143',
#   'rebounds': '1.6',
#   'assists': '0.3',
#   'steals': '0.3',
#   'blocks': '0.2',
#   'points_per_game': '0.8'},
#  {'name': 'Rudy Gobert',
#   'team': 'UTA',
#   'year': 2021,
#   'games_played': '36',
#   'mpg': '30.7',
#   'fg%': '.641',
#   '3pfg%': '.000',
#   'rebounds': '13.1',
#   'assists': '1.3',
#   'steals': '0.5',
#   'blocks': '2.7',
#   'points_per_game': '14.2'},
#  {'name': 'Brandon Goodwin',
#   'team': 'ATL',
#   'year': 2021,
#   'games_played': '24',
#   'mpg': '12.0',
#   'fg%': '.330',
#   '3pfg%': '.283',
#   'rebounds': '1.1',
#   'assists': '1.8',
#   'steals': '0.4',
#   'blocks': '0.0',
#   'points_per_game': '4.3'},
#  {'name': 'Aaron Gordon',
#   'team': 'ORL',
#   'year': 2021,
#   'games_played': '19',
#   'mpg': '29.1',
#   'fg%': '.427',
#   '3pfg%': '.369',
#   'rebounds': '7.2',
#   'assists': '4.2',
#   'steals': '0.7',
#   'blocks': '0.8',
#   'points_per_game': '13.8'},
#  {'name': 'Eric Gordon',
#   'team': 'HOU',
#   'year': 2021,
#   'games_played': '26',
#   'mpg': '29.3',
#   'fg%': '.437',
#   '3pfg%': '.328',
#   'rebounds': '2.2',
#   'assists': '2.7',
#   'steals': '0.5',
#   'blocks': '0.5',
#   'points_per_game': '17.8'},
#  {'name': "Devonte' Graham",
#   'team': 'CHO',
#   'year': 2021,
#   'games_played': '25',
#   'mpg': '32.8',
#   'fg%': '.352',
#   '3pfg%': '.347',
#   'rebounds': '3.0',
#   'assists': '5.7',
#   'steals': '1.0',
#   'blocks': '0.0',
#   'points_per_game': '13.7'},
#  {'name': 'Jerami Grant',
#   'team': 'DET',
#   'year': 2021,
#   'games_played': '33',
#   'mpg': '36.2',
#   'fg%': '.433',
#   '3pfg%': '.363',
#   'rebounds': '5.3',
#   'assists': '2.9',
#   'steals': '0.8',
#   'blocks': '1.1',
#   'points_per_game': '23.4'},
#  {'name': 'Danny Green',
#   'team': 'PHI',
#   'year': 2021,
#   'games_played': '36',
#   'mpg': '28.3',
#   'fg%': '.393',
#   '3pfg%': '.376',
#   'rebounds': '3.6',
#   'assists': '1.7',
#   'steals': '1.3',
#   'blocks': '0.8',
#   'points_per_game': '8.5'},
#  {'name': 'Draymond Green',
#   'team': 'GSW',
#   'year': 2021,
#   'games_played': '31',
#   'mpg': '29.6',
#   'fg%': '.391',
#   '3pfg%': '.237',
#   'rebounds': '6.1',
#   'assists': '8.6',
#   'steals': '1.4',
#   'blocks': '0.7',
#   'points_per_game': '5.7'},
#  {'name': 'JaMychal Green',
#   'team': 'DEN',
#   'year': 2021,
#   'games_played': '25',
#   'mpg': '20.5',
#   'fg%': '.444',
#   '3pfg%': '.427',
#   'rebounds': '6.0',
#   'assists': '1.0',
#   'steals': '0.6',
#   'blocks': '0.3',
#   'points_per_game': '9.1'},
#  {'name': 'Javonte Green',
#   'team': 'BOS',
#   'year': 2021,
#   'games_played': '22',
#   'mpg': '15.0',
#   'fg%': '.549',
#   '3pfg%': '.318',
#   'rebounds': '2.3',
#   'assists': '0.5',
#   'steals': '0.8',
#   'blocks': '0.1',
#   'points_per_game': '4.8'},
#  {'name': 'Jeff Green',
#   'team': 'BRK',
#   'year': 2021,
#   'games_played': '33',
#   'mpg': '26.4',
#   'fg%': '.507',
#   '3pfg%': '.422',
#   'rebounds': '3.6',
#   'assists': '1.4',
#   'steals': '0.7',
#   'blocks': '0.2',
#   'points_per_game': '9.5'},
#  {'name': 'Josh Green',
#   'team': 'DAL',
#   'year': 2021,
#   'games_played': '17',
#   'mpg': '12.5',
#   'fg%': '.472',
#   '3pfg%': '.167',
#   'rebounds': '2.3',
#   'assists': '0.6',
#   'steals': '0.2',
#   'blocks': '0.1',
#   'points_per_game': '2.5'},
#  {'name': 'Blake Griffin',
#   'team': 'DET',
#   'year': 2021,
#   'games_played': '20',
#   'mpg': '31.3',
#   'fg%': '.365',
#   '3pfg%': '.315',
#   'rebounds': '5.2',
#   'assists': '3.9',
#   'steals': '0.7',
#   'blocks': '0.1',
#   'points_per_game': '12.3'},
#  {'name': 'Kyle Guy',
#   'team': 'SAC',
#   'year': 2021,
#   'games_played': '14',
#   'mpg': '8.2',
#   'fg%': '.318',
#   '3pfg%': '.250',
#   'rebounds': '1.0',
#   'assists': '1.1',
#   'steals': '0.3',
#   'blocks': '0.0',
#   'points_per_game': '2.9'},
#  {'name': 'Rui Hachimura',
#   'team': 'WAS',
#   'year': 2021,
#   'games_played': '28',
#   'mpg': '29.9',
#   'fg%': '.451',
#   '3pfg%': '.306',
#   'rebounds': '5.5',
#   'assists': '1.7',
#   'steals': '0.7',
#   'blocks': '0.1',
#   'points_per_game': '12.4'},
#  {'name': 'Ashton Hagans',
#   'team': 'MIN',
#   'year': 2021,
#   'games_played': '2',
#   'mpg': '2.0',
#   'fg%': '',
#   '3pfg%': '',
#   'rebounds': '0.0',
#   'assists': '0.0',
#   'steals': '0.0',
#   'blocks': '0.0',
#   'points_per_game': '0.0'},
#  {'name': 'Tyrese Haliburton',
#   'team': 'SAC',
#   'year': 2021,
#   'games_played': '30',
#   'mpg': '30.1',
#   'fg%': '.494',
#   '3pfg%': '.433',
#   'rebounds': '3.6',
#   'assists': '5.4',
#   'steals': '1.4',
#   'blocks': '0.6',
#   'points_per_game': '13.2'},
#  {'name': 'Josh Hall',
#   'team': 'OKC',
#   'year': 2021,
#   'games_played': '7',
#   'mpg': '7.3',
#   'fg%': '.222',
#   '3pfg%': '.125',
#   'rebounds': '1.3',
#   'assists': '1.0',
#   'steals': '0.0',
#   'blocks': '0.0',
#   'points_per_game': '1.7'},
#  {'name': 'R.J. Hampton',
#   'team': 'DEN',
#   'year': 2021,
#   'games_played': '24',
#   'mpg': '9.2',
#   'fg%': '.414',
#   '3pfg%': '.278',
#   'rebounds': '2.0',
#   'assists': '0.5',
#   'steals': '0.2',
#   'blocks': '0.1',
#   'points_per_game': '2.5'},
#  {'name': 'Tim Hardaway Jr.',
#   'team': 'DAL',
#   'year': 2021,
#   'games_played': '34',
#   'mpg': '29.4',
#   'fg%': '.434',
#   '3pfg%': '.380',
#   'rebounds': '3.1',
#   'assists': '1.7',
#   'steals': '0.6',
#   'blocks': '0.2',
#   'points_per_game': '16.2'},
#  {'name': 'James Harden',
#   'team': 'TOT',
#   'year': 2021,
#   'games_played': '31',
#   'mpg': '37.8',
#   'fg%': '.484',
#   '3pfg%': '.401',
#   'rebounds': '7.8',
#   'assists': '11.1',
#   'steals': '1.2',
#   'blocks': '0.7',
#   'points_per_game': '25.3'},
#  {'name': 'Maurice Harkless',
#   'team': 'MIA',
#   'year': 2021,
#   'games_played': '10',
#   'mpg': '10.9',
#   'fg%': '.400',
#   '3pfg%': '.500',
#   'rebounds': '0.9',
#   'assists': '0.7',
#   'steals': '0.2',
#   'blocks': '0.3',
#   'points_per_game': '1.2'},
#  {'name': 'Jared Harper',
#   'team': 'NYK',
#   'year': 2021,
#   'games_played': '2',
#   'mpg': '2.5',
#   'fg%': '.000',
#   '3pfg%': '',
#   'rebounds': '0.0',
#   'assists': '0.0',
#   'steals': '0.0',
#   'blocks': '0.0',
#   'points_per_game': '1.0'},
#  {'name': 'Montrezl Harrell',
#   'team': 'LAL',
#   'year': 2021,
#   'games_played': '37',
#   'mpg': '24.1',
#   'fg%': '.626',
#   '3pfg%': '.000',
#   'rebounds': '6.4',
#   'assists': '1.1',
#   'steals': '0.6',
#   'blocks': '0.7',
#   'points_per_game': '13.8'},
#  {'name': 'Gary Harris',
#   'team': 'DEN',
#   'year': 2021,
#   'games_played': '19',
#   'mpg': '30.6',
#   'fg%': '.442',
#   '3pfg%': '.320',
#   'rebounds': '2.5',
#   'assists': '1.7',
#   'steals': '0.9',
#   'blocks': '0.2',
#   'points_per_game': '9.7'},
#  {'name': 'Jalen Harris',
#   'team': 'TOR',
#   'year': 2021,
#   'games_played': '2',
#   'mpg': '2.0',
#   'fg%': '',
#   '3pfg%': '',
#   'rebounds': '0.5',
#   'assists': '0.0',
#   'steals': '0.0',
#   'blocks': '0.0',
#   'points_per_game': '0.0'},
#  {'name': 'Joe Harris',
#   'team': 'BRK',
#   'year': 2021,
#   'games_played': '37',
#   'mpg': '30.9',
#   'fg%': '.530',
#   '3pfg%': '.506',
#   'rebounds': '3.5',
#   'assists': '1.8',
#   'steals': '0.5',
#   'blocks': '0.2',
#   'points_per_game': '14.8'},
#  {'name': 'Tobias Harris',
#   'team': 'PHI',
#   'year': 2021,
#   'games_played': '31',
#   'mpg': '34.4',
#   'fg%': '.513',
#   '3pfg%': '.402',
#   'rebounds': '7.6',
#   'assists': '3.4',
#   'steals': '0.8',
#   'blocks': '0.8',
#   'points_per_game': '20.2'},
#  {'name': 'Shaquille Harrison',
#   'team': 'UTA',
#   'year': 2021,
#   'games_played': '17',
#   'mpg': '3.3',
#   'fg%': '.300',
#   '3pfg%': '.000',
#   'rebounds': '0.5',
#   'assists': '0.5',
#   'steals': '0.1',
#   'blocks': '0.0',
#   'points_per_game': '1.0'},
#  {'name': 'Josh Hart',
#   'team': 'NOP',
#   'year': 2021,
#   'games_played': '36',
#   'mpg': '28.7',
#   'fg%': '.447',
#   '3pfg%': '.333',
#   'rebounds': '7.3',
#   'assists': '2.1',
#   'steals': '0.8',
#   'blocks': '0.3',
#   'points_per_game': '9.2'},
#  {'name': 'Isaiah Hartenstein',
#   'team': 'DEN',
#   'year': 2021,
#   'games_played': '26',
#   'mpg': '9.3',
#   'fg%': '.513',
#   '3pfg%': '',
#   'rebounds': '2.8',
#   'assists': '0.5',
#   'steals': '0.4',
#   'blocks': '0.6',
#   'points_per_game': '3.8'},
#  {'name': 'Jaxson Hayes',
#   'team': 'NOP',
#   'year': 2021,
#   'games_played': '25',
#   'mpg': '12.4',
#   'fg%': '.676',
#   '3pfg%': '',
#   'rebounds': '3.6',
#   'assists': '0.4',
#   'steals': '0.4',
#   'blocks': '0.5',
#   'points_per_game': '4.4'},
#  {'name': 'Killian Hayes',
#   'team': 'DET',
#   'year': 2021,
#   'games_played': '7',
#   'mpg': '21.1',
#   'fg%': '.277',
#   '3pfg%': '.250',
#   'rebounds': '1.1',
#   'assists': '3.6',
#   'steals': '0.3',
#   'blocks': '0.0',
#   'points_per_game': '4.6'},
#  {'name': 'Gordon Hayward',
#   'team': 'CHO',
#   'year': 2021,
#   'games_played': '31',
#   'mpg': '34.8',
#   'fg%': '.487',
#   '3pfg%': '.405',
#   'rebounds': '5.4',
#   'assists': '3.9',
#   'steals': '1.3',
#   'blocks': '0.4',
#   'points_per_game': '21.5'},
#  {'name': 'Juan Hernangómez',
#   'team': 'MIN',
#   'year': 2021,
#   'games_played': '17',
#   'mpg': '15.9',
#   'fg%': '.400',
#   '3pfg%': '.302',
#   'rebounds': '4.4',
#   'assists': '0.6',
#   'steals': '0.4',
#   'blocks': '0.1',
#   'points_per_game': '5.9'},
# ...
#  {'name': 'Max Strus',
#   'team': 'MIA',
#   'year': 2021,
#   'games_played': '19',
#   'mpg': '14.9',
#   'fg%': '.456',
#   '3pfg%': '.365',
#   'rebounds': '1.1',
#   'assists': '0.5',
#   'steals': '0.2',
#   'blocks': '0.0',
#   'points_per_game': '7.1'},
#  {'name': 'Edmond Sumner',
#   'team': 'IND',
#   'year': 2021,
#   'games_played': '22',
#   'mpg': '11.4',
#   'fg%': '.512',
#   '3pfg%': '.346',
#   'rebounds': '1.4',
#   'assists': '0.5',
#   'steals': '0.6',
#   'blocks': '0.1',
#   'points_per_game': '5.1'},
#  {'name': "Jae'Sean Tate",
#   'team': 'HOU',
#   'year': 2021,
#   'games_played': '34',
#   'mpg': '27.4',
#   'fg%': '.536',
#   '3pfg%': '.319',
#   'rebounds': '5.3',
#   'assists': '1.7',
#   'steals': '0.9',
#   'blocks': '0.5',
#   'points_per_game': '9.9'},
#  {'name': 'Jayson Tatum',
#   'team': 'BOS',
#   'year': 2021,
#   'games_played': '31',
#   'mpg': '35.8',
#   'fg%': '.437',
#   '3pfg%': '.368',
#   'rebounds': '7.1',
#   'assists': '4.5',
#   'steals': '1.4',
#   'blocks': '0.5',
#   'points_per_game': '24.9'},
#  {'name': 'Jeff Teague',
#   'team': 'BOS',
#   'year': 2021,
#   'games_played': '28',
#   'mpg': '18.1',
#   'fg%': '.373',
#   '3pfg%': '.422',
#   'rebounds': '1.6',
#   'assists': '2.1',
#   'steals': '0.8',
#   'blocks': '0.2',
#   'points_per_game': '6.4'},
#  {'name': 'Garrett Temple',
#   'team': 'CHI',
#   'year': 2021,
#   'games_played': '33',
#   'mpg': '28.4',
#   'fg%': '.428',
#   '3pfg%': '.344',
#   'rebounds': '3.2',
#   'assists': '2.1',
#   'steals': '0.9',
#   'blocks': '0.5',
#   'points_per_game': '8.8'},
#  {'name': 'Tyrell Terry',
#   'team': 'DAL',
#   'year': 2021,
#   'games_played': '11',
#   'mpg': '5.1',
#   'fg%': '.313',
#   '3pfg%': '.000',
#   'rebounds': '0.5',
#   'assists': '0.5',
#   'steals': '0.5',
#   'blocks': '0.0',
#   'points_per_game': '1.0'},
#  {'name': 'Daniel Theis',
#   'team': 'BOS',
#   'year': 2021,
#   'games_played': '34',
#   'mpg': '24.3',
#   'fg%': '.564',
#   '3pfg%': '.370',
#   'rebounds': '5.0',
#   'assists': '1.4',
#   'steals': '0.6',
#   'blocks': '1.1',
#   'points_per_game': '9.3'},
#  {'name': 'Brodric Thomas',
#   'team': 'HOU',
#   'year': 2021,
#   'games_played': '4',
#   'mpg': '6.0',
#   'fg%': '.286',
#   '3pfg%': '.167',
#   'rebounds': '1.0',
#   'assists': '1.0',
#   'steals': '0.3',
#   'blocks': '0.3',
#   'points_per_game': '2.5'},
#  {'name': 'Matt Thomas',
#   'team': 'TOR',
#   'year': 2021,
#   'games_played': '21',
#   'mpg': '6.9',
#   'fg%': '.391',
#   '3pfg%': '.387',
#   'rebounds': '0.7',
#   'assists': '0.4',
#   'steals': '0.1',
#   'blocks': '0.0',
#   'points_per_game': '2.5'},
#  {'name': 'Tristan Thompson',
#   'team': 'BOS',
#   'year': 2021,
#   'games_played': '34',
#   'mpg': '22.8',
#   'fg%': '.531',
#   '3pfg%': '.000',
#   'rebounds': '8.3',
#   'assists': '1.0',
#   'steals': '0.4',
#   'blocks': '0.4',
#   'points_per_game': '7.9'},
#  {'name': 'Sindarius Thornwell',
#   'team': 'NOP',
#   'year': 2021,
#   'games_played': '11',
#   'mpg': '4.8',
#   'fg%': '.462',
#   '3pfg%': '.500',
#   'rebounds': '0.3',
#   'assists': '0.2',
#   'steals': '0.4',
#   'blocks': '0.0',
#   'points_per_game': '1.4'},
#  {'name': 'Matisse Thybulle',
#   'team': 'PHI',
#   'year': 2021,
#   'games_played': '33',
#   'mpg': '18.1',
#   'fg%': '.368',
#   '3pfg%': '.262',
#   'rebounds': '1.5',
#   'assists': '0.9',
#   'steals': '1.4',
#   'blocks': '0.9',
#   'points_per_game': '3.1'},
#  {'name': 'Killian Tillie',
#   'team': 'MEM',
#   'year': 2021,
#   'games_played': '2',
#   'mpg': '10.5',
#   'fg%': '.250',
#   '3pfg%': '.500',
#   'rebounds': '1.0',
#   'assists': '0.0',
#   'steals': '0.5',
#   'blocks': '0.0',
#   'points_per_game': '1.5'},
#  {'name': 'Xavier Tillman Sr.',
#   'team': 'MEM',
#   'year': 2021,
#   'games_played': '28',
#   'mpg': '20.3',
#   'fg%': '.512',
#   '3pfg%': '.278',
#   'rebounds': '4.6',
#   'assists': '1.6',
#   'steals': '0.9',
#   'blocks': '0.6',
#   'points_per_game': '7.0'},
#  {'name': 'Obi Toppin',
#   'team': 'NYK',
#   'year': 2021,
#   'games_played': '27',
#   'mpg': '12.7',
#   'fg%': '.486',
#   '3pfg%': '.295',
#   'rebounds': '2.5',
#   'assists': '0.6',
#   'steals': '0.3',
#   'blocks': '0.4',
#   'points_per_game': '4.7'},
#  {'name': 'Juan Toscano-Anderson',
#   'team': 'GSW',
#   'year': 2021,
#   'games_played': '23',
#   'mpg': '20.6',
#   'fg%': '.564',
#   '3pfg%': '.429',
#   'rebounds': '4.5',
#   'assists': '2.2',
#   'steals': '0.6',
#   'blocks': '0.5',
#   'points_per_game': '5.8'},
#  {'name': 'Karl-Anthony Towns',
#   'team': 'MIN',
#   'year': 2021,
#   'games_played': '16',
#   'mpg': '32.8',
#   'fg%': '.494',
#   '3pfg%': '.375',
#   'rebounds': '10.9',
#   'assists': '3.9',
#   'steals': '0.9',
#   'blocks': '1.7',
#   'points_per_game': '22.0'},
#  {'name': 'Gary Trent Jr.',
#   'team': 'POR',
#   'year': 2021,
#   'games_played': '33',
#   'mpg': '31.2',
#   'fg%': '.423',
#   '3pfg%': '.406',
#   'rebounds': '2.2',
#   'assists': '1.5',
#   'steals': '0.8',
#   'blocks': '0.2',
#   'points_per_game': '15.2'},
#  {'name': 'P.J. Tucker',
#   'team': 'HOU',
#   'year': 2021,
#   'games_played': '32',
#   'mpg': '30.0',
#   'fg%': '.366',
#   '3pfg%': '.314',
#   'rebounds': '4.6',
#   'assists': '1.4',
#   'steals': '0.9',
#   'blocks': '0.6',
#   'points_per_game': '4.4'},
#  {'name': 'Myles Turner',
#   'team': 'IND',
#   'year': 2021,
#   'games_played': '33',
#   'mpg': '31.5',
#   'fg%': '.484',
#   '3pfg%': '.314',
#   'rebounds': '6.5',
#   'assists': '0.9',
#   'steals': '1.0',
#   'blocks': '3.4',
#   'points_per_game': '13.5'},
#  {'name': 'Jonas Valančiūnas',
#   'team': 'MEM',
#   'year': 2021,
#   'games_played': '28',
#   'mpg': '27.4',
#   'fg%': '.541',
#   '3pfg%': '.333',
#   'rebounds': '11.6',
#   'assists': '1.8',
#   'steals': '0.6',
#   'blocks': '0.8',
#   'points_per_game': '16.0'},
#  {'name': 'Denzel Valentine',
#   'team': 'CHI',
#   'year': 2021,
#   'games_played': '30',
#   'mpg': '19.7',
#   'fg%': '.375',
#   '3pfg%': '.348',
#   'rebounds': '4.1',
#   'assists': '1.8',
#   'steals': '0.7',
#   'blocks': '0.0',
#   'points_per_game': '8.0'},
#  {'name': 'Jarred Vanderbilt',
#   'team': 'MIN',
#   'year': 2021,
#   'games_played': '34',
#   'mpg': '19.2',
#   'fg%': '.612',
#   '3pfg%': '.500',
#   'rebounds': '5.7',
#   'assists': '1.5',
#   'steals': '1.1',
#   'blocks': '0.6',
#   'points_per_game': '6.1'},
#  {'name': 'Fred VanVleet',
#   'team': 'TOR',
#   'year': 2021,
#   'games_played': '34',
#   'mpg': '36.7',
#   'fg%': '.400',
#   '3pfg%': '.383',
#   'rebounds': '4.4',
#   'assists': '6.6',
#   'steals': '1.7',
#   'blocks': '0.8',
#   'points_per_game': '20.1'},
#  {'name': 'Devin Vassell',
#   'team': 'SAS',
#   'year': 2021,
#   'games_played': '26',
#   'mpg': '17.3',
#   'fg%': '.397',
#   '3pfg%': '.397',
#   'rebounds': '3.2',
#   'assists': '1.1',
#   'steals': '1.1',
#   'blocks': '0.3',
#   'points_per_game': '5.5'},
#  {'name': 'Gabe Vincent',
#   'team': 'MIA',
#   'year': 2021,
#   'games_played': '25',
#   'mpg': '15.0',
#   'fg%': '.364',
#   '3pfg%': '.258',
#   'rebounds': '1.1',
#   'assists': '1.2',
#   'steals': '0.5',
#   'blocks': '0.1',
#   'points_per_game': '5.8'},
#  {'name': 'Noah Vonleh',
#   'team': 'BRK',
#   'year': 2021,
#   'games_played': '4',
#   'mpg': '2.8',
#   'fg%': '.000',
#   '3pfg%': '.000',
#   'rebounds': '0.3',
#   'assists': '0.3',
#   'steals': '0.0',
#   'blocks': '0.0',
#   'points_per_game': '0.0'},
#  {'name': 'Nikola Vučević',
#   'team': 'ORL',
#   'year': 2021,
#   'games_played': '36',
#   'mpg': '33.9',
#   'fg%': '.483',
#   '3pfg%': '.412',
#   'rebounds': '11.6',
#   'assists': '3.7',
#   'steals': '1.0',
#   'blocks': '0.6',
#   'points_per_game': '24.6'},
#  {'name': 'Dean Wade',
#   'team': 'CLE',
#   'year': 2021,
#   'games_played': '28',
#   'mpg': '11.4',
#   'fg%': '.446',
#   '3pfg%': '.423',
#   'rebounds': '2.1',
#   'assists': '0.6',
#   'steals': '0.2',
#   'blocks': '0.2',
#   'points_per_game': '3.4'},
#  {'name': 'Moritz Wagner',
#   'team': 'WAS',
#   'year': 2021,
#   'games_played': '23',
#   'mpg': '14.7',
#   'fg%': '.509',
#   '3pfg%': '.308',
#   'rebounds': '3.0',
#   'assists': '1.2',
#   'steals': '0.7',
#   'blocks': '0.3',
#   'points_per_game': '7.1'},
#  {'name': 'Kemba Walker',
#   'team': 'BOS',
#   'year': 2021,
#   'games_played': '20',
#   'mpg': '30.0',
#   'fg%': '.388',
#   '3pfg%': '.366',
#   'rebounds': '3.6',
#   'assists': '4.6',
#   'steals': '1.1',
#   'blocks': '0.4',
#   'points_per_game': '18.5'},
#  {'name': 'Lonnie Walker',
#   'team': 'SAS',
#   'year': 2021,
#   'games_played': '31',
#   'mpg': '27.0',
#   'fg%': '.407',
#   '3pfg%': '.362',
#   'rebounds': '2.8',
#   'assists': '1.7',
#   'steals': '0.5',
#   'blocks': '0.4',
#   'points_per_game': '11.3'},
#  {'name': 'John Wall',
#   'team': 'HOU',
#   'year': 2021,
#   'games_played': '25',
#   'mpg': '31.7',
#   'fg%': '.424',
#   '3pfg%': '.340',
#   'rebounds': '3.2',
#   'assists': '6.0',
#   'steals': '0.9',
#   'blocks': '0.7',
#   'points_per_game': '21.0'},
#  {'name': 'Brad Wanamaker',
#   'team': 'GSW',
#   'year': 2021,
#   'games_played': '37',
#   'mpg': '16.2',
#   'fg%': '.358',
#   '3pfg%': '.232',
#   'rebounds': '1.7',
#   'assists': '2.7',
#   'steals': '0.7',
#   'blocks': '0.2',
#   'points_per_game': '4.8'},
#  {'name': 'T.J. Warren',
#   'team': 'IND',
#   'year': 2021,
#   'games_played': '4',
#   'mpg': '29.3',
#   'fg%': '.529',
#   '3pfg%': '.000',
#   'rebounds': '3.5',
#   'assists': '1.3',
#   'steals': '0.5',
#   'blocks': '0.0',
#   'points_per_game': '15.5'},
#  {'name': 'P.J. Washington',
#   'team': 'CHO',
#   'year': 2021,
#   'games_played': '31',
#   'mpg': '29.4',
#   'fg%': '.449',
#   '3pfg%': '.385',
#   'rebounds': '6.3',
#   'assists': '2.9',
#   'steals': '1.1',
#   'blocks': '1.2',
#   'points_per_game': '12.5'},
#  {'name': 'Yuta Watanabe',
#   'team': 'TOR',
#   'year': 2021,
#   'games_played': '22',
#   'mpg': '12.2',
#   'fg%': '.333',
#   '3pfg%': '.364',
#   'rebounds': '3.2',
#   'assists': '0.4',
#   'steals': '0.4',
#   'blocks': '0.5',
#   'points_per_game': '2.7'},
#  {'name': 'Tremont Waters',
#   'team': 'BOS',
#   'year': 2021,
#   'games_played': '10',
#   'mpg': '9.8',
#   'fg%': '.323',
#   '3pfg%': '.400',
#   'rebounds': '0.8',
#   'assists': '3.0',
#   'steals': '0.6',
#   'blocks': '0.0',
#   'points_per_game': '3.3'},
#  {'name': 'Paul Watson',
#   'team': 'TOR',
#   'year': 2021,
#   'games_played': '16',
#   'mpg': '4.6',
#   'fg%': '.500',
#   '3pfg%': '.529',
#   'rebounds': '0.9',
#   'assists': '0.1',
#   'steals': '0.0',
#   'blocks': '0.1',
#   'points_per_game': '1.8'},
#  {'name': 'Quinndary Weatherspoon',
#   'team': 'SAS',
#   'year': 2021,
#   'games_played': '5',
#   'mpg': '4.8',
#   'fg%': '.200',
#   '3pfg%': '.000',
#   'rebounds': '0.4',
#   'assists': '0.6',
#   'steals': '0.2',
#   'blocks': '0.0',
#   'points_per_game': '0.8'},
#  {'name': 'Russell Westbrook',
#   'team': 'WAS',
#   'year': 2021,
#   'games_played': '28',
#   'mpg': '34.3',
#   'fg%': '.432',
#   '3pfg%': '.286',
#   'rebounds': '9.6',
#   'assists': '9.8',
#   'steals': '1.2',
#   'blocks': '0.3',
#   'points_per_game': '20.3'},
#  {'name': 'Coby White',
#   'team': 'CHI',
#   'year': 2021,
#   'games_played': '34',
#   'mpg': '33.2',
#   'fg%': '.420',
#   '3pfg%': '.354',
#   'rebounds': '5.1',
#   'assists': '5.0',
#   'steals': '0.4',
#   'blocks': '0.1',
#   'points_per_game': '16.2'},
#  {'name': 'Derrick White',
#   'team': 'SAS',
#   'year': 2021,
#   'games_played': '9',
#   'mpg': '24.0',
#   'fg%': '.372',
#   '3pfg%': '.313',
#   'rebounds': '1.6',
#   'assists': '3.6',
#   'steals': '0.9',
#   'blocks': '1.0',
#   'points_per_game': '11.1'},
#  {'name': 'Hassan Whiteside',
#   'team': 'SAC',
#   'year': 2021,
#   'games_played': '23',
#   'mpg': '14.6',
#   'fg%': '.580',
#   '3pfg%': '.000',
#   'rebounds': '5.7',
#   'assists': '0.5',
#   'steals': '0.3',
#   'blocks': '1.3',
#   'points_per_game': '8.3'},
#  {'name': 'Greg Whittington',
#   'team': 'DEN',
#   'year': 2021,
#   'games_played': '2',
#   'mpg': '4.0',
#   'fg%': '.000',
#   '3pfg%': '.000',
#   'rebounds': '0.0',
#   'assists': '0.0',
#   'steals': '0.0',
#   'blocks': '0.0',
#   'points_per_game': '0.0'},
#  {'name': 'Andrew Wiggins',
#   'team': 'GSW',
#   'year': 2021,
#   'games_played': '37',
#   'mpg': '32.2',
#   'fg%': '.463',
#   '3pfg%': '.351',
#   'rebounds': '4.5',
#   'assists': '2.2',
#   'steals': '0.8',
#   'blocks': '1.1',
#   'points_per_game': '17.0'},
#  {'name': 'Grant Williams',
#   'team': 'BOS',
#   'year': 2021,
#   'games_played': '28',
#   'mpg': '18.5',
#   'fg%': '.470',
#   '3pfg%': '.433',
#   'rebounds': '2.9',
#   'assists': '0.9',
#   'steals': '0.5',
#   'blocks': '0.4',
#   'points_per_game': '5.3'},
#  {'name': 'Kenrich Williams',
#   'team': 'OKC',
#   'year': 2021,
#   'games_played': '36',
#   'mpg': '18.9',
#   'fg%': '.554',
#   '3pfg%': '.420',
#   'rebounds': '4.0',
#   'assists': '1.6',
#   'steals': '0.8',
#   'blocks': '0.2',
#   'points_per_game': '6.2'},
#  {'name': 'Lou Williams',
#   'team': 'LAC',
#   'year': 2021,
#   'games_played': '35',
#   'mpg': '22.7',
#   'fg%': '.422',
#   '3pfg%': '.398',
#   'rebounds': '2.3',
#   'assists': '3.7',
#   'steals': '0.9',
#   'blocks': '0.1',
#   'points_per_game': '12.5'},
#  {'name': 'Patrick Williams',
#   'team': 'CHI',
#   'year': 2021,
#   'games_played': '33',
#   'mpg': '28.5',
#   'fg%': '.474',
#   '3pfg%': '.390',
#   'rebounds': '4.8',
#   'assists': '1.2',
#   'steals': '0.7',
#   'blocks': '0.8',
#   'points_per_game': '10.2'},
#  {'name': 'Robert Williams',
#   'team': 'BOS',
#   'year': 2021,
#   'games_played': '29',
#   'mpg': '16.1',
#   'fg%': '.721',
#   '3pfg%': '.000',
#   'rebounds': '5.9',
#   'assists': '1.1',
#   'steals': '0.9',
#   'blocks': '1.4',
#   'points_per_game': '6.9'},
#  {'name': 'Zion Williamson',
#   'team': 'NOP',
#   'year': 2021,
#   'games_played': '34',
#   'mpg': '33.1',
#   'fg%': '.614',
#   '3pfg%': '.316',
#   'rebounds': '7.2',
#   'assists': '3.4',
#   'steals': '0.9',
#   'blocks': '0.7',
#   'points_per_game': '25.6'},
#  {'name': 'D.J. Wilson',
#   'team': 'MIL',
#   'year': 2021,
#   'games_played': '11',
#   'mpg': '9.0',
#   'fg%': '.366',
#   '3pfg%': '.346',
#   'rebounds': '2.1',
#   'assists': '0.3',
#   'steals': '0.1',
#   'blocks': '0.4',
#   'points_per_game': '3.6'},
#  {'name': 'Dylan Windler',
#   'team': 'CLE',
#   'year': 2021,
#   'games_played': '22',
#   'mpg': '19.0',
#   'fg%': '.456',
#   '3pfg%': '.365',
#   'rebounds': '4.1',
#   'assists': '1.3',
#   'steals': '0.7',
#   'blocks': '0.5',
#   'points_per_game': '6.3'},
#  {'name': 'Justise Winslow',
#   'team': 'MEM',
#   'year': 2021,
#   'games_played': '7',
#   'mpg': '22.3',
#   'fg%': '.364',
#   '3pfg%': '.188',
#   'rebounds': '5.3',
#   'assists': '1.9',
#   'steals': '0.4',
#   'blocks': '0.7',
#   'points_per_game': '9.4'},
#  {'name': 'Cassius Winston',
#   'team': 'WAS',
#   'year': 2021,
#   'games_played': '6',
#   'mpg': '7.3',
#   'fg%': '.400',
#   '3pfg%': '.429',
#   'rebounds': '0.7',
#   'assists': '1.0',
#   'steals': '0.0',
#   'blocks': '0.2',
#   'points_per_game': '2.2'},
#  {'name': 'James Wiseman',
#   'team': 'GSW',
#   'year': 2021,
#   'games_played': '26',
#   'mpg': '20.8',
#   'fg%': '.510',
#   '3pfg%': '.370',
#   'rebounds': '5.9',
#   'assists': '0.7',
#   'steals': '0.3',
#   'blocks': '1.1',
#   'points_per_game': '11.8'},
#  {'name': 'Christian Wood',
#   'team': 'HOU',
#   'year': 2021,
#   'games_played': '17',
#   'mpg': '31.2',
#   'fg%': '.558',
#   '3pfg%': '.421',
#   'rebounds': '10.2',
#   'assists': '1.3',
#   'steals': '0.9',
#   'blocks': '1.5',
#   'points_per_game': '22.0'},
#  {'name': 'Robert Woodard',
#   'team': 'SAC',
#   'year': 2021,
#   'games_played': '6',
#   'mpg': '2.8',
#   'fg%': '.545',
#   '3pfg%': '.333',
#   'rebounds': '1.3',
#   'assists': '0.0',
#   'steals': '0.0',
#   'blocks': '0.0',
#   'points_per_game': '2.2'},
#  {'name': 'Delon Wright',
#   'team': 'DET',
#   'year': 2021,
#   'games_played': '29',
#   'mpg': '29.2',
#   'fg%': '.468',
#   '3pfg%': '.384',
#   'rebounds': '4.6',
#   'assists': '4.9',
#   'steals': '1.4',
#   'blocks': '0.5',
#   'points_per_game': '10.7'},
#  {'name': 'Thaddeus Young',
#   'team': 'CHI',
#   'year': 2021,
#   'games_played': '30',
#   'mpg': '25.3',
#   'fg%': '.609',
#   '3pfg%': '.227',
#   'rebounds': '5.9',
#   'assists': '4.4',
#   'steals': '1.4',
#   'blocks': '0.6',
#   'points_per_game': '12.1'},
#  {'name': 'Trae Young',
#   'team': 'ATL',
#   'year': 2021,
#   'games_played': '34',
#   'mpg': '34.8',
#   'fg%': '.430',
#   '3pfg%': '.378',
#   'rebounds': '4.2',
#   'assists': '9.4',
#   'steals': '0.9',
#   'blocks': '0.2',
#   'points_per_game': '26.4'},
#  {'name': 'Cody Zeller',
#   'team': 'CHO',
#   'year': 2021,
#   'games_played': '18',
#   'mpg': '23.4',
#   'fg%': '.514',
#   '3pfg%': '.158',
#   'rebounds': '7.6',
#   'assists': '2.4',
#   'steals': '0.6',
#   'blocks': '0.6',
#   'points_per_game': '9.7'},
#  {'name': 'Ivica Zubac',
#   'team': 'LAC',
#   'year': 2021,
#   'games_played': '38',
#   'mpg': '19.8',
#   'fg%': '.659',
#   '3pfg%': '.000',
#   'rebounds': '7.0',
#   'assists': '1.1',
#   'steals': '0.4',
#   'blocks': '0.8',
#   'points_per_game': '8.2'}]

# %% [markdown]
# Same as above, saving the scrape to a pandas df:

# %%
df_2021_basic = pd.DataFrame(players_2021_basic)
df_2021_basic
# Out:
#                   name team  year games_played   mpg   fg% 3pfg% rebounds  \
# 0     Precious Achiuwa  MIA  2021           35  14.0  .579            4.0
# 1         Jaylen Adams  MIL  2021            7   2.6  .125  .000      0.4
# 2         Steven Adams  NOP  2021           33  27.8  .615  .000      8.9
# 3          Bam Adebayo  MIA  2021           33  33.9  .563  .333      9.5
# 4    LaMarcus Aldridge  SAS  2021           21  25.9  .464  .360      4.5
# ..                 ...  ...   ...          ...   ...   ...   ...      ...
# 487       Delon Wright  DET  2021           29  29.2  .468  .384      4.6
# 488     Thaddeus Young  CHI  2021           30  25.3  .609  .227      5.9
# 489         Trae Young  ATL  2021           34  34.8  .430  .378      4.2
# 490        Cody Zeller  CHO  2021           18  23.4  .514  .158      7.6
# 491        Ivica Zubac  LAC  2021           38  19.8  .659  .000      7.0
#
#     assists steals blocks points_per_game
# 0       0.6    0.4    0.5             6.1
# 1       0.3    0.0    0.0             0.3
# 2       2.1    0.9    0.6             8.0
# 3       5.4    0.9    1.0            19.2
# 4       1.7    0.4    0.9            13.7
# ..      ...    ...    ...             ...
# 487     4.9    1.4    0.5            10.7
# 488     4.4    1.4    0.6            12.1
# 489     9.4    0.9    0.2            26.4
# 490     2.4    0.6    0.6             9.7
# 491     1.1    0.4    0.8             8.2
#
# [492 rows x 12 columns]

# %% [markdown]
# Now we will perform a separate scrap of the advanced statistics for each player over the past 30 years. Since the tables are organized in different orders on the basketball-reference website, it's important to include a common row to join on with our other scrapes, so once again we are making sure to include the player's name, team, and the year associated with the data. Also we will want to make sure to create our target variable by denoting a 1 to the player row if their scraped team is in the previous playoff teams dictionary from above (and a 0 if not).

# %%
#advanced stats ALL YEARS:
players_advanced = []
for i in reversed(range(1990, 2021)):
    year = i
    url = f'https://www.basketball-reference.com/leagues/NBA_{year}_advanced.html'
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'lxml')
    table = soup.find('table', {'id': 'advanced_stats'})
    for row in table.find('tbody').find_all('tr', {'class':'full_table'}):
        player = {}
        player['name'] = row.find('td', {'data-stat': 'player'}).text
        player['team'] = row.find('td', {'data-stat': 'team_id'}).text
        player['year'] = i
        player['position'] = row.find('td', {'data-stat': 'pos'}).text
        player['player_efficiency'] = row.find('td', {'data-stat': 'per'}).text
        player['true_shooting'] = row.find('td', {'data-stat': 'ts_pct'}).text
        player['plus_minus'] = row.find('td', {'data-stat': 'bpm'}).text
        player['win_shares_percentage'] = row.find('td', {'data-stat': 'ws_per_48'}).text
        player['in_playoff'] = 1 if player.get('team') in playoff_teams.get(str(year)) else 0
        players_advanced.append(player)

time.sleep(5)        
players_advanced
# Out:
# [{'name': 'Steven Adams',
#   'team': 'OKC',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '20.5',
#   'true_shooting': '.604',
#   'plus_minus': '2.9',
#   'win_shares_percentage': '.185',
#   'in_playoff': 1},
#  {'name': 'Bam Adebayo',
#   'team': 'MIA',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '20.3',
#   'true_shooting': '.598',
#   'plus_minus': '3.4',
#   'win_shares_percentage': '.168',
#   'in_playoff': 1},
#  {'name': 'LaMarcus Aldridge',
#   'team': 'SAS',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '19.7',
#   'true_shooting': '.571',
#   'plus_minus': '1.4',
#   'win_shares_percentage': '.122',
#   'in_playoff': 0},
#  {'name': 'Kyle Alexander',
#   'team': 'MIA',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '4.7',
#   'true_shooting': '.500',
#   'plus_minus': '-9.6',
#   'win_shares_percentage': '-0.003',
#   'in_playoff': 1},
#  {'name': 'Nickeil Alexander-Walker',
#   'team': 'NOP',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '8.9',
#   'true_shooting': '.473',
#   'plus_minus': '-4.6',
#   'win_shares_percentage': '-0.020',
#   'in_playoff': 0},
#  {'name': 'Grayson Allen',
#   'team': 'MEM',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '12.0',
#   'true_shooting': '.609',
#   'plus_minus': '-1.3',
#   'win_shares_percentage': '.082',
#   'in_playoff': 0},
#  {'name': 'Jarrett Allen',
#   'team': 'BRK',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '20.7',
#   'true_shooting': '.664',
#   'plus_minus': '2.3',
#   'win_shares_percentage': '.212',
#   'in_playoff': 1},
#  {'name': 'Kadeem Allen',
#   'team': 'NYK',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '14.0',
#   'true_shooting': '.512',
#   'plus_minus': '-0.7',
#   'win_shares_percentage': '.053',
#   'in_playoff': 0},
#  {'name': 'Al-Farouq Aminu',
#   'team': 'ORL',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '7.6',
#   'true_shooting': '.395',
#   'plus_minus': '-3.0',
#   'win_shares_percentage': '.014',
#   'in_playoff': 1},
#  {'name': 'Justin Anderson',
#   'team': 'BRK',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '3.2',
#   'true_shooting': '.352',
#   'plus_minus': '-7.7',
#   'win_shares_percentage': '-0.054',
#   'in_playoff': 1},
#  {'name': 'Kyle Anderson',
#   'team': 'MEM',
#   'year': 2020,
#   'position': 'SF',
#   'player_efficiency': '12.5',
#   'true_shooting': '.534',
#   'plus_minus': '0.5',
#   'win_shares_percentage': '.091',
#   'in_playoff': 0},
#  {'name': 'Ryan Anderson',
#   'team': 'HOU',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '9.4',
#   'true_shooting': '.357',
#   'plus_minus': '-2.8',
#   'win_shares_percentage': '-0.037',
#   'in_playoff': 1},
#  {'name': 'Giannis Antetokounmpo',
#   'team': 'MIL',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '31.9',
#   'true_shooting': '.613',
#   'plus_minus': '11.5',
#   'win_shares_percentage': '.279',
#   'in_playoff': 1},
#  {'name': 'Kostas Antetokounmpo',
#   'team': 'LAL',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '16.3',
#   'true_shooting': '.902',
#   'plus_minus': '-0.7',
#   'win_shares_percentage': '.193',
#   'in_playoff': 1},
#  {'name': 'Thanasis Antetokounmpo',
#   'team': 'MIL',
#   'year': 2020,
#   'position': 'SF',
#   'player_efficiency': '12.2',
#   'true_shooting': '.496',
#   'plus_minus': '-3.2',
#   'win_shares_percentage': '.070',
#   'in_playoff': 1},
#  {'name': 'Carmelo Anthony',
#   'team': 'POR',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '12.4',
#   'true_shooting': '.525',
#   'plus_minus': '-3.6',
#   'win_shares_percentage': '.033',
#   'in_playoff': 1},
#  {'name': 'OG Anunoby',
#   'team': 'TOR',
#   'year': 2020,
#   'position': 'SF',
#   'player_efficiency': '13.2',
#   'true_shooting': '.600',
#   'plus_minus': '1.2',
#   'win_shares_percentage': '.134',
#   'in_playoff': 1},
#  {'name': 'Ryan Arcidiacono',
#   'team': 'CHI',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '9.0',
#   'true_shooting': '.551',
#   'plus_minus': '-2.8',
#   'win_shares_percentage': '.071',
#   'in_playoff': 0},
#  {'name': 'Trevor Ariza',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'SF',
#   'player_efficiency': '11.0',
#   'true_shooting': '.593',
#   'plus_minus': '-0.5',
#   'win_shares_percentage': '.081',
#   'in_playoff': 0},
#  {'name': 'D.J. Augustin',
#   'team': 'ORL',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '14.0',
#   'true_shooting': '.554',
#   'plus_minus': '-1.6',
#   'win_shares_percentage': '.098',
#   'in_playoff': 1},
#  {'name': 'Deandre Ayton',
#   'team': 'PHO',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '20.0',
#   'true_shooting': '.568',
#   'plus_minus': '0.4',
#   'win_shares_percentage': '.121',
#   'in_playoff': 0},
#  {'name': 'Dwayne Bacon',
#   'team': 'CHO',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '6.1',
#   'true_shooting': '.419',
#   'plus_minus': '-6.8',
#   'win_shares_percentage': '-0.053',
#   'in_playoff': 0},
#  {'name': 'Marvin Bagley III',
#   'team': 'SAC',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '15.6',
#   'true_shooting': '.512',
#   'plus_minus': '-3.5',
#   'win_shares_percentage': '.051',
#   'in_playoff': 0},
#  {'name': 'Lonzo Ball',
#   'team': 'NOP',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '13.1',
#   'true_shooting': '.517',
#   'plus_minus': '0.6',
#   'win_shares_percentage': '.058',
#   'in_playoff': 0},
#  {'name': 'Mo Bamba',
#   'team': 'ORL',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '17.5',
#   'true_shooting': '.542',
#   'plus_minus': '0.4',
#   'win_shares_percentage': '.135',
#   'in_playoff': 1},
#  {'name': 'J.J. Barea',
#   'team': 'DAL',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '14.6',
#   'true_shooting': '.512',
#   'plus_minus': '-1.4',
#   'win_shares_percentage': '.072',
#   'in_playoff': 1},
#  {'name': 'Harrison Barnes',
#   'team': 'SAC',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '13.3',
#   'true_shooting': '.574',
#   'plus_minus': '-1.3',
#   'win_shares_percentage': '.088',
#   'in_playoff': 0},
#  {'name': 'RJ Barrett',
#   'team': 'NYK',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '10.7',
#   'true_shooting': '.479',
#   'plus_minus': '-4.3',
#   'win_shares_percentage': '-0.015',
#   'in_playoff': 0},
#  {'name': 'Will Barton',
#   'team': 'DEN',
#   'year': 2020,
#   'position': 'SF',
#   'player_efficiency': '15.6',
#   'true_shooting': '.549',
#   'plus_minus': '1.1',
#   'win_shares_percentage': '.106',
#   'in_playoff': 1},
#  {'name': 'Keita Bates-Diop',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'PF-SF',
#   'player_efficiency': '12.4',
#   'true_shooting': '.539',
#   'plus_minus': '-1.4',
#   'win_shares_percentage': '.078',
#   'in_playoff': 0},
#  {'name': 'Nicolas Batum',
#   'team': 'CHO',
#   'year': 2020,
#   'position': 'SF',
#   'player_efficiency': '9.2',
#   'true_shooting': '.463',
#   'plus_minus': '-1.9',
#   'win_shares_percentage': '.055',
#   'in_playoff': 0},
#  {'name': 'Aron Baynes',
#   'team': 'PHO',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '15.2',
#   'true_shooting': '.581',
#   'plus_minus': '-1.0',
#   'win_shares_percentage': '.107',
#   'in_playoff': 0},
#  {'name': 'Kent Bazemore',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'SF',
#   'player_efficiency': '9.3',
#   'true_shooting': '.499',
#   'plus_minus': '-3.1',
#   'win_shares_percentage': '.017',
#   'in_playoff': 0},
#  {'name': 'Darius Bazley',
#   'team': 'OKC',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '9.6',
#   'true_shooting': '.497',
#   'plus_minus': '-1.6',
#   'win_shares_percentage': '.041',
#   'in_playoff': 1},
#  {'name': 'Bradley Beal',
#   'team': 'WAS',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '23.2',
#   'true_shooting': '.579',
#   'plus_minus': '2.9',
#   'win_shares_percentage': '.118',
#   'in_playoff': 0},
#  {'name': 'Malik Beasley',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '12.7',
#   'true_shooting': '.546',
#   'plus_minus': '-2.1',
#   'win_shares_percentage': '.049',
#   'in_playoff': 0},
#  {'name': 'Marco Belinelli',
#   'team': 'SAS',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '10.8',
#   'true_shooting': '.532',
#   'plus_minus': '-2.7',
#   'win_shares_percentage': '.046',
#   'in_playoff': 0},
#  {'name': 'Jordan Bell',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '13.9',
#   'true_shooting': '.577',
#   'plus_minus': '-2.5',
#   'win_shares_percentage': '.070',
#   'in_playoff': 0},
#  {'name': "DeAndre' Bembry",
#   'team': 'ATL',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '9.6',
#   'true_shooting': '.500',
#   'plus_minus': '-2.5',
#   'win_shares_percentage': '.012',
#   'in_playoff': 0},
#  {'name': 'Dragan Bender',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'PF-C',
#   'player_efficiency': '10.9',
#   'true_shooting': '.545',
#   'plus_minus': '-3.0',
#   'win_shares_percentage': '.052',
#   'in_playoff': 0},
#  {'name': 'Dāvis Bertāns',
#   'team': 'WAS',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '15.5',
#   'true_shooting': '.628',
#   'plus_minus': '0.9',
#   'win_shares_percentage': '.107',
#   'in_playoff': 0},
#  {'name': 'Patrick Beverley',
#   'team': 'LAC',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '12.5',
#   'true_shooting': '.560',
#   'plus_minus': '2.2',
#   'win_shares_percentage': '.128',
#   'in_playoff': 1},
#  {'name': 'Khem Birch',
#   'team': 'ORL',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '11.7',
#   'true_shooting': '.566',
#   'plus_minus': '-2.4',
#   'win_shares_percentage': '.112',
#   'in_playoff': 1},
#  {'name': 'Goga Bitadze',
#   'team': 'IND',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '12.1',
#   'true_shooting': '.523',
#   'plus_minus': '-2.3',
#   'win_shares_percentage': '.067',
#   'in_playoff': 1},
#  {'name': 'Bismack Biyombo',
#   'team': 'CHO',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '16.1',
#   'true_shooting': '.570',
#   'plus_minus': '-2.5',
#   'win_shares_percentage': '.113',
#   'in_playoff': 0},
#  {'name': 'Nemanja Bjelica',
#   'team': 'SAC',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '15.7',
#   'true_shooting': '.602',
#   'plus_minus': '1.7',
#   'win_shares_percentage': '.127',
#   'in_playoff': 0},
#  {'name': 'Eric Bledsoe',
#   'team': 'MIL',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '17.6',
#   'true_shooting': '.571',
#   'plus_minus': '1.8',
#   'win_shares_percentage': '.157',
#   'in_playoff': 1},
#  {'name': 'Bogdan Bogdanović',
#   'team': 'SAC',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '15.1',
#   'true_shooting': '.565',
#   'plus_minus': '0.6',
#   'win_shares_percentage': '.084',
#   'in_playoff': 0},
#  {'name': 'Bojan Bogdanović',
#   'team': 'UTA',
#   'year': 2020,
#   'position': 'SF',
#   'player_efficiency': '15.6',
#   'true_shooting': '.603',
#   'plus_minus': '0.1',
#   'win_shares_percentage': '.096',
#   'in_playoff': 1},
#  {'name': 'Bol Bol',
#   'team': 'DEN',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '14.4',
#   'true_shooting': '.617',
#   'plus_minus': '-2.9',
#   'win_shares_percentage': '.063',
#   'in_playoff': 1},
#  {'name': 'Jonah Bolden',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '4.9',
#   'true_shooting': '.392',
#   'plus_minus': '-8.8',
#   'win_shares_percentage': '-0.006',
#   'in_playoff': 0},
#  {'name': 'Marques Bolden',
#   'team': 'CLE',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '19.8',
#   'true_shooting': '',
#   'plus_minus': '5.4',
#   'win_shares_percentage': '.282',
#   'in_playoff': 0},
#  {'name': 'Jordan Bone',
#   'team': 'DET',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '0.8',
#   'true_shooting': '.300',
#   'plus_minus': '-11.9',
#   'win_shares_percentage': '-0.117',
#   'in_playoff': 0},
#  {'name': 'Isaac Bonga',
#   'team': 'WAS',
#   'year': 2020,
#   'position': 'SF',
#   'player_efficiency': '10.2',
#   'true_shooting': '.608',
#   'plus_minus': '-2.8',
#   'win_shares_percentage': '.068',
#   'in_playoff': 0},
#  {'name': 'Devin Booker',
#   'team': 'PHO',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '20.6',
#   'true_shooting': '.618',
#   'plus_minus': '2.2',
#   'win_shares_percentage': '.143',
#   'in_playoff': 0},
#  {'name': 'Chris Boucher',
#   'team': 'TOR',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '20.7',
#   'true_shooting': '.587',
#   'plus_minus': '2.0',
#   'win_shares_percentage': '.224',
#   'in_playoff': 1},
#  {'name': 'Brian Bowen',
#   'team': 'IND',
#   'year': 2020,
#   'position': 'SF',
#   'player_efficiency': '0.1',
#   'true_shooting': '.300',
#   'plus_minus': '-10.7',
#   'win_shares_percentage': '-0.107',
#   'in_playoff': 1},
#  {'name': 'Ky Bowman',
#   'team': 'GSW',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '9.1',
#   'true_shooting': '.494',
#   'plus_minus': '-4.3',
#   'win_shares_percentage': '-0.003',
#   'in_playoff': 0},
#  {'name': 'Avery Bradley',
#   'team': 'LAL',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '8.9',
#   'true_shooting': '.537',
#   'plus_minus': '-2.5',
#   'win_shares_percentage': '.062',
#   'in_playoff': 1},
#  {'name': 'Tony Bradley',
#   'team': 'UTA',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '21.7',
#   'true_shooting': '.681',
#   'plus_minus': '1.3',
#   'win_shares_percentage': '.236',
#   'in_playoff': 1},
#  {'name': 'Jarrell Brantley',
#   'team': 'UTA',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '8.0',
#   'true_shooting': '.416',
#   'plus_minus': '-4.6',
#   'win_shares_percentage': '-0.006',
#   'in_playoff': 1},
#  {'name': 'Ignas Brazdeikis',
#   'team': 'NYK',
#   'year': 2020,
#   'position': 'SF',
#   'player_efficiency': '3.2',
#   'true_shooting': '.351',
#   'plus_minus': '-9.0',
#   'win_shares_percentage': '-0.108',
#   'in_playoff': 0},
#  {'name': 'Corey Brewer',
#   'team': 'SAC',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '8.7',
#   'true_shooting': '.470',
#   'plus_minus': '-3.1',
#   'win_shares_percentage': '.064',
#   'in_playoff': 0},
#  {'name': 'Mikal Bridges',
#   'team': 'PHO',
#   'year': 2020,
#   'position': 'SF',
#   'player_efficiency': '12.9',
#   'true_shooting': '.620',
#   'plus_minus': '0.8',
#   'win_shares_percentage': '.113',
#   'in_playoff': 0},
#  {'name': 'Miles Bridges',
#   'team': 'CHO',
#   'year': 2020,
#   'position': 'SF',
#   'player_efficiency': '12.1',
#   'true_shooting': '.520',
#   'plus_minus': '-2.5',
#   'win_shares_percentage': '.039',
#   'in_playoff': 0},
#  {'name': 'Oshae Brissett',
#   'team': 'TOR',
#   'year': 2020,
#   'position': 'SF',
#   'player_efficiency': '6.7',
#   'true_shooting': '.458',
#   'plus_minus': '-5.4',
#   'win_shares_percentage': '.043',
#   'in_playoff': 1},
#  {'name': 'Ryan Broekhoff',
#   'team': 'DAL',
#   'year': 2020,
#   'position': 'SF',
#   'player_efficiency': '13.1',
#   'true_shooting': '.568',
#   'plus_minus': '0.7',
#   'win_shares_percentage': '.109',
#   'in_playoff': 1},
#  {'name': 'Malcolm Brogdon',
#   'team': 'IND',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '17.7',
#   'true_shooting': '.541',
#   'plus_minus': '1.8',
#   'win_shares_percentage': '.114',
#   'in_playoff': 1},
#  {'name': 'Dillon Brooks',
#   'team': 'MEM',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '11.3',
#   'true_shooting': '.510',
#   'plus_minus': '-4.1',
#   'win_shares_percentage': '.027',
#   'in_playoff': 0},
#  {'name': 'Bruce Brown',
#   'team': 'DET',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '11.9',
#   'true_shooting': '.518',
#   'plus_minus': '-1.2',
#   'win_shares_percentage': '.062',
#   'in_playoff': 0},
#  {'name': 'Charlie Brown',
#   'team': 'ATL',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '11.0',
#   'true_shooting': '.472',
#   'plus_minus': '-2.5',
#   'win_shares_percentage': '-0.028',
#   'in_playoff': 0},
#  {'name': 'Jaylen Brown',
#   'team': 'BOS',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '16.9',
#   'true_shooting': '.583',
#   'plus_minus': '0.8',
#   'win_shares_percentage': '.123',
#   'in_playoff': 1},
#  {'name': 'Moses Brown',
#   'team': 'POR',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '6.7',
#   'true_shooting': '.407',
#   'plus_minus': '-10.0',
#   'win_shares_percentage': '-0.065',
#   'in_playoff': 1},
#  {'name': 'Sterling Brown',
#   'team': 'MIL',
#   'year': 2020,
#   'position': 'SF',
#   'player_efficiency': '9.5',
#   'true_shooting': '.486',
#   'plus_minus': '-2.0',
#   'win_shares_percentage': '.070',
#   'in_playoff': 1},
#  {'name': 'Troy Brown Jr.',
#   'team': 'WAS',
#   'year': 2020,
#   'position': 'SF',
#   'player_efficiency': '13.7',
#   'true_shooting': '.524',
#   'plus_minus': '-1.3',
#   'win_shares_percentage': '.065',
#   'in_playoff': 0},
#  {'name': 'Jalen Brunson',
#   'team': 'DAL',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '14.9',
#   'true_shooting': '.553',
#   'plus_minus': '-0.9',
#   'win_shares_percentage': '.101',
#   'in_playoff': 1},
#  {'name': 'Thomas Bryant',
#   'team': 'WAS',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '21.1',
#   'true_shooting': '.649',
#   'plus_minus': '2.2',
#   'win_shares_percentage': '.164',
#   'in_playoff': 0},
#  {'name': 'Reggie Bullock',
#   'team': 'NYK',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '9.3',
#   'true_shooting': '.502',
#   'plus_minus': '-3.0',
#   'win_shares_percentage': '.036',
#   'in_playoff': 0},
#  {'name': 'Trey Burke',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '15.6',
#   'true_shooting': '.548',
#   'plus_minus': '-0.2',
#   'win_shares_percentage': '.123',
#   'in_playoff': 0},
#  {'name': 'Alec Burks',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'SF-SG',
#   'player_efficiency': '16.7',
#   'true_shooting': '.561',
#   'plus_minus': '0.5',
#   'win_shares_percentage': '.101',
#   'in_playoff': 0},
#  {'name': 'Deonte Burton',
#   'team': 'OKC',
#   'year': 2020,
#   'position': 'SF',
#   'player_efficiency': '4.3',
#   'true_shooting': '.396',
#   'plus_minus': '-6.8',
#   'win_shares_percentage': '-0.067',
#   'in_playoff': 1},
#  {'name': 'Jimmy Butler',
#   'team': 'MIA',
#   'year': 2020,
#   'position': 'SF',
#   'player_efficiency': '23.6',
#   'true_shooting': '.585',
#   'plus_minus': '5.4',
#   'win_shares_percentage': '.221',
#   'in_playoff': 1},
#  {'name': 'Bruno Caboclo',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '14.1',
#   'true_shooting': '.484',
#   'plus_minus': '-2.1',
#   'win_shares_percentage': '.076',
#   'in_playoff': 0},
#  {'name': 'Devontae Cacok',
#   'team': 'LAL',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '28.6',
#   'true_shooting': '.500',
#   'plus_minus': '0.2',
#   'win_shares_percentage': '.226',
#   'in_playoff': 1},
#  {'name': 'Kentavious Caldwell-Pope',
#   'team': 'LAL',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '11.0',
#   'true_shooting': '.584',
#   'plus_minus': '-0.8',
#   'win_shares_percentage': '.102',
#   'in_playoff': 1},
#  {'name': 'Vlatko Čančar',
#   'team': 'DEN',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '11.4',
#   'true_shooting': '.507',
#   'plus_minus': '-4.6',
#   'win_shares_percentage': '.062',
#   'in_playoff': 1},
#  {'name': 'Clint Capela',
#   'team': 'HOU',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '20.6',
#   'true_shooting': '.626',
#   'plus_minus': '1.4',
#   'win_shares_percentage': '.184',
#   'in_playoff': 1},
#  {'name': 'DeMarre Carroll',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'SF-C',
#   'player_efficiency': '9.1',
#   'true_shooting': '.515',
#   'plus_minus': '-3.9',
#   'win_shares_percentage': '.045',
#   'in_playoff': 0},
#  {'name': 'Jevon Carter',
#   'team': 'PHO',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '11.3',
#   'true_shooting': '.563',
#   'plus_minus': '0.6',
#   'win_shares_percentage': '.093',
#   'in_playoff': 0},
#  {'name': 'Vince Carter',
#   'team': 'ATL',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '7.5',
#   'true_shooting': '.470',
#   'plus_minus': '-4.3',
#   'win_shares_percentage': '-0.011',
#   'in_playoff': 0},
#  {'name': 'Wendell Carter Jr.',
#   'team': 'CHI',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '15.5',
#   'true_shooting': '.590',
#   'plus_minus': '-2.4',
#   'win_shares_percentage': '.127',
#   'in_playoff': 0},
#  {'name': 'Michael Carter-Williams',
#   'team': 'ORL',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '15.3',
#   'true_shooting': '.535',
#   'plus_minus': '0.1',
#   'win_shares_percentage': '.111',
#   'in_playoff': 1},
#  {'name': 'Alex Caruso',
#   'team': 'LAL',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '10.8',
#   'true_shooting': '.525',
#   'plus_minus': '-0.2',
#   'win_shares_percentage': '.095',
#   'in_playoff': 1},
#  {'name': 'Willie Cauley-Stein',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '17.0',
#   'true_shooting': '.589',
#   'plus_minus': '0.5',
#   'win_shares_percentage': '.128',
#   'in_playoff': 0},
#  {'name': 'Tyson Chandler',
#   'team': 'HOU',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '10.8',
#   'true_shooting': '.717',
#   'plus_minus': '-1.5',
#   'win_shares_percentage': '.131',
#   'in_playoff': 1},
#  {'name': 'Wilson Chandler',
#   'team': 'BRK',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '7.4',
#   'true_shooting': '.531',
#   'plus_minus': '-2.7',
#   'win_shares_percentage': '.046',
#   'in_playoff': 1},
#  {'name': 'Joe Chealey',
#   'team': 'CHO',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '-2.9',
#   'true_shooting': '.127',
#   'plus_minus': '-12.5',
#   'win_shares_percentage': '-0.188',
#   'in_playoff': 0},
#  {'name': 'Zylan Cheatham',
#   'team': 'NOP',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '6.7',
#   'true_shooting': '.667',
#   'plus_minus': '-7.1',
#   'win_shares_percentage': '.034',
#   'in_playoff': 0},
#  {'name': 'Chris Chiozza',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '12.0',
#   'true_shooting': '.499',
#   'plus_minus': '-1.2',
#   'win_shares_percentage': '.055',
#   'in_playoff': 0},
#  {'name': 'Marquese Chriss',
#   'team': 'GSW',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '19.5',
#   'true_shooting': '.604',
#   'plus_minus': '0.6',
#   'win_shares_percentage': '.136',
#   'in_playoff': 0},
#  {'name': 'Gary Clark',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'SF-PF',
#   'player_efficiency': '10.7',
#   'true_shooting': '.568',
#   'plus_minus': '-1.9',
#   'win_shares_percentage': '.100',
#   'in_playoff': 0},
#  {'name': 'Brandon Clarke',
#   'team': 'MEM',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '20.9',
#   'true_shooting': '.663',
#   'plus_minus': '3.1',
#   'win_shares_percentage': '.183',
#   'in_playoff': 0},
#  {'name': 'Jordan Clarkson',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '17.3',
#   'true_shooting': '.574',
#   'plus_minus': '1.1',
#   'win_shares_percentage': '.096',
#   'in_playoff': 0},
#  {'name': 'Nicolas Claxton',
#   'team': 'BRK',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '14.8',
#   'true_shooting': '.577',
#   'plus_minus': '-0.6',
#   'win_shares_percentage': '.121',
#   'in_playoff': 1},
#  {'name': 'Chris Clemons',
#   'team': 'HOU',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '13.1',
#   'true_shooting': '.548',
#   'plus_minus': '-1.0',
#   'win_shares_percentage': '.058',
#   'in_playoff': 1},
#  {'name': 'Antonius Cleveland',
#   'team': 'DAL',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '2.5',
#   'true_shooting': '.340',
#   'plus_minus': '-10.1',
#   'win_shares_percentage': '-0.076',
#   'in_playoff': 1},
#  {'name': 'Amir Coffey',
#   'team': 'LAC',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '8.5',
#   'true_shooting': '.493',
#   'plus_minus': '-4.1',
#   'win_shares_percentage': '.041',
#   'in_playoff': 1},
#  {'name': 'John Collins',
#   'team': 'ATL',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '23.5',
#   'true_shooting': '.659',
#   'plus_minus': '3.1',
#   'win_shares_percentage': '.174',
#   'in_playoff': 0},
#  {'name': 'Zach Collins',
#   'team': 'POR',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '9.9',
#   'true_shooting': '.538',
#   'plus_minus': '-3.1',
#   'win_shares_percentage': '.052',
#   'in_playoff': 1},
#  {'name': 'Mike Conley',
#   'team': 'UTA',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '14.1',
#   'true_shooting': '.537',
#   'plus_minus': '0.3',
#   'win_shares_percentage': '.089',
#   'in_playoff': 1},
#  {'name': 'Pat Connaughton',
#   'team': 'MIL',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '11.5',
#   'true_shooting': '.565',
#   'plus_minus': '0.6',
#   'win_shares_percentage': '.130',
#   'in_playoff': 1},
#  {'name': 'Quinn Cook',
#   'team': 'LAL',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '10.0',
#   'true_shooting': '.509',
#   'plus_minus': '-3.8',
#   'win_shares_percentage': '.030',
#   'in_playoff': 1},
#  {'name': 'Tyler Cook',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'PF-SF',
#   'player_efficiency': '19.4',
#   'true_shooting': '.741',
#   'plus_minus': '-0.4',
#   'win_shares_percentage': '.182',
#   'in_playoff': 0},
#  {'name': 'Robert Covington',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'PF-C',
#   'player_efficiency': '13.3',
#   'true_shooting': '.559',
#   'plus_minus': '0.0',
#   'win_shares_percentage': '.083',
#   'in_playoff': 0},
#  {'name': 'Allen Crabbe',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'SG-SF',
#   'player_efficiency': '6.0',
#   'true_shooting': '.470',
#   'plus_minus': '-5.3',
#   'win_shares_percentage': '-0.007',
#   'in_playoff': 0},
#  {'name': 'Torrey Craig',
#   'team': 'DEN',
#   'year': 2020,
#   'position': 'SF',
#   'player_efficiency': '10.8',
#   'true_shooting': '.553',
#   'plus_minus': '-2.3',
#   'win_shares_percentage': '.091',
#   'in_playoff': 1},
#  {'name': 'Jamal Crawford',
#   'team': 'BRK',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '33.2',
#   'true_shooting': '.625',
#   'plus_minus': '15.0',
#   'win_shares_percentage': '.492',
#   'in_playoff': 1},
#  {'name': 'Jae Crowder',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'SF-PF',
#   'player_efficiency': '12.5',
#   'true_shooting': '.553',
#   'plus_minus': '-0.1',
#   'win_shares_percentage': '.098',
#   'in_playoff': 0},
#  {'name': 'Jarrett Culver',
#   'team': 'MIN',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '9.6',
#   'true_shooting': '.467',
#   'plus_minus': '-4.0',
#   'win_shares_percentage': '-0.004',
#   'in_playoff': 0},
#  {'name': 'Seth Curry',
#   'team': 'DAL',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '15.5',
#   'true_shooting': '.643',
#   'plus_minus': '0.8',
#   'win_shares_percentage': '.130',
#   'in_playoff': 1},
#  {'name': 'Stephen Curry',
#   'team': 'GSW',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '21.7',
#   'true_shooting': '.557',
#   'plus_minus': '3.9',
#   'win_shares_percentage': '.103',
#   'in_playoff': 0},
#  {'name': 'Troy Daniels',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '8.4',
#   'true_shooting': '.518',
#   'plus_minus': '-2.9',
#   'win_shares_percentage': '.056',
#   'in_playoff': 0},
#  {'name': 'Anthony Davis',
#   'team': 'LAL',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '27.4',
#   'true_shooting': '.610',
#   'plus_minus': '8.0',
#   'win_shares_percentage': '.250',
#   'in_playoff': 1},
#  {'name': 'Ed Davis',
#   'team': 'UTA',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '9.5',
#   'true_shooting': '.489',
#   'plus_minus': '-3.2',
#   'win_shares_percentage': '.102',
#   'in_playoff': 1},
#  {'name': 'Terence Davis',
#   'team': 'TOR',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '13.8',
#   'true_shooting': '.588',
#   'plus_minus': '0.8',
#   'win_shares_percentage': '.122',
#   'in_playoff': 1},
#  {'name': 'Dewayne Dedmon',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '9.4',
#   'true_shooting': '.473',
#   'plus_minus': '-5.8',
#   'win_shares_percentage': '.005',
#   'in_playoff': 0},
#  {'name': 'Matthew Dellavedova',
#   'team': 'CLE',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '8.1',
#   'true_shooting': '.463',
#   'plus_minus': '-5.2',
#   'win_shares_percentage': '.011',
#   'in_playoff': 0},
#  {'name': 'DeMar DeRozan',
#   'team': 'SAS',
#   'year': 2020,
#   'position': 'SF',
#   'player_efficiency': '21.6',
#   'true_shooting': '.603',
#   'plus_minus': '1.9',
#   'win_shares_percentage': '.151',
#   'in_playoff': 0},
#  {'name': 'Cheick Diallo',
#   'team': 'PHO',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '16.5',
#   'true_shooting': '.688',
#   'plus_minus': '-1.3',
#   'win_shares_percentage': '.132',
#   'in_playoff': 0},
#  {'name': 'Hamidou Diallo',
#   'team': 'OKC',
#   'year': 2020,
#   'position': 'SF',
#   'player_efficiency': '9.3',
#   'true_shooting': '.491',
#   'plus_minus': '-3.9',
#   'win_shares_percentage': '.022',
#   'in_playoff': 1},
#  {'name': 'Gorgui Dieng',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '17.1',
#   'true_shooting': '.568',
#   'plus_minus': '1.5',
#   'win_shares_percentage': '.129',
#   'in_playoff': 0},
#  {'name': 'Spencer Dinwiddie',
#   'team': 'BRK',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '17.8',
#   'true_shooting': '.541',
#   'plus_minus': '1.8',
#   'win_shares_percentage': '.116',
#   'in_playoff': 1},
#  {'name': 'Donte DiVincenzo',
#   'team': 'MIL',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '14.1',
#   'true_shooting': '.557',
#   'plus_minus': '1.3',
#   'win_shares_percentage': '.135',
#   'in_playoff': 1},
#  {'name': 'Luka Dončić',
#   'team': 'DAL',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '27.6',
#   'true_shooting': '.585',
#   'plus_minus': '8.4',
#   'win_shares_percentage': '.207',
#   'in_playoff': 1},
#  {'name': 'Luguentz Dort',
#   'team': 'OKC',
#   'year': 2020,
#   'position': 'SF',
#   'player_efficiency': '7.6',
#   'true_shooting': '.506',
#   'plus_minus': '-3.7',
#   'win_shares_percentage': '.049',
#   'in_playoff': 1},
#  {'name': 'Damyean Dotson',
#   'team': 'NYK',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '10.9',
#   'true_shooting': '.527',
#   'plus_minus': '-1.5',
#   'win_shares_percentage': '.053',
#   'in_playoff': 0},
#  {'name': 'Sekou Doumbouya',
#   'team': 'DET',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '6.2',
#   'true_shooting': '.474',
#   'plus_minus': '-6.7',
#   'win_shares_percentage': '-0.020',
#   'in_playoff': 0},
#  {'name': 'PJ Dozier',
#   'team': 'DEN',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '11.6',
#   'true_shooting': '.495',
#   'plus_minus': '-3.9',
#   'win_shares_percentage': '.044',
#   'in_playoff': 1},
#  {'name': 'Goran Dragić',
#   'team': 'MIA',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '16.3',
#   'true_shooting': '.573',
#   'plus_minus': '-0.1',
#   'win_shares_percentage': '.102',
#   'in_playoff': 1},
#  {'name': 'Andre Drummond',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '22.0',
#   'true_shooting': '.553',
#   'plus_minus': '0.9',
#   'win_shares_percentage': '.108',
#   'in_playoff': 0},
#  {'name': 'Jared Dudley',
#   'team': 'LAL',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '7.8',
#   'true_shooting': '.558',
#   'plus_minus': '-0.8',
#   'win_shares_percentage': '.102',
#   'in_playoff': 1},
#  {'name': 'Kris Dunn',
#   'team': 'CHI',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '12.1',
#   'true_shooting': '.510',
#   'plus_minus': '-0.6',
#   'win_shares_percentage': '.085',
#   'in_playoff': 0},
#  {'name': 'Carsen Edwards',
#   'team': 'BOS',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '6.9',
#   'true_shooting': '.444',
#   'plus_minus': '-4.6',
#   'win_shares_percentage': '.014',
#   'in_playoff': 1},
#  {'name': 'Henry Ellenson',
#   'team': 'BRK',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '-1.3',
#   'true_shooting': '.143',
#   'plus_minus': '-10.9',
#   'win_shares_percentage': '-0.183',
#   'in_playoff': 1},
#  {'name': 'Wayne Ellington',
#   'team': 'NYK',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '8.5',
#   'true_shooting': '.509',
#   'plus_minus': '-2.9',
#   'win_shares_percentage': '.035',
#   'in_playoff': 0},
#  {'name': 'Joel Embiid',
#   'team': 'PHI',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '25.8',
#   'true_shooting': '.590',
#   'plus_minus': '4.7',
#   'win_shares_percentage': '.192',
#   'in_playoff': 1},
#  {'name': 'James Ennis',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'SF-SG',
#   'player_efficiency': '11.5',
#   'true_shooting': '.565',
#   'plus_minus': '-2.6',
#   'win_shares_percentage': '.090',
#   'in_playoff': 0},
#  {'name': 'Drew Eubanks',
#   'team': 'SAS',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '17.3',
#   'true_shooting': '.682',
#   'plus_minus': '-1.7',
#   'win_shares_percentage': '.134',
#   'in_playoff': 0},
#  {'name': 'Jacob Evans',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '5.5',
#   'true_shooting': '.436',
#   'plus_minus': '-7.1',
#   'win_shares_percentage': '-0.056',
#   'in_playoff': 0},
#  {'name': 'Dante Exum',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '10.3',
#   'true_shooting': '.576',
#   'plus_minus': '-2.9',
#   'win_shares_percentage': '.043',
#   'in_playoff': 0},
#  {'name': 'Tacko Fall',
#   'team': 'BOS',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '28.4',
#   'true_shooting': '.751',
#   'plus_minus': '6.5',
#   'win_shares_percentage': '.223',
#   'in_playoff': 1},
#  {'name': 'Derrick Favors',
#   'team': 'NOP',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '18.5',
#   'true_shooting': '.620',
#   'plus_minus': '1.0',
#   'win_shares_percentage': '.162',
#   'in_playoff': 0},
#  {'name': 'Cristiano Felício',
#   'team': 'CHI',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '12.8',
#   'true_shooting': '.671',
#   'plus_minus': '-3.0',
#   'win_shares_percentage': '.126',
#   'in_playoff': 0},
#  {'name': 'Terrance Ferguson',
#   'team': 'OKC',
#   'year': 2020,
#   'position': 'SF',
#   'player_efficiency': '3.7',
#   'true_shooting': '.481',
#   'plus_minus': '-4.5',
#   'win_shares_percentage': '.021',
#   'in_playoff': 1},
#  {'name': 'Bruno Fernando',
#   'team': 'ATL',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '11.9',
#   'true_shooting': '.542',
#   'plus_minus': '-4.1',
#   'win_shares_percentage': '.055',
#   'in_playoff': 0},
#  {'name': 'Yogi Ferrell',
#   'team': 'SAC',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '12.2',
#   'true_shooting': '.528',
#   'plus_minus': '-1.8',
#   'win_shares_percentage': '.060',
#   'in_playoff': 0},
#  {'name': 'Dorian Finney-Smith',
#   'team': 'DAL',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '12.3',
#   'true_shooting': '.595',
#   'plus_minus': '-0.2',
#   'win_shares_percentage': '.110',
#   'in_playoff': 1},
#  {'name': 'Bryn Forbes',
#   'team': 'SAS',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '11.1',
#   'true_shooting': '.570',
#   'plus_minus': '-2.7',
#   'win_shares_percentage': '.047',
#   'in_playoff': 0},
#  {'name': 'Evan Fournier',
#   'team': 'ORL',
#   'year': 2020,
#   'position': 'SF',
#   'player_efficiency': '16.4',
#   'true_shooting': '.595',
#   'plus_minus': '1.0',
#   'win_shares_percentage': '.106',
#   'in_playoff': 1},
#  {'name': "De'Aaron Fox",
#   'team': 'SAC',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '20.6',
#   'true_shooting': '.558',
#   'plus_minus': '1.8',
#   'win_shares_percentage': '.118',
#   'in_playoff': 0},
#  {'name': 'Melvin Frazier',
#   'team': 'ORL',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '9.8',
#   'true_shooting': '.559',
#   'plus_minus': '-2.3',
#   'win_shares_percentage': '.057',
#   'in_playoff': 1},
#  {'name': 'Michael Frazier',
#   'team': 'HOU',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '-0.9',
#   'true_shooting': '.384',
#   'plus_minus': '-11.0',
#   'win_shares_percentage': '-0.060',
#   'in_playoff': 1},
#  {'name': 'Tim Frazier',
#   'team': 'DET',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '9.8',
#   'true_shooting': '.464',
#   'plus_minus': '-4.6',
#   'win_shares_percentage': '.016',
#   'in_playoff': 0},
#  {'name': 'Markelle Fultz',
#   'team': 'ORL',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '14.3',
#   'true_shooting': '.517',
#   'plus_minus': '-1.8',
#   'win_shares_percentage': '.065',
#   'in_playoff': 1},
#  {'name': 'Wenyen Gabriel',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '9.6',
#   'true_shooting': '.546',
#   'plus_minus': '-3.8',
#   'win_shares_percentage': '.048',
#   'in_playoff': 0},
#  {'name': 'Daniel Gafford',
#   'team': 'CHI',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '16.2',
#   'true_shooting': '.686',
#   'plus_minus': '-1.3',
#   'win_shares_percentage': '.146',
#   'in_playoff': 0},
#  {'name': 'Danilo Gallinari',
#   'team': 'OKC',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '19.5',
#   'true_shooting': '.612',
#   'plus_minus': '3.3',
#   'win_shares_percentage': '.166',
#   'in_playoff': 1},
#  {'name': 'Langston Galloway',
#   'team': 'DET',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '12.3',
#   'true_shooting': '.584',
#   'plus_minus': '-0.8',
#   'win_shares_percentage': '.087',
#   'in_playoff': 0},
#  {'name': 'Darius Garland',
#   'team': 'CLE',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '8.5',
#   'true_shooting': '.498',
#   'plus_minus': '-5.6',
#   'win_shares_percentage': '-0.034',
#   'in_playoff': 0},
#  {'name': 'Marc Gasol',
#   'team': 'TOR',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '11.8',
#   'true_shooting': '.551',
#   'plus_minus': '1.6',
#   'win_shares_percentage': '.124',
#   'in_playoff': 1},
#  {'name': 'Rudy Gay',
#   'team': 'SAS',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '15.4',
#   'true_shooting': '.553',
#   'plus_minus': '-0.8',
#   'win_shares_percentage': '.068',
#   'in_playoff': 0},
#  {'name': 'Paul George',
#   'team': 'LAC',
#   'year': 2020,
#   'position': 'SF',
#   'player_efficiency': '21.1',
#   'true_shooting': '.589',
#   'plus_minus': '4.9',
#   'win_shares_percentage': '.161',
#   'in_playoff': 1},
#  {'name': 'Taj Gibson',
#   'team': 'NYK',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '16.1',
#   'true_shooting': '.610',
#   'plus_minus': '-1.1',
#   'win_shares_percentage': '.120',
#   'in_playoff': 0},
#  {'name': 'Harry Giles',
#   'team': 'SAC',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '16.4',
#   'true_shooting': '.580',
#   'plus_minus': '-1.3',
#   'win_shares_percentage': '.112',
#   'in_playoff': 0},
#  {'name': 'Shai Gilgeous-Alexander',
#   'team': 'OKC',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '17.7',
#   'true_shooting': '.568',
#   'plus_minus': '1.7',
#   'win_shares_percentage': '.121',
#   'in_playoff': 1},
#  {'name': 'Rudy Gobert',
#   'team': 'UTA',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '21.7',
#   'true_shooting': '.699',
#   'plus_minus': '3.6',
#   'win_shares_percentage': '.221',
#   'in_playoff': 1},
#  {'name': 'Brandon Goodwin',
#   'team': 'ATL',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '11.6',
#   'true_shooting': '.507',
#   'plus_minus': '-2.9',
#   'win_shares_percentage': '.013',
#   'in_playoff': 0},
#  {'name': 'Aaron Gordon',
#   'team': 'ORL',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '15.1',
#   'true_shooting': '.516',
#   'plus_minus': '0.0',
#   'win_shares_percentage': '.087',
#   'in_playoff': 1},
#  {'name': 'Eric Gordon',
#   'team': 'HOU',
#   'year': 2020,
#   'position': 'SF',
#   'player_efficiency': '10.3',
#   'true_shooting': '.510',
#   'plus_minus': '-3.9',
#   'win_shares_percentage': '.024',
#   'in_playoff': 1},
#  {'name': "Devonte' Graham",
#   'team': 'CHO',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '15.8',
#   'true_shooting': '.537',
#   'plus_minus': '0.5',
#   'win_shares_percentage': '.073',
#   'in_playoff': 0},
#  {'name': 'Treveon Graham',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'SF',
#   'player_efficiency': '6.6',
#   'true_shooting': '.456',
#   'plus_minus': '-5.6',
#   'win_shares_percentage': '.009',
#   'in_playoff': 0},
#  {'name': 'Jerami Grant',
#   'team': 'DEN',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '14.4',
#   'true_shooting': '.591',
#   'plus_minus': '-0.5',
#   'win_shares_percentage': '.111',
#   'in_playoff': 1},
#  {'name': 'Jerian Grant',
#   'team': 'WAS',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '6.6',
#   'true_shooting': '.449',
#   'plus_minus': '-6.8',
#   'win_shares_percentage': '-0.018',
#   'in_playoff': 0},
#  {'name': 'Josh Gray',
#   'team': 'NOP',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '-5.0',
#   'true_shooting': '.500',
#   'plus_minus': '-16.0',
#   'win_shares_percentage': '-0.226',
#   'in_playoff': 0},
#  {'name': 'Danny Green',
#   'team': 'LAL',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '10.8',
#   'true_shooting': '.552',
#   'plus_minus': '0.5',
#   'win_shares_percentage': '.096',
#   'in_playoff': 1},
#  {'name': 'Draymond Green',
#   'team': 'GSW',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '12.5',
#   'true_shooting': '.489',
#   'plus_minus': '-0.2',
#   'win_shares_percentage': '.044',
#   'in_playoff': 0},
#  {'name': 'JaMychal Green',
#   'team': 'LAC',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '11.1',
#   'true_shooting': '.576',
#   'plus_minus': '-0.5',
#   'win_shares_percentage': '.115',
#   'in_playoff': 1},
#  {'name': 'Javonte Green',
#   'team': 'BOS',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '13.1',
#   'true_shooting': '.564',
#   'plus_minus': '-0.7',
#   'win_shares_percentage': '.113',
#   'in_playoff': 1},
#  {'name': 'Jeff Green',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'PF-C',
#   'player_efficiency': '13.7',
#   'true_shooting': '.590',
#   'plus_minus': '-0.1',
#   'win_shares_percentage': '.104',
#   'in_playoff': 0},
#  {'name': 'Blake Griffin',
#   'team': 'DET',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '11.9',
#   'true_shooting': '.476',
#   'plus_minus': '-4.3',
#   'win_shares_percentage': '-0.012',
#   'in_playoff': 0},
#  {'name': 'Marko Guduric',
#   'team': 'MEM',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '8.8',
#   'true_shooting': '.514',
#   'plus_minus': '-3.4',
#   'win_shares_percentage': '.014',
#   'in_playoff': 0},
#  {'name': 'Kyle Guy',
#   'team': 'SAC',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '6.6',
#   'true_shooting': '.400',
#   'plus_minus': '-12.3',
#   'win_shares_percentage': '-0.045',
#   'in_playoff': 0},
#  {'name': 'Rui Hachimura',
#   'team': 'WAS',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '13.5',
#   'true_shooting': '.535',
#   'plus_minus': '-3.2',
#   'win_shares_percentage': '.060',
#   'in_playoff': 0},
#  {'name': 'Devon Hall',
#   'team': 'OKC',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '3.1',
#   'true_shooting': '.298',
#   'plus_minus': '-6.4',
#   'win_shares_percentage': '-0.116',
#   'in_playoff': 1},
#  {'name': 'Donta Hall',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'C-PF',
#   'player_efficiency': '13.6',
#   'true_shooting': '.652',
#   'plus_minus': '-3.7',
#   'win_shares_percentage': '.137',
#   'in_playoff': 0},
#  {'name': 'Dusty Hannahs',
#   'team': 'MEM',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '21.3',
#   'true_shooting': '.607',
#   'plus_minus': '3.1',
#   'win_shares_percentage': '.146',
#   'in_playoff': 0},
#  {'name': 'Tim Hardaway Jr.',
#   'team': 'DAL',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '14.5',
#   'true_shooting': '.581',
#   'plus_minus': '-0.1',
#   'win_shares_percentage': '.102',
#   'in_playoff': 1},
#  {'name': 'James Harden',
#   'team': 'HOU',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '29.1',
#   'true_shooting': '.626',
#   'plus_minus': '9.6',
#   'win_shares_percentage': '.254',
#   'in_playoff': 1},
#  {'name': 'Maurice Harkless',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'PF-SF',
#   'player_efficiency': '9.8',
#   'true_shooting': '.572',
#   'plus_minus': '-0.7',
#   'win_shares_percentage': '.090',
#   'in_playoff': 0},
#  {'name': 'Jared Harper',
#   'team': 'PHO',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '-5.3',
#   'true_shooting': '.250',
#   'plus_minus': '-15.7',
#   'win_shares_percentage': '-0.249',
#   'in_playoff': 0},
#  {'name': 'Montrezl Harrell',
#   'team': 'LAC',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '23.2',
#   'true_shooting': '.607',
#   'plus_minus': '2.9',
#   'win_shares_percentage': '.191',
#   'in_playoff': 1},
#  {'name': 'Gary Harris',
#   'team': 'DEN',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '9.7',
#   'true_shooting': '.519',
#   'plus_minus': '-2.5',
#   'win_shares_percentage': '.052',
#   'in_playoff': 1},
#  {'name': 'Joe Harris',
#   'team': 'BRK',
#   'year': 2020,
#   'position': 'SF',
#   'player_efficiency': '13.3',
#   'true_shooting': '.606',
#   'plus_minus': '-0.2',
#   'win_shares_percentage': '.097',
#   'in_playoff': 1},
#  {'name': 'Tobias Harris',
#   'team': 'PHI',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '17.2',
#   'true_shooting': '.556',
#   'plus_minus': '0.8',
#   'win_shares_percentage': '.121',
#   'in_playoff': 1},
#  {'name': 'Shaquille Harrison',
#   'team': 'CHI',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '17.8',
#   'true_shooting': '.559',
#   'plus_minus': '2.8',
#   'win_shares_percentage': '.153',
#   'in_playoff': 0},
#  {'name': 'Josh Hart',
#   'team': 'NOP',
#   'year': 2020,
#   'position': 'SF',
#   'player_efficiency': '11.9',
#   'true_shooting': '.563',
#   'plus_minus': '-0.7',
#   'win_shares_percentage': '.085',
#   'in_playoff': 0},
#  {'name': 'Isaiah Hartenstein',
#   'team': 'HOU',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '18.6',
#   'true_shooting': '.674',
#   'plus_minus': '0.3',
#   'win_shares_percentage': '.190',
#   'in_playoff': 1},
#  {'name': 'Udonis Haslem',
#   'team': 'MIA',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '6.5',
#   'true_shooting': '.470',
#   'plus_minus': '-7.6',
#   'win_shares_percentage': '.041',
#   'in_playoff': 1},
#  {'name': 'Jaxson Hayes',
#   'team': 'NOP',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '17.6',
#   'true_shooting': '.689',
#   'plus_minus': '-0.3',
#   'win_shares_percentage': '.171',
#   'in_playoff': 0},
#  {'name': 'Gordon Hayward',
#   'team': 'BOS',
#   'year': 2020,
#   'position': 'SF',
#   'player_efficiency': '18.1',
#   'true_shooting': '.595',
#   'plus_minus': '2.7',
#   'win_shares_percentage': '.158',
#   'in_playoff': 1},
#  {'name': 'John Henson',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '17.0',
#   'true_shooting': '.578',
#   'plus_minus': '0.9',
#   'win_shares_percentage': '.109',
#   'in_playoff': 0},
#  {'name': 'Dewan Hernandez',
#   'team': 'TOR',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '12.9',
#   'true_shooting': '.432',
#   'plus_minus': '-9.6',
#   'win_shares_percentage': '.043',
#   'in_playoff': 1},
#  {'name': 'Juan Hernangómez',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '10.4',
#   'true_shooting': '.518',
#   'plus_minus': '-3.4',
#   'win_shares_percentage': '.052',
#   'in_playoff': 0},
#  {'name': 'Willy Hernangómez',
#   'team': 'CHO',
#   'year': 2020,
#   'position': 'C',
#   'player_efficiency': '19.2',
#   'true_shooting': '.576',
#   'plus_minus': '0.1',
#   'win_shares_percentage': '.107',
#   'in_playoff': 0},
#  {'name': 'Tyler Herro',
#   'team': 'MIA',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '12.5',
#   'true_shooting': '.550',
#   'plus_minus': '-1.6',
#   'win_shares_percentage': '.050',
#   'in_playoff': 1},
#  {'name': 'Kevin Hervey',
#   'team': 'OKC',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '5.0',
#   'true_shooting': '.315',
#   'plus_minus': '-5.1',
#   'win_shares_percentage': '-0.085',
#   'in_playoff': 1},
#  {'name': 'Mario Hezonja',
#   'team': 'POR',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '9.5',
#   'true_shooting': '.525',
#   'plus_minus': '-2.9',
#   'win_shares_percentage': '.043',
#   'in_playoff': 1},
#  {'name': 'Buddy Hield',
#   'team': 'SAC',
#   'year': 2020,
#   'position': 'SG',
#   'player_efficiency': '16.0',
#   'true_shooting': '.566',
#   'plus_minus': '1.1',
#   'win_shares_percentage': '.064',
#   'in_playoff': 0},
#  {'name': 'George Hill',
#   'team': 'MIL',
#   'year': 2020,
#   'position': 'PG',
#   'player_efficiency': '16.9',
#   'true_shooting': '.659',
#   'plus_minus': '2.9',
#   'win_shares_percentage': '.210',
#   'in_playoff': 1},
#  {'name': 'Solomon Hill',
#   'team': 'TOT',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '9.8',
#   'true_shooting': '.535',
#   'plus_minus': '-1.7',
#   'win_shares_percentage': '.064',
#   'in_playoff': 0},
#  {'name': 'Jaylen Hoard',
#   'team': 'POR',
#   'year': 2020,
#   'position': 'PF',
#   'player_efficiency': '14.9',
#   'true_shooting': '.504',
#   'plus_minus': '-1.9',
#   'win_shares_percentage': '.093',
#   'in_playoff': 1},
#  {'name': 'Aaron Holiday',
#   'team': 'IND',
#   'year': 2020,
# ...
#   'year': 2019,
#   'position': 'C',
#   'player_efficiency': '10.5',
#   'true_shooting': '.317',
#   'plus_minus': '-2.0',
#   'win_shares_percentage': '.079',
#   'in_playoff': 1},
#  {'name': 'Chris Paul',
#   'team': 'HOU',
#   'year': 2019,
#   'position': 'PG',
#   'player_efficiency': '19.7',
#   'true_shooting': '.560',
#   'plus_minus': '3.9',
#   'win_shares_percentage': '.172',
#   'in_playoff': 1},
#  {'name': 'Cameron Payne',
#   'team': 'TOT',
#   'year': 2019,
#   'position': 'PG',
#   'player_efficiency': '11.5',
#   'true_shooting': '.519',
#   'plus_minus': '-3.0',
#   'win_shares_percentage': '.031',
#   'in_playoff': 0},
#  {'name': 'Elfrid Payton',
#   'team': 'NOP',
#   'year': 2019,
#   'position': 'PG',
#   'player_efficiency': '14.0',
#   'true_shooting': '.502',
#   'plus_minus': '-1.4',
#   'win_shares_percentage': '.058',
#   'in_playoff': 0},
#  {'name': 'Gary Payton II',
#   'team': 'WAS',
#   'year': 2019,
#   'position': 'PG',
#   'player_efficiency': '36.9',
#   'true_shooting': '.688',
#   'plus_minus': '18.9',
#   'win_shares_percentage': '.358',
#   'in_playoff': 0},
#  {'name': 'Theo Pinson',
#   'team': 'BRK',
#   'year': 2019,
#   'position': 'SG',
#   'player_efficiency': '8.1',
#   'true_shooting': '.490',
#   'plus_minus': '-3.2',
#   'win_shares_percentage': '.004',
#   'in_playoff': 1},
#  {'name': 'Mason Plumlee',
#   'team': 'DEN',
#   'year': 2019,
#   'position': 'C',
#   'player_efficiency': '17.8',
#   'true_shooting': '.602',
#   'plus_minus': '2.1',
#   'win_shares_percentage': '.160',
#   'in_playoff': 1},
#  {'name': 'Miles Plumlee',
#   'team': 'ATL',
#   'year': 2019,
#   'position': 'C',
#   'player_efficiency': '18.9',
#   'true_shooting': '.654',
#   'plus_minus': '1.6',
#   'win_shares_percentage': '.145',
#   'in_playoff': 0},
#  {'name': 'Jakob Poeltl',
#   'team': 'SAS',
#   'year': 2019,
#   'position': 'C',
#   'player_efficiency': '19.4',
#   'true_shooting': '.640',
#   'plus_minus': '2.0',
#   'win_shares_percentage': '.193',
#   'in_playoff': 1},
#  {'name': 'Quincy Pondexter',
#   'team': 'SAS',
#   'year': 2019,
#   'position': 'SF',
#   'player_efficiency': '13.2',
#   'true_shooting': '.641',
#   'plus_minus': '-0.9',
#   'win_shares_percentage': '.128',
#   'in_playoff': 1},
#  {'name': 'Otto Porter',
#   'team': 'TOT',
#   'year': 2019,
#   'position': 'SF',
#   'player_efficiency': '15.9',
#   'true_shooting': '.569',
#   'plus_minus': '0.9',
#   'win_shares_percentage': '.093',
#   'in_playoff': 0},
#  {'name': 'Bobby Portis',
#   'team': 'TOT',
#   'year': 2019,
#   'position': 'PF',
#   'player_efficiency': '16.1',
#   'true_shooting': '.529',
#   'plus_minus': '-2.4',
#   'win_shares_percentage': '.060',
#   'in_playoff': 0},
#  {'name': 'Dwight Powell',
#   'team': 'DAL',
#   'year': 2019,
#   'position': 'C',
#   'player_efficiency': '20.4',
#   'true_shooting': '.682',
#   'plus_minus': '2.9',
#   'win_shares_percentage': '.215',
#   'in_playoff': 0},
#  {'name': 'Norman Powell',
#   'team': 'TOR',
#   'year': 2019,
#   'position': 'SG',
#   'player_efficiency': '13.3',
#   'true_shooting': '.596',
#   'plus_minus': '-0.7',
#   'win_shares_percentage': '.102',
#   'in_playoff': 1},
#  {'name': 'Alex Poythress',
#   'team': 'ATL',
#   'year': 2019,
#   'position': 'PF',
#   'player_efficiency': '12.2',
#   'true_shooting': '.571',
#   'plus_minus': '-3.5',
#   'win_shares_percentage': '.086',
#   'in_playoff': 0},
#  {'name': 'Taurean Prince',
#   'team': 'ATL',
#   'year': 2019,
#   'position': 'SF',
#   'player_efficiency': '11.9',
#   'true_shooting': '.575',
#   'plus_minus': '-2.0',
#   'win_shares_percentage': '.047',
#   'in_playoff': 0},
#  {'name': 'Zhou Qi',
#   'team': 'HOU',
#   'year': 2019,
#   'position': 'PF',
#   'player_efficiency': '80.4',
#   'true_shooting': '1.000',
#   'plus_minus': '52.0',
#   'win_shares_percentage': '1.261',
#   'in_playoff': 1},
#  {'name': 'Ivan Rabb',
#   'team': 'MEM',
#   'year': 2019,
#   'position': 'PF',
#   'player_efficiency': '16.1',
#   'true_shooting': '.586',
#   'plus_minus': '-1.4',
#   'win_shares_percentage': '.137',
#   'in_playoff': 0},
#  {'name': 'Chasson Randle',
#   'team': 'WAS',
#   'year': 2019,
#   'position': 'PG',
#   'player_efficiency': '9.9',
#   'true_shooting': '.555',
#   'plus_minus': '-4.0',
#   'win_shares_percentage': '.041',
#   'in_playoff': 0},
#  {'name': 'Julius Randle',
#   'team': 'NOP',
#   'year': 2019,
#   'position': 'PF',
#   'player_efficiency': '21.0',
#   'true_shooting': '.600',
#   'plus_minus': '1.5',
#   'win_shares_percentage': '.131',
#   'in_playoff': 0},
#  {'name': 'J.J. Redick',
#   'team': 'PHI',
#   'year': 2019,
#   'position': 'SG',
#   'player_efficiency': '15.1',
#   'true_shooting': '.602',
#   'plus_minus': '0.2',
#   'win_shares_percentage': '.118',
#   'in_playoff': 1},
#  {'name': 'Davon Reed',
#   'team': 'IND',
#   'year': 2019,
#   'position': 'SG',
#   'player_efficiency': '8.1',
#   'true_shooting': '.500',
#   'plus_minus': '-5.5',
#   'win_shares_percentage': '.064',
#   'in_playoff': 1},
#  {'name': 'Cameron Reynolds',
#   'team': 'MIN',
#   'year': 2019,
#   'position': 'SG',
#   'player_efficiency': '10.4',
#   'true_shooting': '.580',
#   'plus_minus': '-2.5',
#   'win_shares_percentage': '.078',
#   'in_playoff': 0},
#  {'name': 'Josh Richardson',
#   'team': 'MIA',
#   'year': 2019,
#   'position': 'SG',
#   'player_efficiency': '14.0',
#   'true_shooting': '.536',
#   'plus_minus': '0.3',
#   'win_shares_percentage': '.106',
#   'in_playoff': 0},
#  {'name': 'Malachi Richardson',
#   'team': 'TOR',
#   'year': 2019,
#   'position': 'SG',
#   'player_efficiency': '0.9',
#   'true_shooting': '.481',
#   'plus_minus': '-8.8',
#   'win_shares_percentage': '-0.060',
#   'in_playoff': 1},
#  {'name': 'Austin Rivers',
#   'team': 'TOT',
#   'year': 2019,
#   'position': 'SG',
#   'player_efficiency': '7.7',
#   'true_shooting': '.503',
#   'plus_minus': '-4.3',
#   'win_shares_percentage': '.028',
#   'in_playoff': 0},
#  {'name': 'Devin Robinson',
#   'team': 'WAS',
#   'year': 2019,
#   'position': 'SF',
#   'player_efficiency': '20.6',
#   'true_shooting': '.616',
#   'plus_minus': '1.9',
#   'win_shares_percentage': '.175',
#   'in_playoff': 0},
#  {'name': 'Duncan Robinson',
#   'team': 'MIA',
#   'year': 2019,
#   'position': 'SF',
#   'player_efficiency': '7.6',
#   'true_shooting': '.514',
#   'plus_minus': '-3.4',
#   'win_shares_percentage': '.051',
#   'in_playoff': 0},
#  {'name': 'Glenn Robinson III',
#   'team': 'DET',
#   'year': 2019,
#   'position': 'SF',
#   'player_efficiency': '8.7',
#   'true_shooting': '.511',
#   'plus_minus': '-3.0',
#   'win_shares_percentage': '.054',
#   'in_playoff': 1},
#  {'name': 'Jerome Robinson',
#   'team': 'LAC',
#   'year': 2019,
#   'position': 'SG',
#   'player_efficiency': '7.2',
#   'true_shooting': '.491',
#   'plus_minus': '-4.7',
#   'win_shares_percentage': '.012',
#   'in_playoff': 1},
#  {'name': 'Mitchell Robinson',
#   'team': 'NYK',
#   'year': 2019,
#   'position': 'C',
#   'player_efficiency': '22.0',
#   'true_shooting': '.692',
#   'plus_minus': '2.5',
#   'win_shares_percentage': '.217',
#   'in_playoff': 0},
#  {'name': 'Rajon Rondo',
#   'team': 'LAL',
#   'year': 2019,
#   'position': 'PG',
#   'player_efficiency': '12.1',
#   'true_shooting': '.473',
#   'plus_minus': '-1.5',
#   'win_shares_percentage': '.047',
#   'in_playoff': 0},
#  {'name': 'Derrick Rose',
#   'team': 'MIN',
#   'year': 2019,
#   'position': 'PG',
#   'player_efficiency': '19.5',
#   'true_shooting': '.557',
#   'plus_minus': '1.4',
#   'win_shares_percentage': '.102',
#   'in_playoff': 0},
#  {'name': 'Terrence Ross',
#   'team': 'ORL',
#   'year': 2019,
#   'position': 'SG',
#   'player_efficiency': '15.4',
#   'true_shooting': '.561',
#   'plus_minus': '0.8',
#   'win_shares_percentage': '.095',
#   'in_playoff': 1},
#  {'name': 'Terry Rozier',
#   'team': 'BOS',
#   'year': 2019,
#   'position': 'PG',
#   'player_efficiency': '12.9',
#   'true_shooting': '.501',
#   'plus_minus': '-0.2',
#   'win_shares_percentage': '.086',
#   'in_playoff': 1},
#  {'name': 'Ricky Rubio',
#   'team': 'UTA',
#   'year': 2019,
#   'position': 'PG',
#   'player_efficiency': '14.0',
#   'true_shooting': '.520',
#   'plus_minus': '-0.2',
#   'win_shares_percentage': '.095',
#   'in_playoff': 1},
#  {'name': "D'Angelo Russell",
#   'team': 'BRK',
#   'year': 2019,
#   'position': 'PG',
#   'player_efficiency': '19.4',
#   'true_shooting': '.533',
#   'plus_minus': '3.4',
#   'win_shares_percentage': '.097',
#   'in_playoff': 1},
#  {'name': 'Domantas Sabonis',
#   'team': 'IND',
#   'year': 2019,
#   'position': 'C',
#   'player_efficiency': '21.9',
#   'true_shooting': '.630',
#   'plus_minus': '3.1',
#   'win_shares_percentage': '.197',
#   'in_playoff': 1},
#  {'name': 'Brandon Sampson',
#   'team': 'CHI',
#   'year': 2019,
#   'position': 'SG',
#   'player_efficiency': '8.5',
#   'true_shooting': '.567',
#   'plus_minus': '-4.7',
#   'win_shares_percentage': '.010',
#   'in_playoff': 0},
#  {'name': 'JaKarr Sampson',
#   'team': 'CHI',
#   'year': 2019,
#   'position': 'SF',
#   'player_efficiency': '22.5',
#   'true_shooting': '.633',
#   'plus_minus': '3.7',
#   'win_shares_percentage': '.173',
#   'in_playoff': 0},
#  {'name': 'Dario Šarić',
#   'team': 'TOT',
#   'year': 2019,
#   'position': 'PF',
#   'player_efficiency': '13.1',
#   'true_shooting': '.563',
#   'plus_minus': '-1.6',
#   'win_shares_percentage': '.084',
#   'in_playoff': 0},
#  {'name': 'Tomáš Satoranský',
#   'team': 'WAS',
#   'year': 2019,
#   'position': 'PG',
#   'player_efficiency': '14.1',
#   'true_shooting': '.590',
#   'plus_minus': '-0.7',
#   'win_shares_percentage': '.104',
#   'in_playoff': 0},
#  {'name': 'Dennis Schröder',
#   'team': 'OKC',
#   'year': 2019,
#   'position': 'PG',
#   'player_efficiency': '12.7',
#   'true_shooting': '.508',
#   'plus_minus': '-2.0',
#   'win_shares_percentage': '.060',
#   'in_playoff': 1},
#  {'name': 'Mike Scott',
#   'team': 'TOT',
#   'year': 2019,
#   'position': 'PF',
#   'player_efficiency': '8.6',
#   'true_shooting': '.528',
#   'plus_minus': '-2.5',
#   'win_shares_percentage': '.053',
#   'in_playoff': 0},
#  {'name': 'Thabo Sefolosha',
#   'team': 'UTA',
#   'year': 2019,
#   'position': 'SF',
#   'player_efficiency': '12.1',
#   'true_shooting': '.599',
#   'plus_minus': '1.5',
#   'win_shares_percentage': '.115',
#   'in_playoff': 1},
#  {'name': 'Wayne Selden',
#   'team': 'TOT',
#   'year': 2019,
#   'position': 'SG',
#   'player_efficiency': '8.3',
#   'true_shooting': '.491',
#   'plus_minus': '-5.4',
#   'win_shares_percentage': '-0.009',
#   'in_playoff': 0},
#  {'name': 'Collin Sexton',
#   'team': 'CLE',
#   'year': 2019,
#   'position': 'PG',
#   'player_efficiency': '12.0',
#   'true_shooting': '.520',
#   'plus_minus': '-4.7',
#   'win_shares_percentage': '-0.011',
#   'in_playoff': 0},
#  {'name': 'Landry Shamet',
#   'team': 'TOT',
#   'year': 2019,
#   'position': 'SG',
#   'player_efficiency': '11.0',
#   'true_shooting': '.604',
#   'plus_minus': '-1.6',
#   'win_shares_percentage': '.095',
#   'in_playoff': 0},
#  {'name': 'Iman Shumpert',
#   'team': 'TOT',
#   'year': 2019,
#   'position': 'SG',
#   'player_efficiency': '9.1',
#   'true_shooting': '.499',
#   'plus_minus': '-1.9',
#   'win_shares_percentage': '.045',
#   'in_playoff': 0},
#  {'name': 'Pascal Siakam',
#   'team': 'TOR',
#   'year': 2019,
#   'position': 'PF',
#   'player_efficiency': '18.7',
#   'true_shooting': '.628',
#   'plus_minus': '2.4',
#   'win_shares_percentage': '.175',
#   'in_playoff': 1},
#  {'name': 'Jordan Sibert',
#   'team': 'ATL',
#   'year': 2019,
#   'position': 'SG',
#   'player_efficiency': '29.7',
#   'true_shooting': '1.500',
#   'plus_minus': '16.0',
#   'win_shares_percentage': '.183',
#   'in_playoff': 0},
#  {'name': 'Ben Simmons',
#   'team': 'PHI',
#   'year': 2019,
#   'position': 'PG',
#   'player_efficiency': '20.0',
#   'true_shooting': '.582',
#   'plus_minus': '3.6',
#   'win_shares_percentage': '.146',
#   'in_playoff': 1},
#  {'name': 'Jonathon Simmons',
#   'team': 'TOT',
#   'year': 2019,
#   'position': 'SG-SF',
#   'player_efficiency': '8.5',
#   'true_shooting': '.466',
#   'plus_minus': '-4.2',
#   'win_shares_percentage': '.013',
#   'in_playoff': 0},
#  {'name': 'Kobi Simmons',
#   'team': 'CLE',
#   'year': 2019,
#   'position': 'PG',
#   'player_efficiency': '0.0',
#   'true_shooting': '',
#   'plus_minus': '-10.6',
#   'win_shares_percentage': '-0.033',
#   'in_playoff': 0},
#  {'name': 'Anfernee Simons',
#   'team': 'POR',
#   'year': 2019,
#   'position': 'SG',
#   'player_efficiency': '11.1',
#   'true_shooting': '.535',
#   'plus_minus': '-5.3',
#   'win_shares_percentage': '.020',
#   'in_playoff': 1},
#  {'name': 'Marcus Smart',
#   'team': 'BOS',
#   'year': 2019,
#   'position': 'SG',
#   'player_efficiency': '13.1',
#   'true_shooting': '.568',
#   'plus_minus': '0.8',
#   'win_shares_percentage': '.116',
#   'in_playoff': 1},
#  {'name': 'Dennis Smith Jr.',
#   'team': 'TOT',
#   'year': 2019,
#   'position': 'PG',
#   'player_efficiency': '12.3',
#   'true_shooting': '.502',
#   'plus_minus': '-1.9',
#   'win_shares_percentage': '.001',
#   'in_playoff': 0},
#  {'name': 'Ish Smith',
#   'team': 'DET',
#   'year': 2019,
#   'position': 'PG',
#   'player_efficiency': '11.8',
#   'true_shooting': '.485',
#   'plus_minus': '-2.0',
#   'win_shares_percentage': '.064',
#   'in_playoff': 1},
#  {'name': 'J.R. Smith',
#   'team': 'CLE',
#   'year': 2019,
#   'position': 'SG',
#   'player_efficiency': '7.8',
#   'true_shooting': '.444',
#   'plus_minus': '-3.2',
#   'win_shares_percentage': '-0.038',
#   'in_playoff': 0},
#  {'name': 'Jason Smith',
#   'team': 'TOT',
#   'year': 2019,
#   'position': 'C-PF',
#   'player_efficiency': '9.8',
#   'true_shooting': '.492',
#   'plus_minus': '-4.7',
#   'win_shares_percentage': '.038',
#   'in_playoff': 0},
#  {'name': 'Zhaire Smith',
#   'team': 'PHI',
#   'year': 2019,
#   'position': 'SG',
#   'player_efficiency': '9.5',
#   'true_shooting': '.533',
#   'plus_minus': '-5.0',
#   'win_shares_percentage': '.048',
#   'in_playoff': 1},
#  {'name': 'Tony Snell',
#   'team': 'MIL',
#   'year': 2019,
#   'position': 'SF',
#   'player_efficiency': '10.7',
#   'true_shooting': '.585',
#   'plus_minus': '-0.7',
#   'win_shares_percentage': '.117',
#   'in_playoff': 1},
#  {'name': 'Ray Spalding',
#   'team': 'TOT',
#   'year': 2019,
#   'position': 'PF',
#   'player_efficiency': '14.6',
#   'true_shooting': '.516',
#   'plus_minus': '-5.1',
#   'win_shares_percentage': '.051',
#   'in_playoff': 0},
#  {'name': 'Omari Spellman',
#   'team': 'ATL',
#   'year': 2019,
#   'position': 'PF',
#   'player_efficiency': '12.4',
#   'true_shooting': '.516',
#   'plus_minus': '-1.2',
#   'win_shares_percentage': '.070',
#   'in_playoff': 0},
#  {'name': 'Nik Stauskas',
#   'team': 'TOT',
#   'year': 2019,
#   'position': 'SG',
#   'player_efficiency': '10.9',
#   'true_shooting': '.545',
#   'plus_minus': '-1.9',
#   'win_shares_percentage': '.052',
#   'in_playoff': 0},
#  {'name': 'D.J. Stephens',
#   'team': 'MEM',
#   'year': 2019,
#   'position': 'SG',
#   'player_efficiency': '5.5',
#   'true_shooting': '.500',
#   'plus_minus': '-5.5',
#   'win_shares_percentage': '-0.119',
#   'in_playoff': 0},
#  {'name': 'Lance Stephenson',
#   'team': 'LAL',
#   'year': 2019,
#   'position': 'SG',
#   'player_efficiency': '11.8',
#   'true_shooting': '.529',
#   'plus_minus': '-1.5',
#   'win_shares_percentage': '.049',
#   'in_playoff': 0},
#  {'name': 'Edmond Sumner',
#   'team': 'IND',
#   'year': 2019,
#   'position': 'PG',
#   'player_efficiency': '7.6',
#   'true_shooting': '.443',
#   'plus_minus': '-5.3',
#   'win_shares_percentage': '.020',
#   'in_playoff': 1},
#  {'name': 'Caleb Swanigan',
#   'team': 'TOT',
#   'year': 2019,
#   'position': 'PF',
#   'player_efficiency': '4.7',
#   'true_shooting': '.377',
#   'plus_minus': '-7.2',
#   'win_shares_percentage': '-0.060',
#   'in_playoff': 0},
#  {'name': 'Jayson Tatum',
#   'team': 'BOS',
#   'year': 2019,
#   'position': 'SF',
#   'player_efficiency': '15.1',
#   'true_shooting': '.547',
#   'plus_minus': '-0.2',
#   'win_shares_percentage': '.097',
#   'in_playoff': 1},
#  {'name': 'Jeff Teague',
#   'team': 'MIN',
#   'year': 2019,
#   'position': 'PG',
#   'player_efficiency': '15.4',
#   'true_shooting': '.528',
#   'plus_minus': '-0.4',
#   'win_shares_percentage': '.085',
#   'in_playoff': 0},
#  {'name': 'Garrett Temple',
#   'team': 'TOT',
#   'year': 2019,
#   'position': 'SG',
#   'player_efficiency': '8.5',
#   'true_shooting': '.543',
#   'plus_minus': '-2.8',
#   'win_shares_percentage': '.052',
#   'in_playoff': 0},
#  {'name': 'Miloš Teodosić',
#   'team': 'LAC',
#   'year': 2019,
#   'position': 'PG',
#   'player_efficiency': '6.5',
#   'true_shooting': '.557',
#   'plus_minus': '-5.4',
#   'win_shares_percentage': '-0.019',
#   'in_playoff': 1},
#  {'name': 'Jared Terrell',
#   'team': 'MIN',
#   'year': 2019,
#   'position': 'SG',
#   'player_efficiency': '0.7',
#   'true_shooting': '.372',
#   'plus_minus': '-10.9',
#   'win_shares_percentage': '-0.140',
#   'in_playoff': 0},
#  ...]

# %% [markdown]
# Saving advanced scrape to a dataframe:

# %%
df_advanced = pd.DataFrame(players_advanced)
df_advanced
# Out:
#                            name team  year position player_efficiency  \
# 0                  Steven Adams  OKC  2020        C              20.5
# 1                   Bam Adebayo  MIA  2020       PF              20.3
# 2             LaMarcus Aldridge  SAS  2020        C              19.7
# 3                Kyle Alexander  MIA  2020        C               4.7
# 4      Nickeil Alexander-Walker  NOP  2020       SG               8.9
# ...                         ...  ...   ...      ...               ...
# 13940         Orlando Woolridge  LAL  1990       SF              17.6
# 13941          Haywoode Workman  ATL  1990       PG              26.1
# 13942             James Worthy*  LAL  1990       SF              19.8
# 13943               Danny Young  POR  1990       PG              11.5
# 13944             Michael Young  LAC  1990       SF              16.0
#
#       true_shooting plus_minus win_shares_percentage  in_playoff
# 0              .604        2.9                  .185           1
# 1              .598        3.4                  .168           1
# 2              .571        1.4                  .122           0
# 3              .500       -9.6                -0.003           1
# 4              .473       -4.6                -0.020           0
# ...             ...        ...                   ...         ...
# 13940          .601        1.5                  .161           1
# 13941          .773       13.6                  .357           0
# 13942          .586        3.8                  .172           1
# 13943          .508        0.9                  .103           1
# 13944          .520        0.4                  .119           0
#
# [13945 rows x 9 columns]

# %% [markdown]
# Scraping for the same advanced statistics for the current players (except no in_playoffs column since that will be what we are predicting for the 2021 players):

# %%
#advanced stats 2021:
players_2021_advanced = []

year = 2021
url = f'https://www.basketball-reference.com/leagues/NBA_{year}_advanced.html'
res = requests.get(url)
soup = BeautifulSoup(res.content, 'lxml')
table = soup.find('table', {'id': 'advanced_stats'})
for row in table.find('tbody').find_all('tr', {'class':'full_table'}):
    player = {}
    player['name'] = row.find('td', {'data-stat': 'player'}).text
    player['team'] = row.find('td', {'data-stat': 'team_id'}).text
    player['year'] = year
    player['position'] = row.find('td', {'data-stat': 'pos'}).text
    player['player_efficiency'] = row.find('td', {'data-stat': 'per'}).text
    player['true_shooting'] = row.find('td', {'data-stat': 'ts_pct'}).text
    player['plus_minus'] = row.find('td', {'data-stat': 'bpm'}).text
    player['win_shares_percentage'] = row.find('td', {'data-stat': 'ws_per_48'}).text
    players_2021_advanced.append(player)

time.sleep(5)        
players_2021_advanced
# Out:
# [{'name': 'Precious Achiuwa',
#   'team': 'MIA',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '15.4',
#   'true_shooting': '.587',
#   'plus_minus': '-2.7',
#   'win_shares_percentage': '.111'},
#  {'name': 'Jaylen Adams',
#   'team': 'MIL',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '-6.6',
#   'true_shooting': '.125',
#   'plus_minus': '-19.8',
#   'win_shares_percentage': '-0.250'},
#  {'name': 'Steven Adams',
#   'team': 'NOP',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '16.0',
#   'true_shooting': '.597',
#   'plus_minus': '-0.9',
#   'win_shares_percentage': '.110'},
#  {'name': 'Bam Adebayo',
#   'team': 'MIA',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '22.0',
#   'true_shooting': '.631',
#   'plus_minus': '4.4',
#   'win_shares_percentage': '.193'},
#  {'name': 'LaMarcus Aldridge',
#   'team': 'SAS',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '15.0',
#   'true_shooting': '.545',
#   'plus_minus': '-1.2',
#   'win_shares_percentage': '.074'},
#  {'name': 'Ty-Shon Alexander',
#   'team': 'PHO',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '-11.9',
#   'true_shooting': '.000',
#   'plus_minus': '-21.2',
#   'win_shares_percentage': '-0.320'},
#  {'name': 'Nickeil Alexander-Walker',
#   'team': 'NOP',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '12.4',
#   'true_shooting': '.508',
#   'plus_minus': '-1.8',
#   'win_shares_percentage': '.028'},
#  {'name': 'Grayson Allen',
#   'team': 'MEM',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '12.5',
#   'true_shooting': '.592',
#   'plus_minus': '-0.2',
#   'win_shares_percentage': '.110'},
#  {'name': 'Jarrett Allen',
#   'team': 'TOT',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '23.6',
#   'true_shooting': '.714',
#   'plus_minus': '3.4',
#   'win_shares_percentage': '.219'},
#  {'name': 'Al-Farouq Aminu',
#   'team': 'ORL',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '11.8',
#   'true_shooting': '.500',
#   'plus_minus': '-2.8',
#   'win_shares_percentage': '.051'},
#  {'name': 'Kyle Anderson',
#   'team': 'MEM',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '17.6',
#   'true_shooting': '.585',
#   'plus_minus': '2.9',
#   'win_shares_percentage': '.142'},
#  {'name': 'Giannis Antetokounmpo',
#   'team': 'MIL',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '29.0',
#   'true_shooting': '.618',
#   'plus_minus': '8.1',
#   'win_shares_percentage': '.233'},
#  {'name': 'Kostas Antetokounmpo',
#   'team': 'LAL',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '-0.2',
#   'true_shooting': '.387',
#   'plus_minus': '-12.3',
#   'win_shares_percentage': '-0.202'},
#  {'name': 'Thanasis Antetokounmpo',
#   'team': 'MIL',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '11.4',
#   'true_shooting': '.616',
#   'plus_minus': '-2.8',
#   'win_shares_percentage': '.088'},
#  {'name': 'Carmelo Anthony',
#   'team': 'POR',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '14.9',
#   'true_shooting': '.532',
#   'plus_minus': '-1.9',
#   'win_shares_percentage': '.061'},
#  {'name': 'Cole Anthony',
#   'team': 'ORL',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '10.2',
#   'true_shooting': '.469',
#   'plus_minus': '-4.1',
#   'win_shares_percentage': '-0.009'},
#  {'name': 'OG Anunoby',
#   'team': 'TOR',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '13.8',
#   'true_shooting': '.607',
#   'plus_minus': '0.2',
#   'win_shares_percentage': '.097'},
#  {'name': 'Ryan Arcidiacono',
#   'team': 'CHI',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '11.1',
#   'true_shooting': '.565',
#   'plus_minus': '-1.7',
#   'win_shares_percentage': '.108'},
#  {'name': 'D.J. Augustin',
#   'team': 'MIL',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '10.0',
#   'true_shooting': '.520',
#   'plus_minus': '-2.3',
#   'win_shares_percentage': '.075'},
#  {'name': 'Deni Avdija',
#   'team': 'WAS',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '8.5',
#   'true_shooting': '.551',
#   'plus_minus': '-3.4',
#   'win_shares_percentage': '.047'},
#  {'name': 'Deandre Ayton',
#   'team': 'PHO',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '18.9',
#   'true_shooting': '.624',
#   'plus_minus': '-0.2',
#   'win_shares_percentage': '.175'},
#  {'name': 'Udoka Azubuike',
#   'team': 'UTA',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '10.6',
#   'true_shooting': '.622',
#   'plus_minus': '-4.3',
#   'win_shares_percentage': '.107'},
#  {'name': 'Dwayne Bacon',
#   'team': 'ORL',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '9.3',
#   'true_shooting': '.505',
#   'plus_minus': '-5.1',
#   'win_shares_percentage': '.022'},
#  {'name': 'Marvin Bagley III',
#   'team': 'SAC',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '15.9',
#   'true_shooting': '.550',
#   'plus_minus': '-3.5',
#   'win_shares_percentage': '.045'},
#  {'name': 'LaMelo Ball',
#   'team': 'CHO',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '18.8',
#   'true_shooting': '.561',
#   'plus_minus': '3.1',
#   'win_shares_percentage': '.124'},
#  {'name': 'Lonzo Ball',
#   'team': 'NOP',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '15.0',
#   'true_shooting': '.563',
#   'plus_minus': '0.7',
#   'win_shares_percentage': '.083'},
#  {'name': 'Mo Bamba',
#   'team': 'ORL',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '20.4',
#   'true_shooting': '.582',
#   'plus_minus': '0.5',
#   'win_shares_percentage': '.141'},
#  {'name': 'Desmond Bane',
#   'team': 'MEM',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '11.9',
#   'true_shooting': '.618',
#   'plus_minus': '-1.6',
#   'win_shares_percentage': '.090'},
#  {'name': 'Harrison Barnes',
#   'team': 'SAC',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '16.3',
#   'true_shooting': '.624',
#   'plus_minus': '0.3',
#   'win_shares_percentage': '.106'},
#  {'name': 'RJ Barrett',
#   'team': 'NYK',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '13.4',
#   'true_shooting': '.520',
#   'plus_minus': '-2.0',
#   'win_shares_percentage': '.067'},
#  {'name': 'Will Barton',
#   'team': 'DEN',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '11.3',
#   'true_shooting': '.537',
#   'plus_minus': '-2.5',
#   'win_shares_percentage': '.053'},
#  {'name': 'Keita Bates-Diop',
#   'team': 'SAS',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '12.6',
#   'true_shooting': '.492',
#   'plus_minus': '-0.5',
#   'win_shares_percentage': '.102'},
#  {'name': 'Nicolas Batum',
#   'team': 'LAC',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '13.5',
#   'true_shooting': '.641',
#   'plus_minus': '1.3',
#   'win_shares_percentage': '.140'},
#  {'name': 'Aron Baynes',
#   'team': 'TOR',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '9.8',
#   'true_shooting': '.498',
#   'plus_minus': '-4.9',
#   'win_shares_percentage': '.045'},
#  {'name': 'Kent Bazemore',
#   'team': 'GSW',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '12.8',
#   'true_shooting': '.611',
#   'plus_minus': '0.4',
#   'win_shares_percentage': '.101'},
#  {'name': 'Darius Bazley',
#   'team': 'OKC',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '9.3',
#   'true_shooting': '.487',
#   'plus_minus': '-4.1',
#   'win_shares_percentage': '-0.004'},
#  {'name': 'Bradley Beal',
#   'team': 'WAS',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '24.5',
#   'true_shooting': '.591',
#   'plus_minus': '4.7',
#   'win_shares_percentage': '.142'},
#  {'name': 'Malik Beasley',
#   'team': 'MIN',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '15.9',
#   'true_shooting': '.582',
#   'plus_minus': '0.3',
#   'win_shares_percentage': '.071'},
#  {'name': 'Jordan Bell',
#   'team': 'WAS',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '8.0',
#   'true_shooting': '.333',
#   'plus_minus': '-6.3',
#   'win_shares_percentage': '-0.034'},
#  {'name': "DeAndre' Bembry",
#   'team': 'TOR',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '10.5',
#   'true_shooting': '.633',
#   'plus_minus': '-2.0',
#   'win_shares_percentage': '.079'},
#  {'name': 'Dāvis Bertāns',
#   'team': 'WAS',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '11.3',
#   'true_shooting': '.603',
#   'plus_minus': '-1.4',
#   'win_shares_percentage': '.085'},
#  {'name': 'Patrick Beverley',
#   'team': 'LAC',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '13.3',
#   'true_shooting': '.613',
#   'plus_minus': '0.8',
#   'win_shares_percentage': '.134'},
#  {'name': 'Saddiq Bey',
#   'team': 'DET',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '12.5',
#   'true_shooting': '.582',
#   'plus_minus': '-0.8',
#   'win_shares_percentage': '.090'},
#  {'name': 'Tyler Bey',
#   'team': 'DAL',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '14.0',
#   'true_shooting': '.444',
#   'plus_minus': '-4.5',
#   'win_shares_percentage': '.068'},
#  {'name': 'Khem Birch',
#   'team': 'ORL',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '15.6',
#   'true_shooting': '.564',
#   'plus_minus': '-1.5',
#   'win_shares_percentage': '.138'},
#  {'name': 'Goga Bitadze',
#   'team': 'IND',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '14.1',
#   'true_shooting': '.569',
#   'plus_minus': '-2.9',
#   'win_shares_percentage': '.093'},
#  {'name': 'Bismack Biyombo',
#   'team': 'CHO',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '12.0',
#   'true_shooting': '.566',
#   'plus_minus': '-2.9',
#   'win_shares_percentage': '.095'},
#  {'name': 'Nemanja Bjelica',
#   'team': 'SAC',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '15.0',
#   'true_shooting': '.589',
#   'plus_minus': '-1.4',
#   'win_shares_percentage': '.070'},
#  {'name': 'Eric Bledsoe',
#   'team': 'NOP',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '12.7',
#   'true_shooting': '.552',
#   'plus_minus': '-1.9',
#   'win_shares_percentage': '.057'},
#  {'name': 'Keljin Blevins',
#   'team': 'POR',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '-3.6',
#   'true_shooting': '.182',
#   'plus_minus': '-14.1',
#   'win_shares_percentage': '-0.191'},
#  {'name': 'Bogdan Bogdanović',
#   'team': 'ATL',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '9.9',
#   'true_shooting': '.537',
#   'plus_minus': '-2.2',
#   'win_shares_percentage': '.043'},
#  {'name': 'Bojan Bogdanović',
#   'team': 'UTA',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '13.3',
#   'true_shooting': '.587',
#   'plus_minus': '-0.7',
#   'win_shares_percentage': '.114'},
#  {'name': 'Bol Bol',
#   'team': 'DEN',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '8.0',
#   'true_shooting': '.612',
#   'plus_minus': '-3.8',
#   'win_shares_percentage': '-0.001'},
#  {'name': 'Marques Bolden',
#   'team': 'CLE',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '13.4',
#   'true_shooting': '.537',
#   'plus_minus': '-2.8',
#   'win_shares_percentage': '.067'},
#  {'name': 'Jordan Bone',
#   'team': 'ORL',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '8.9',
#   'true_shooting': '.519',
#   'plus_minus': '-4.2',
#   'win_shares_percentage': '.054'},
#  {'name': 'Isaac Bonga',
#   'team': 'WAS',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '5.1',
#   'true_shooting': '.503',
#   'plus_minus': '-5.7',
#   'win_shares_percentage': '.021'},
#  {'name': 'Devin Booker',
#   'team': 'PHO',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '18.6',
#   'true_shooting': '.597',
#   'plus_minus': '-0.1',
#   'win_shares_percentage': '.103'},
#  {'name': 'Chris Boucher',
#   'team': 'TOR',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '22.9',
#   'true_shooting': '.660',
#   'plus_minus': '3.7',
#   'win_shares_percentage': '.219'},
#  {'name': 'Brian Bowen',
#   'team': 'IND',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '17.7',
#   'true_shooting': '.615',
#   'plus_minus': '-1.8',
#   'win_shares_percentage': '.155'},
#  {'name': 'Avery Bradley',
#   'team': 'MIA',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '10.4',
#   'true_shooting': '.607',
#   'plus_minus': '-3.2',
#   'win_shares_percentage': '.076'},
#  {'name': 'Tony Bradley',
#   'team': 'PHI',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '20.8',
#   'true_shooting': '.570',
#   'plus_minus': '1.7',
#   'win_shares_percentage': '.218'},
#  {'name': 'Jarrell Brantley',
#   'team': 'UTA',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '11.7',
#   'true_shooting': '.550',
#   'plus_minus': '-1.3',
#   'win_shares_percentage': '.103'},
#  {'name': 'Ignas Brazdeikis',
#   'team': 'NYK',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '11.3',
#   'true_shooting': '.532',
#   'plus_minus': '-4.8',
#   'win_shares_percentage': '.032'},
#  {'name': 'Mikal Bridges',
#   'team': 'PHO',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '16.9',
#   'true_shooting': '.658',
#   'plus_minus': '3.1',
#   'win_shares_percentage': '.180'},
#  {'name': 'Miles Bridges',
#   'team': 'CHO',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '12.7',
#   'true_shooting': '.609',
#   'plus_minus': '-1.4',
#   'win_shares_percentage': '.084'},
#  {'name': 'Malcolm Brogdon',
#   'team': 'IND',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '17.6',
#   'true_shooting': '.546',
#   'plus_minus': '1.2',
#   'win_shares_percentage': '.101'},
#  {'name': 'Dillon Brooks',
#   'team': 'MEM',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '11.0',
#   'true_shooting': '.490',
#   'plus_minus': '-4.6',
#   'win_shares_percentage': '.008'},
#  {'name': 'Bruce Brown',
#   'team': 'BRK',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '16.2',
#   'true_shooting': '.634',
#   'plus_minus': '-0.5',
#   'win_shares_percentage': '.147'},
#  {'name': 'Jaylen Brown',
#   'team': 'BOS',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '21.0',
#   'true_shooting': '.591',
#   'plus_minus': '3.3',
#   'win_shares_percentage': '.132'},
#  {'name': 'Moses Brown',
#   'team': 'OKC',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '33.7',
#   'true_shooting': '.650',
#   'plus_minus': '9.1',
#   'win_shares_percentage': '.348'},
#  {'name': 'Sterling Brown',
#   'team': 'HOU',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '11.9',
#   'true_shooting': '.585',
#   'plus_minus': '-1.0',
#   'win_shares_percentage': '.101'},
#  {'name': 'Troy Brown Jr.',
#   'team': 'WAS',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '6.3',
#   'true_shooting': '.465',
#   'plus_minus': '-5.7',
#   'win_shares_percentage': '-0.015'},
#  {'name': 'Jalen Brunson',
#   'team': 'DAL',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '17.4',
#   'true_shooting': '.649',
#   'plus_minus': '0.6',
#   'win_shares_percentage': '.144'},
#  {'name': 'Thomas Bryant',
#   'team': 'WAS',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '18.8',
#   'true_shooting': '.704',
#   'plus_minus': '0.4',
#   'win_shares_percentage': '.161'},
#  {'name': 'Reggie Bullock',
#   'team': 'NYK',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '8.9',
#   'true_shooting': '.536',
#   'plus_minus': '-2.1',
#   'win_shares_percentage': '.070'},
#  {'name': 'Trey Burke',
#   'team': 'DAL',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '13.9',
#   'true_shooting': '.580',
#   'plus_minus': '-0.2',
#   'win_shares_percentage': '.093'},
#  {'name': 'Alec Burks',
#   'team': 'NYK',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '13.4',
#   'true_shooting': '.552',
#   'plus_minus': '-0.2',
#   'win_shares_percentage': '.106'},
#  {'name': 'Jimmy Butler',
#   'team': 'MIA',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '25.4',
#   'true_shooting': '.571',
#   'plus_minus': '6.8',
#   'win_shares_percentage': '.233'},
#  {'name': 'Bruno Caboclo',
#   'team': 'HOU',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '9.2',
#   'true_shooting': '.475',
#   'plus_minus': '-10.6',
#   'win_shares_percentage': '-0.068'},
#  {'name': 'Devontae Cacok',
#   'team': 'LAL',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '21.0',
#   'true_shooting': '.820',
#   'plus_minus': '6.2',
#   'win_shares_percentage': '.110'},
#  {'name': 'Kentavious Caldwell-Pope',
#   'team': 'LAL',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '9.7',
#   'true_shooting': '.585',
#   'plus_minus': '-2.1',
#   'win_shares_percentage': '.096'},
#  {'name': 'Facundo Campazzo',
#   'team': 'DEN',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '11.7',
#   'true_shooting': '.580',
#   'plus_minus': '-1.4',
#   'win_shares_percentage': '.103'},
#  {'name': 'Vlatko Čančar',
#   'team': 'DEN',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '7.6',
#   'true_shooting': '.490',
#   'plus_minus': '-3.5',
#   'win_shares_percentage': '.011'},
#  {'name': 'Clint Capela',
#   'team': 'ATL',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '24.1',
#   'true_shooting': '.593',
#   'plus_minus': '2.4',
#   'win_shares_percentage': '.188'},
#  {'name': 'Vernon Carey Jr.',
#   'team': 'CHO',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '29.7',
#   'true_shooting': '.387',
#   'plus_minus': '7.4',
#   'win_shares_percentage': '.198'},
#  {'name': 'Jevon Carter',
#   'team': 'PHO',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '9.9',
#   'true_shooting': '.465',
#   'plus_minus': '0.3',
#   'win_shares_percentage': '.087'},
#  {'name': 'Wendell Carter Jr.',
#   'team': 'CHI',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '16.2',
#   'true_shooting': '.598',
#   'plus_minus': '-1.6',
#   'win_shares_percentage': '.123'},
#  {'name': 'Michael Carter-Williams',
#   'team': 'ORL',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '10.7',
#   'true_shooting': '.476',
#   'plus_minus': '-3.9',
#   'win_shares_percentage': '.026'},
#  {'name': 'Alex Caruso',
#   'team': 'LAL',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '10.9',
#   'true_shooting': '.542',
#   'plus_minus': '-0.3',
#   'win_shares_percentage': '.102'},
#  {'name': 'Willie Cauley-Stein',
#   'team': 'DAL',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '14.8',
#   'true_shooting': '.654',
#   'plus_minus': '-1.1',
#   'win_shares_percentage': '.149'},
#  {'name': 'Chris Chiozza',
#   'team': 'BRK',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '14.2',
#   'true_shooting': '.503',
#   'plus_minus': '-0.8',
#   'win_shares_percentage': '.096'},
#  {'name': 'Marquese Chriss',
#   'team': 'GSW',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '11.8',
#   'true_shooting': '.412',
#   'plus_minus': '-3.2',
#   'win_shares_percentage': '-0.027'},
#  {'name': 'Gary Clark',
#   'team': 'ORL',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '5.6',
#   'true_shooting': '.431',
#   'plus_minus': '-5.3',
#   'win_shares_percentage': '.012'},
#  {'name': 'Brandon Clarke',
#   'team': 'MEM',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '16.8',
#   'true_shooting': '.561',
#   'plus_minus': '0.6',
#   'win_shares_percentage': '.138'},
#  {'name': 'Jordan Clarkson',
#   'team': 'UTA',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '18.8',
#   'true_shooting': '.581',
#   'plus_minus': '2.7',
#   'win_shares_percentage': '.137'},
#  {'name': 'Nicolas Claxton',
#   'team': 'BRK',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '29.7',
#   'true_shooting': '.711',
#   'plus_minus': '8.1',
#   'win_shares_percentage': '.294'},
#  {'name': 'Amir Coffey',
#   'team': 'LAC',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '10.0',
#   'true_shooting': '.637',
#   'plus_minus': '-2.8',
#   'win_shares_percentage': '.061'},
#  {'name': 'John Collins',
#   'team': 'ATL',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '19.4',
#   'true_shooting': '.625',
#   'plus_minus': '1.5',
#   'win_shares_percentage': '.157'},
#  {'name': 'Mike Conley',
#   'team': 'UTA',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '19.2',
#   'true_shooting': '.588',
#   'plus_minus': '3.9',
#   'win_shares_percentage': '.194'},
#  {'name': 'Pat Connaughton',
#   'team': 'MIL',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '12.7',
#   'true_shooting': '.589',
#   'plus_minus': '0.9',
#   'win_shares_percentage': '.131'},
#  {'name': 'Quinn Cook',
#   'team': 'LAL',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '14.1',
#   'true_shooting': '.585',
#   'plus_minus': '-1.1',
#   'win_shares_percentage': '.108'},
#  {'name': 'Tyler Cook',
#   'team': 'BRK',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '1.6',
#   'true_shooting': '.333',
#   'plus_minus': '-6.8',
#   'win_shares_percentage': '-0.046'},
#  {'name': 'DeMarcus Cousins',
#   'team': 'HOU',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '15.1',
#   'true_shooting': '.511',
#   'plus_minus': '0.4',
#   'win_shares_percentage': '.081'},
#  {'name': 'Robert Covington',
#   'team': 'POR',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '10.1',
#   'true_shooting': '.513',
#   'plus_minus': '-1.7',
#   'win_shares_percentage': '.048'},
#  {'name': 'Torrey Craig',
#   'team': 'MIL',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '10.2',
#   'true_shooting': '.490',
#   'plus_minus': '-1.2',
#   'win_shares_percentage': '.096'},
#  {'name': 'Jae Crowder',
#   'team': 'PHO',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '11.7',
#   'true_shooting': '.566',
#   'plus_minus': '0.5',
#   'win_shares_percentage': '.100'},
#  {'name': 'Jarrett Culver',
#   'team': 'MIN',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '9.3',
#   'true_shooting': '.478',
#   'plus_minus': '-6.7',
#   'win_shares_percentage': '-0.007'},
#  {'name': 'Seth Curry',
#   'team': 'PHI',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '12.4',
#   'true_shooting': '.614',
#   'plus_minus': '-1.4',
#   'win_shares_percentage': '.102'},
#  {'name': 'Stephen Curry',
#   'team': 'GSW',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '25.2',
#   'true_shooting': '.646',
#   'plus_minus': '7.5',
#   'win_shares_percentage': '.200'},
#  {'name': 'Anthony Davis',
#   'team': 'LAL',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '24.7',
#   'true_shooting': '.588',
#   'plus_minus': '6.4',
#   'win_shares_percentage': '.205'},
#  {'name': 'Ed Davis',
#   'team': 'MIN',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '12.1',
#   'true_shooting': '.462',
#   'plus_minus': '-3.4',
#   'win_shares_percentage': '.114'},
#  {'name': 'Terence Davis',
#   'team': 'TOR',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '11.7',
#   'true_shooting': '.549',
#   'plus_minus': '-2.6',
#   'win_shares_percentage': '.043'},
#  {'name': 'DeMar DeRozan',
#   'team': 'SAS',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '22.2',
#   'true_shooting': '.597',
#   'plus_minus': '4.1',
#   'win_shares_percentage': '.200'},
#  {'name': 'Hamidou Diallo',
#   'team': 'OKC',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '15.1',
#   'true_shooting': '.536',
#   'plus_minus': '-1.7',
#   'win_shares_percentage': '.081'},
#  {'name': 'Gorgui Dieng',
#   'team': 'MEM',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '19.3',
#   'true_shooting': '.682',
#   'plus_minus': '2.6',
#   'win_shares_percentage': '.194'},
#  {'name': 'Spencer Dinwiddie',
#   'team': 'BRK',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '10.1',
#   'true_shooting': '.536',
#   'plus_minus': '-1.4',
#   'win_shares_percentage': '.045'},
#  {'name': 'Donte DiVincenzo',
#   'team': 'MIL',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '12.8',
#   'true_shooting': '.528',
#   'plus_minus': '-0.5',
#   'win_shares_percentage': '.089'},
#  {'name': 'Luka Dončić',
#   'team': 'DAL',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '25.9',
#   'true_shooting': '.585',
#   'plus_minus': '7.2',
#   'win_shares_percentage': '.166'},
#  {'name': 'Luguentz Dort',
#   'team': 'OKC',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '8.8',
#   'true_shooting': '.511',
#   'plus_minus': '-4.6',
#   'win_shares_percentage': '.013'},
#  {'name': 'Damyean Dotson',
#   'team': 'CLE',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '9.4',
#   'true_shooting': '.492',
#   'plus_minus': '-3.5',
#   'win_shares_percentage': '.019'},
#  {'name': 'Devon Dotson',
#   'team': 'CHI',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '6.8',
#   'true_shooting': '.500',
#   'plus_minus': '-8.5',
#   'win_shares_percentage': '.000'},
#  {'name': 'Sekou Doumbouya',
#   'team': 'DET',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '5.9',
#   'true_shooting': '.440',
#   'plus_minus': '-7.4',
#   'win_shares_percentage': '-0.018'},
#  {'name': 'PJ Dozier',
#   'team': 'DEN',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '13.8',
#   'true_shooting': '.553',
#   'plus_minus': '-0.5',
#   'win_shares_percentage': '.105'},
#  {'name': 'Goran Dragić',
#   'team': 'MIA',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '13.8',
#   'true_shooting': '.573',
#   'plus_minus': '-3.0',
#   'win_shares_percentage': '.059'},
#  {'name': 'Andre Drummond',
#   'team': 'CLE',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '20.8',
#   'true_shooting': '.500',
#   'plus_minus': '-0.3',
#   'win_shares_percentage': '.050'},
#  {'name': 'Jared Dudley',
#   'team': 'LAL',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '5.5',
#   'true_shooting': '.429',
#   'plus_minus': '-3.6',
#   'win_shares_percentage': '.082'},
#  {'name': 'Kevin Durant',
#   'team': 'BRK',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '25.2',
#   'true_shooting': '.652',
#   'plus_minus': '5.4',
#   'win_shares_percentage': '.187'},
#  {'name': 'Anthony Edwards',
#   'team': 'MIN',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '9.8',
#   'true_shooting': '.466',
#   'plus_minus': '-5.1',
#   'win_shares_percentage': '-0.043'},
#  {'name': 'Carsen Edwards',
#   'team': 'BOS',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '13.6',
#   'true_shooting': '.568',
#   'plus_minus': '-3.4',
#   'win_shares_percentage': '.103'},
#  {'name': 'CJ Elleby',
#   'team': 'POR',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '10.8',
#   'true_shooting': '.558',
#   'plus_minus': '-4.0',
#   'win_shares_percentage': '.068'},
#  {'name': 'Wayne Ellington',
#   'team': 'DET',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '13.2',
#   'true_shooting': '.634',
#   'plus_minus': '0.2',
#   'win_shares_percentage': '.098'},
#  {'name': 'Joel Embiid',
#   'team': 'PHI',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '31.1',
#   'true_shooting': '.646',
#   'plus_minus': '8.5',
#   'win_shares_percentage': '.283'},
#  {'name': 'James Ennis',
#   'team': 'ORL',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '12.9',
#   'true_shooting': '.628',
#   'plus_minus': '-1.7',
#   'win_shares_percentage': '.112'},
#  {'name': 'Drew Eubanks',
#   'team': 'SAS',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '10.7',
#   'true_shooting': '.468',
#   'plus_minus': '-4.0',
#   'win_shares_percentage': '.043'},
#  {'name': 'Dante Exum',
#   'team': 'CLE',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '6.0',
#   'true_shooting': '.428',
#   'plus_minus': '-3.1',
#   'win_shares_percentage': '-0.017'},
#  {'name': 'Tacko Fall',
#   'team': 'BOS',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '22.4',
#   'true_shooting': '.636',
#   'plus_minus': '2.4',
#   'win_shares_percentage': '.220'},
#  {'name': 'Derrick Favors',
#   'team': 'UTA',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '20.2',
#   'true_shooting': '.689',
#   'plus_minus': '2.3',
#   'win_shares_percentage': '.244'},
#  {'name': 'Cristiano Felício',
#   'team': 'CHI',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '18.2',
#   'true_shooting': '.731',
#   'plus_minus': '3.6',
#   'win_shares_percentage': '.196'},
#  {'name': 'Terrance Ferguson',
#   'team': 'PHI',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '-6.9',
#   'true_shooting': '.200',
#   'plus_minus': '-15.4',
#   'win_shares_percentage': '-0.164'},
#  {'name': 'Bruno Fernando',
#   'team': 'ATL',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '6.8',
#   'true_shooting': '.491',
#   'plus_minus': '-5.9',
#   'win_shares_percentage': '-0.008'},
#  {'name': 'Yogi Ferrell',
#   'team': 'CLE',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '12.6',
#   'true_shooting': '.434',
#   'plus_minus': '-1.5',
#   'win_shares_percentage': '-0.021'},
#  {'name': 'Dorian Finney-Smith',
#   'team': 'DAL',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '9.6',
#   'true_shooting': '.552',
#   'plus_minus': '-1.7',
#   'win_shares_percentage': '.078'},
#  {'name': 'Malachi Flynn',
#   'team': 'TOR',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '3.3',
#   'true_shooting': '.346',
#   'plus_minus': '-8.7',
#   'win_shares_percentage': '-0.067'},
#  {'name': 'Bryn Forbes',
#   'team': 'MIL',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '11.9',
#   'true_shooting': '.618',
#   'plus_minus': '-2.2',
#   'win_shares_percentage': '.086'},
#  {'name': 'Trent Forrest',
#   'team': 'UTA',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '6.7',
#   'true_shooting': '.258',
#   'plus_minus': '-3.0',
#   'win_shares_percentage': '.044'},
#  {'name': 'Evan Fournier',
#   'team': 'ORL',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '17.9',
#   'true_shooting': '.593',
#   'plus_minus': '0.5',
#   'win_shares_percentage': '.107'},
#  {'name': "De'Aaron Fox",
#   'team': 'SAC',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '18.8',
#   'true_shooting': '.551',
#   'plus_minus': '0.2',
#   'win_shares_percentage': '.063'},
#  {'name': 'Tim Frazier',
#   'team': 'MEM',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '0.3',
#   'true_shooting': '.250',
#   'plus_minus': '-13.6',
#   'win_shares_percentage': '-0.108'},
#  {'name': 'Markelle Fultz',
#   'team': 'ORL',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '12.0',
#   'true_shooting': '.458',
#   'plus_minus': '-4.6',
#   'win_shares_percentage': '-0.012'},
#  {'name': 'Wenyen Gabriel',
#   'team': 'NOP',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '-0.3',
#   'true_shooting': '.000',
#   'plus_minus': '-11.3',
#   'win_shares_percentage': '-0.146'},
#  {'name': 'Daniel Gafford',
#   'team': 'CHI',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '17.7',
#   'true_shooting': '.684',
#   'plus_minus': '0.2',
#   'win_shares_percentage': '.170'},
#  {'name': 'Danilo Gallinari',
#   'team': 'ATL',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '13.7',
#   'true_shooting': '.582',
#   'plus_minus': '-1.1',
#   'win_shares_percentage': '.099'},
#  {'name': 'Langston Galloway',
#   'team': 'PHO',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '12.9',
#   'true_shooting': '.635',
#   'plus_minus': '-0.4',
#   'win_shares_percentage': '.127'},
#  {'name': 'Darius Garland',
#   'team': 'CLE',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '12.6',
#   'true_shooting': '.524',
#   'plus_minus': '-2.5',
#   'win_shares_percentage': '.021'},
#  {'name': 'Marc Gasol',
#   'team': 'LAL',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '11.2',
#   'true_shooting': '.561',
#   'plus_minus': '1.2',
#   'win_shares_percentage': '.130'},
#  {'name': 'Rudy Gay',
#   'team': 'SAS',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '14.2',
#   'true_shooting': '.523',
#   'plus_minus': '-1.0',
#   'win_shares_percentage': '.059'},
#  {'name': 'Paul George',
#   'team': 'LAC',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '22.7',
#   'true_shooting': '.642',
#   'plus_minus': '5.3',
#   'win_shares_percentage': '.173'},
#  {'name': 'Taj Gibson',
#   'team': 'NYK',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '12.4',
#   'true_shooting': '.620',
#   'plus_minus': '-1.4',
#   'win_shares_percentage': '.134'},
#  {'name': 'Harry Giles',
#   'team': 'POR',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '11.3',
#   'true_shooting': '.486',
#   'plus_minus': '-4.7',
#   'win_shares_percentage': '.060'},
#  {'name': 'Shai Gilgeous-Alexander',
#   'team': 'OKC',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '22.0',
#   'true_shooting': '.627',
#   'plus_minus': '4.4',
#   'win_shares_percentage': '.170'},
#  {'name': 'Anthony Gill',
#   'team': 'WAS',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '8.0',
#   'true_shooting': '.425',
#   'plus_minus': '-3.7',
#   'win_shares_percentage': '.028'},
#  {'name': 'Rudy Gobert',
#   'team': 'UTA',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '22.5',
#   'true_shooting': '.649',
#   'plus_minus': '3.4',
#   'win_shares_percentage': '.220'},
#  {'name': 'Brandon Goodwin',
#   'team': 'ATL',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '8.1',
#   'true_shooting': '.438',
#   'plus_minus': '-3.6',
#   'win_shares_percentage': '.006'},
#  {'name': 'Aaron Gordon',
#   'team': 'ORL',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '14.7',
#   'true_shooting': '.528',
#   'plus_minus': '0.6',
#   'win_shares_percentage': '.042'},
#  {'name': 'Eric Gordon',
#   'team': 'HOU',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '14.9',
#   'true_shooting': '.582',
#   'plus_minus': '-0.4',
#   'win_shares_percentage': '.074'},
#  {'name': "Devonte' Graham",
#   'team': 'CHO',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '12.1',
#   'true_shooting': '.503',
#   'plus_minus': '-1.9',
#   'win_shares_percentage': '.069'},
#  {'name': 'Jerami Grant',
#   'team': 'DET',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '17.8',
#   'true_shooting': '.571',
#   'plus_minus': '1.8',
#   'win_shares_percentage': '.111'},
#  {'name': 'Danny Green',
#   'team': 'PHI',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '9.8',
#   'true_shooting': '.547',
#   'plus_minus': '-0.7',
#   'win_shares_percentage': '.069'},
#  {'name': 'Draymond Green',
#   'team': 'GSW',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '11.4',
#   'true_shooting': '.464',
#   'plus_minus': '-0.1',
#   'win_shares_percentage': '.083'},
#  {'name': 'JaMychal Green',
#   'team': 'DEN',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '14.7',
#   'true_shooting': '.587',
#   'plus_minus': '-1.7',
#   'win_shares_percentage': '.122'},
#  {'name': 'Javonte Green',
#   'team': 'BOS',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '12.7',
#   'true_shooting': '.624',
#   'plus_minus': '-0.4',
#   'win_shares_percentage': '.110'},
#  {'name': 'Jeff Green',
#   'team': 'BRK',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '11.7',
#   'true_shooting': '.642',
#   'plus_minus': '-1.5',
#   'win_shares_percentage': '.096'},
#  {'name': 'Josh Green',
#   'team': 'DAL',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '6.4',
#   'true_shooting': '.514',
#   'plus_minus': '-5.2',
#   'win_shares_percentage': '.016'},
#  {'name': 'Blake Griffin',
#   'team': 'DET',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '9.9',
#   'true_shooting': '.491',
#   'plus_minus': '-2.6',
#   'win_shares_percentage': '.026'},
#  {'name': 'Kyle Guy',
#   'team': 'SAC',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '9.1',
#   'true_shooting': '.431',
#   'plus_minus': '-5.1',
#   'win_shares_percentage': '-0.008'},
#  {'name': 'Rui Hachimura',
#   'team': 'WAS',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '11.4',
#   'true_shooting': '.543',
#   'plus_minus': '-3.6',
#   'win_shares_percentage': '.058'},
#  {'name': 'Ashton Hagans',
#   'team': 'MIN',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '-12.5',
#   'true_shooting': '',
#   'plus_minus': '-21.7',
#   'win_shares_percentage': '-0.350'},
#  {'name': 'Tyrese Haliburton',
#   'team': 'SAC',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '18.2',
#   'true_shooting': '.619',
#   'plus_minus': '2.8',
#   'win_shares_percentage': '.117'},
#  {'name': 'Josh Hall',
#   'team': 'OKC',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '-2.4',
#   'true_shooting': '.285',
#   'plus_minus': '-14.4',
#   'win_shares_percentage': '-0.194'},
#  {'name': 'R.J. Hampton',
#   'team': 'DEN',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '7.4',
#   'true_shooting': '.481',
#   'plus_minus': '-5.9',
#   'win_shares_percentage': '.019'},
#  {'name': 'Tim Hardaway Jr.',
#   'team': 'DAL',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '14.5',
#   'true_shooting': '.572',
#   'plus_minus': '-0.5',
#   'win_shares_percentage': '.080'},
#  {'name': 'James Harden',
#   'team': 'TOT',
#   'year': 2021,
#   'position': 'PG-SG',
#   'player_efficiency': '24.8',
#   'true_shooting': '.642',
#   'plus_minus': '6.6',
#   'win_shares_percentage': '.222'},
#  {'name': 'Maurice Harkless',
#   'team': 'MIA',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '4.6',
#   'true_shooting': '.551',
#   'plus_minus': '-2.5',
#   'win_shares_percentage': '.057'},
#  {'name': 'Jared Harper',
#   'team': 'NYK',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '-11.9',
#   'true_shooting': '.532',
#   'plus_minus': '-23.5',
#   'win_shares_percentage': '-0.465'},
#  {'name': 'Montrezl Harrell',
#   'team': 'LAL',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '22.5',
#   'true_shooting': '.658',
#   'plus_minus': '2.6',
#   'win_shares_percentage': '.229'},
#  {'name': 'Gary Harris',
#   'team': 'DEN',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '9.4',
#   'true_shooting': '.544',
#   'plus_minus': '-3.6',
#   'win_shares_percentage': '.064'},
#  {'name': 'Jalen Harris',
#   'team': 'TOR',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '-10.6',
#   'true_shooting': '',
#   'plus_minus': '-21.2',
#   'win_shares_percentage': '-0.200'},
#  {'name': 'Joe Harris',
#   'team': 'BRK',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '15.1',
#   'true_shooting': '.700',
#   'plus_minus': '0.9',
#   'win_shares_percentage': '.133'},
#  {'name': 'Tobias Harris',
#   'team': 'PHI',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '19.4',
#   'true_shooting': '.607',
#   'plus_minus': '2.9',
#   'win_shares_percentage': '.161'},
#  {'name': 'Shaquille Harrison',
#   'team': 'UTA',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '6.6',
#   'true_shooting': '.375',
#   'plus_minus': '-7.9',
#   'win_shares_percentage': '-0.035'},
#  {'name': 'Josh Hart',
#   'team': 'NOP',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '12.4',
#   'true_shooting': '.577',
#   'plus_minus': '-1.1',
#   'win_shares_percentage': '.096'},
#  {'name': 'Isaiah Hartenstein',
#   'team': 'DEN',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '15.6',
#   'true_shooting': '.539',
#   'plus_minus': '-4.7',
#   'win_shares_percentage': '.112'},
#  {'name': 'Jaxson Hayes',
#   'team': 'NOP',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '15.7',
#   'true_shooting': '.687',
#   'plus_minus': '-1.8',
#   'win_shares_percentage': '.126'},
#  {'name': 'Killian Hayes',
#   'team': 'DET',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '-1.5',
#   'true_shooting': '.334',
#   'plus_minus': '-13.6',
#   'win_shares_percentage': '-0.177'},
#  {'name': 'Gordon Hayward',
#   'team': 'CHO',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '18.8',
#   'true_shooting': '.595',
#   'plus_minus': '2.0',
#   'win_shares_percentage': '.132'},
#  {'name': 'Juan Hernangómez',
#   'team': 'MIN',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '11.1',
#   'true_shooting': '.513',
#   'plus_minus': '-3.7',
#   'win_shares_percentage': '.049'},
#  {'name': 'Willy Hernangómez',
#   'team': 'NOP',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '19.9',
#   'true_shooting': '.576',
#   'plus_minus': '-0.4',
#   'win_shares_percentage': '.162'},
#  {'name': 'Tyler Herro',
#   'team': 'MIA',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '11.9',
#   'true_shooting': '.535',
#   'plus_minus': '-2.5',
#   'win_shares_percentage': '.027'},
#  {'name': 'Buddy Hield',
#   'team': 'SAC',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '11.3',
#   'true_shooting': '.551',
#   'plus_minus': '-2.2',
#   'win_shares_percentage': '.018'},
#  {'name': 'George Hill',
#   'team': 'OKC',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '16.1',
#   'true_shooting': '.630',
#   'plus_minus': '0.4',
#   'win_shares_percentage': '.144'},
#  {'name': 'Solomon Hill',
#   'team': 'ATL',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '6.6',
#   'true_shooting': '.498',
#   'plus_minus': '-3.0',
#   'win_shares_percentage': '.032'},
#  {'name': 'Nate Hinton',
#   'team': 'DAL',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '-6.6',
#   'true_shooting': '.288',
#   'plus_minus': '-17.8',
#   'win_shares_percentage': '-0.432'},
#  {'name': 'Aaron Holiday',
#   'team': 'IND',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '7.4',
#   'true_shooting': '.470',
#   'plus_minus': '-5.5',
#   'win_shares_percentage': '-0.011'},
#  {'name': 'Jrue Holiday',
#   'team': 'MIL',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '18.9',
#   'true_shooting': '.577',
#   'plus_minus': '3.0',
#   'win_shares_percentage': '.160'},
#  {'name': 'Justin Holiday',
#   'team': 'IND',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '12.2',
#   'true_shooting': '.628',
#   'plus_minus': '0.6',
#   'win_shares_percentage': '.106'},
#  {'name': 'Richaun Holmes',
#   'team': 'SAC',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '19.0',
#   'true_shooting': '.680',
#   'plus_minus': '-0.3',
#   'win_shares_percentage': '.144'},
#  {'name': 'Rodney Hood',
#   'team': 'POR',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '4.7',
#   'true_shooting': '.434',
#   'plus_minus': '-8.1',
#   'win_shares_percentage': '-0.052'},
#  {'name': 'Al Horford',
#   'team': 'OKC',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '16.6',
#   'true_shooting': '.527',
#   'plus_minus': '2.7',
#   'win_shares_percentage': '.096'},
#  {'name': 'Talen Horton-Tucker',
#   'team': 'LAL',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '11.7',
#   'true_shooting': '.517',
#   'plus_minus': '-1.6',
#   'win_shares_percentage': '.070'},
#  {'name': 'Danuel House',
#   'team': 'HOU',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '9.0',
#   'true_shooting': '.499',
#   'plus_minus': '-3.1',
#   'win_shares_percentage': '.039'},
#  {'name': 'Dwight Howard',
#   'team': 'PHI',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '15.7',
#   'true_shooting': '.602',
#   'plus_minus': '-3.4',
#   'win_shares_percentage': '.116'},
#  {'name': 'Markus Howard',
#   'team': 'DEN',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '-6.4',
#   'true_shooting': '.251',
#   'plus_minus': '-19.8',
#   'win_shares_percentage': '-0.298'},
#  {'name': 'Kevin Huerter',
#   'team': 'ATL',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '11.9',
#   'true_shooting': '.541',
#   'plus_minus': '-0.6',
#   'win_shares_percentage': '.076'},
#  {'name': 'Elijah Hughes',
#   'team': 'UTA',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '9.7',
#   'true_shooting': '.477',
#   'plus_minus': '-4.5',
#   'win_shares_percentage': '-0.070'},
#  {'name': "De'Andre Hunter",
#   'team': 'ATL',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '17.6',
#   'true_shooting': '.640',
#   'plus_minus': '2.5',
#   'win_shares_percentage': '.151'},
#  {'name': 'Chandler Hutchison',
#   'team': 'CHI',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '0.5',
#   'true_shooting': '.344',
#   'plus_minus': '-10.9',
#   'win_shares_percentage': '-0.104'},
#  {'name': 'Serge Ibaka',
#   'team': 'LAC',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '17.5',
#   'true_shooting': '.583',
#   'plus_minus': '0.5',
#   'win_shares_percentage': '.135'},
#  {'name': 'Andre Iguodala',
#   'team': 'MIA',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '9.8',
#   'true_shooting': '.525',
#   'plus_minus': '0.1',
#   'win_shares_percentage': '.073'},
#  {'name': 'Joe Ingles',
#   'team': 'UTA',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '16.5',
#   'true_shooting': '.705',
#   'plus_minus': '3.9',
#   'win_shares_percentage': '.190'},
#  {'name': 'Brandon Ingram',
#   'team': 'NOP',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '20.4',
#   'true_shooting': '.590',
#   'plus_minus': '2.7',
#   'win_shares_percentage': '.130'},
#  {'name': 'Kyrie Irving',
#   'team': 'BRK',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '24.1',
#   'true_shooting': '.617',
#   'plus_minus': '4.2',
#   'win_shares_percentage': '.191'},
#  {'name': 'Wesley Iwundu',
#   'team': 'DAL',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '3.9',
#   'true_shooting': '.386',
#   'plus_minus': '-6.0',
#   'win_shares_percentage': '-0.012'},
#  {'name': 'Frank Jackson',
#   'team': 'DET',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '3.3',
#   'true_shooting': '.364',
#   'plus_minus': '-8.4',
#   'win_shares_percentage': '-0.098'},
#  {'name': 'Josh Jackson',
#   'team': 'DET',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '12.6',
#   'true_shooting': '.521',
#   'plus_minus': '-2.8',
#   'win_shares_percentage': '.006'},
#  {'name': 'Justin Jackson',
#   'team': 'OKC',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '9.7',
#   'true_shooting': '.510',
#   'plus_minus': '-3.7',
#   'win_shares_percentage': '.018'},
#  {'name': 'Reggie Jackson',
#   'team': 'LAC',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '13.8',
#   'true_shooting': '.569',
#   'plus_minus': '-1.2',
#   'win_shares_percentage': '.108'},
#  {'name': 'Justin James',
#   'team': 'SAC',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '8.3',
#   'true_shooting': '.415',
#   'plus_minus': '-5.9',
#   'win_shares_percentage': '-0.047'},
#  {'name': 'LeBron James',
#   'team': 'LAL',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '24.4',
#   'true_shooting': '.597',
#   'plus_minus': '7.5',
#   'win_shares_percentage': '.189'},
#  {'name': 'DaQuan Jeffries',
#   'team': 'SAC',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '8.1',
#   'true_shooting': '.527',
#   'plus_minus': '-5.3',
#   'win_shares_percentage': '.006'},
#  {'name': 'Ty Jerome',
#   'team': 'OKC',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '13.2',
#   'true_shooting': '.617',
#   'plus_minus': '0.6',
#   'win_shares_percentage': '.146'},
#  {'name': 'Isaiah Joe',
#   'team': 'PHI',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '9.7',
#   'true_shooting': '.530',
#   'plus_minus': '-2.3',
#   'win_shares_percentage': '.083'},
#  {'name': 'Cameron Johnson',
#   'team': 'PHO',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '13.0',
#   'true_shooting': '.587',
#   'plus_minus': '0.4',
#   'win_shares_percentage': '.106'},
#  {'name': 'James Johnson',
#   'team': 'DAL',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '12.4',
#   'true_shooting': '.530',
#   'plus_minus': '0.4',
#   'win_shares_percentage': '.067'},
#  {'name': 'Keldon Johnson',
#   'team': 'SAS',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '15.4',
#   'true_shooting': '.564',
#   'plus_minus': '-1.0',
#   'win_shares_percentage': '.102'},
#  {'name': 'Stanley Johnson',
#   'team': 'TOR',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '9.0',
#   'true_shooting': '.546',
#   'plus_minus': '-1.3',
#   'win_shares_percentage': '.068'},
#  {'name': 'Tyler Johnson',
#   'team': 'BRK',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '9.9',
#   'true_shooting': '.559',
#   'plus_minus': '-3.4',
#   'win_shares_percentage': '.071'},
#  {'name': 'Nikola Jokić',
#   'team': 'DEN',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '31.5',
#   'true_shooting': '.652',
#   'plus_minus': '11.6',
#   'win_shares_percentage': '.310'},
#  {'name': 'Damian Jones',
#   'team': 'TOT',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '10.3',
#   'true_shooting': '.636',
#   'plus_minus': '-3.7',
#   'win_shares_percentage': '.116'},
#  {'name': 'Derrick Jones Jr.',
#   'team': 'POR',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '12.9',
#   'true_shooting': '.597',
#   'plus_minus': '-1.3',
#   'win_shares_percentage': '.098'},
#  {'name': 'Mason Jones',
#   'team': 'HOU',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '11.6',
#   'true_shooting': '.576',
#   'plus_minus': '-3.3',
#   'win_shares_percentage': '.032'},
#  {'name': 'Tre Jones',
#   'team': 'SAS',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '14.8',
#   'true_shooting': '.659',
#   'plus_minus': '-4.5',
#   'win_shares_percentage': '.092'},
#  {'name': 'Tyus Jones',
#   'team': 'MEM',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '15.6',
#   'true_shooting': '.502',
#   'plus_minus': '0.8',
#   'win_shares_percentage': '.112'},
#  {'name': 'DeAndre Jordan',
#   'team': 'BRK',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '16.4',
# ...
#   'position': 'SG',
#   'player_efficiency': '9.1',
#   'true_shooting': '.552',
#   'plus_minus': '-4.1',
#   'win_shares_percentage': '.035'},
#  {'name': 'Iman Shumpert',
#   'team': 'BRK',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '-0.3',
#   'true_shooting': '.250',
#   'plus_minus': '-13.0',
#   'win_shares_percentage': '-0.211'},
#  {'name': 'Pascal Siakam',
#   'team': 'TOR',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '17.5',
#   'true_shooting': '.542',
#   'plus_minus': '0.3',
#   'win_shares_percentage': '.112'},
#  {'name': 'Chris Silva',
#   'team': 'MIA',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '16.2',
#   'true_shooting': '.805',
#   'plus_minus': '-2.0',
#   'win_shares_percentage': '.176'},
#  {'name': 'Ben Simmons',
#   'team': 'PHI',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '19.9',
#   'true_shooting': '.614',
#   'plus_minus': '3.8',
#   'win_shares_percentage': '.168'},
#  {'name': 'Anfernee Simons',
#   'team': 'POR',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '11.4',
#   'true_shooting': '.564',
#   'plus_minus': '-2.6',
#   'win_shares_percentage': '.046'},
#  {'name': 'Deividas Sirvydis',
#   'team': 'DET',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '-9.0',
#   'true_shooting': '.129',
#   'plus_minus': '-24.5',
#   'win_shares_percentage': '-0.304'},
#  {'name': 'Marcus Smart',
#   'team': 'BOS',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '14.6',
#   'true_shooting': '.516',
#   'plus_minus': '0.3',
#   'win_shares_percentage': '.100'},
#  {'name': 'Dennis Smith Jr.',
#   'team': 'TOT',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '14.3',
#   'true_shooting': '.473',
#   'plus_minus': '0.2',
#   'win_shares_percentage': '.061'},
#  {'name': 'Ish Smith',
#   'team': 'WAS',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '10.6',
#   'true_shooting': '.404',
#   'plus_minus': '-2.5',
#   'win_shares_percentage': '.019'},
#  {'name': 'Jalen Smith',
#   'team': 'PHO',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '7.2',
#   'true_shooting': '.402',
#   'plus_minus': '-4.2',
#   'win_shares_percentage': '.009'},
#  {'name': 'Tony Snell',
#   'team': 'ATL',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '9.6',
#   'true_shooting': '.688',
#   'plus_minus': '-0.7',
#   'win_shares_percentage': '.083'},
#  {'name': 'Ray Spalding',
#   'team': 'HOU',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '0.9',
#   'true_shooting': '.410',
#   'plus_minus': '-10.4',
#   'win_shares_percentage': '-0.164'},
#  {'name': 'Cassius Stanley',
#   'team': 'IND',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '6.8',
#   'true_shooting': '.489',
#   'plus_minus': '-7.9',
#   'win_shares_percentage': '.040'},
#  {'name': 'Lamar Stevens',
#   'team': 'CLE',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '8.6',
#   'true_shooting': '.467',
#   'plus_minus': '-5.0',
#   'win_shares_percentage': '.021'},
#  {'name': 'Isaiah Stewart',
#   'team': 'DET',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '14.6',
#   'true_shooting': '.578',
#   'plus_minus': '-2.5',
#   'win_shares_percentage': '.116'},
#  {'name': 'Max Strus',
#   'team': 'MIA',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '11.8',
#   'true_shooting': '.618',
#   'plus_minus': '-1.0',
#   'win_shares_percentage': '.095'},
#  {'name': 'Edmond Sumner',
#   'team': 'IND',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '12.1',
#   'true_shooting': '.602',
#   'plus_minus': '-2.9',
#   'win_shares_percentage': '.061'},
#  {'name': "Jae'Sean Tate",
#   'team': 'HOU',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '13.3',
#   'true_shooting': '.605',
#   'plus_minus': '-1.7',
#   'win_shares_percentage': '.113'},
#  {'name': 'Jayson Tatum',
#   'team': 'BOS',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '19.7',
#   'true_shooting': '.547',
#   'plus_minus': '3.0',
#   'win_shares_percentage': '.111'},
#  {'name': 'Jeff Teague',
#   'team': 'BOS',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '10.1',
#   'true_shooting': '.502',
#   'plus_minus': '-3.4',
#   'win_shares_percentage': '.036'},
#  {'name': 'Garrett Temple',
#   'team': 'CHI',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '9.5',
#   'true_shooting': '.544',
#   'plus_minus': '-2.8',
#   'win_shares_percentage': '.063'},
#  {'name': 'Tyrell Terry',
#   'team': 'DAL',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '5.9',
#   'true_shooting': '.318',
#   'plus_minus': '-5.5',
#   'win_shares_percentage': '-0.056'},
#  {'name': 'Daniel Theis',
#   'team': 'BOS',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '15.1',
#   'true_shooting': '.639',
#   'plus_minus': '0.1',
#   'win_shares_percentage': '.132'},
#  {'name': 'Brodric Thomas',
#   'team': 'HOU',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '7.4',
#   'true_shooting': '.496',
#   'plus_minus': '-7.3',
#   'win_shares_percentage': '-0.045'},
#  {'name': 'Matt Thomas',
#   'team': 'TOR',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '8.2',
#   'true_shooting': '.545',
#   'plus_minus': '-4.5',
#   'win_shares_percentage': '.029'},
#  {'name': 'Tristan Thompson',
#   'team': 'BOS',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '15.6',
#   'true_shooting': '.557',
#   'plus_minus': '-2.1',
#   'win_shares_percentage': '.125'},
#  {'name': 'Sindarius Thornwell',
#   'team': 'NOP',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '8.8',
#   'true_shooting': '.540',
#   'plus_minus': '-2.8',
#   'win_shares_percentage': '.021'},
#  {'name': 'Matisse Thybulle',
#   'team': 'PHI',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '8.4',
#   'true_shooting': '.459',
#   'plus_minus': '0.3',
#   'win_shares_percentage': '.077'},
#  {'name': 'Killian Tillie',
#   'team': 'MEM',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '-1.1',
#   'true_shooting': '.375',
#   'plus_minus': '-9.9',
#   'win_shares_percentage': '-0.036'},
#  {'name': 'Xavier Tillman Sr.',
#   'team': 'MEM',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '13.7',
#   'true_shooting': '.564',
#   'plus_minus': '-1.1',
#   'win_shares_percentage': '.116'},
#  {'name': 'Obi Toppin',
#   'team': 'NYK',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '11.9',
#   'true_shooting': '.561',
#   'plus_minus': '-1.6',
#   'win_shares_percentage': '.083'},
#  {'name': 'Juan Toscano-Anderson',
#   'team': 'GSW',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '11.7',
#   'true_shooting': '.657',
#   'plus_minus': '-0.9',
#   'win_shares_percentage': '.115'},
#  {'name': 'Karl-Anthony Towns',
#   'team': 'MIN',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '22.7',
#   'true_shooting': '.609',
#   'plus_minus': '4.2',
#   'win_shares_percentage': '.142'},
#  {'name': 'Gary Trent Jr.',
#   'team': 'POR',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '12.7',
#   'true_shooting': '.554',
#   'plus_minus': '-2.4',
#   'win_shares_percentage': '.056'},
#  {'name': 'P.J. Tucker',
#   'team': 'HOU',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '5.6',
#   'true_shooting': '.500',
#   'plus_minus': '-4.8',
#   'win_shares_percentage': '.039'},
#  {'name': 'Myles Turner',
#   'team': 'IND',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '16.5',
#   'true_shooting': '.601',
#   'plus_minus': '0.9',
#   'win_shares_percentage': '.128'},
#  {'name': 'Jonas Valančiūnas',
#   'team': 'MEM',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '20.9',
#   'true_shooting': '.590',
#   'plus_minus': '0.1',
#   'win_shares_percentage': '.152'},
#  {'name': 'Denzel Valentine',
#   'team': 'CHI',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '10.9',
#   'true_shooting': '.481',
#   'plus_minus': '-2.7',
#   'win_shares_percentage': '.040'},
#  {'name': 'Jarred Vanderbilt',
#   'team': 'MIN',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '16.1',
#   'true_shooting': '.618',
#   'plus_minus': '-0.5',
#   'win_shares_percentage': '.125'},
#  {'name': 'Fred VanVleet',
#   'team': 'TOR',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '17.7',
#   'true_shooting': '.549',
#   'plus_minus': '2.6',
#   'win_shares_percentage': '.127'},
#  {'name': 'Devin Vassell',
#   'team': 'SAS',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '12.6',
#   'true_shooting': '.529',
#   'plus_minus': '0.2',
#   'win_shares_percentage': '.098'},
#  {'name': 'Gabe Vincent',
#   'team': 'MIA',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '6.5',
#   'true_shooting': '.480',
#   'plus_minus': '-6.5',
#   'win_shares_percentage': '-0.013'},
#  {'name': 'Noah Vonleh',
#   'team': 'BRK',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '-19.0',
#   'true_shooting': '.000',
#   'plus_minus': '-29.9',
#   'win_shares_percentage': '-0.487'},
#  {'name': 'Nikola Vučević',
#   'team': 'ORL',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '24.2',
#   'true_shooting': '.571',
#   'plus_minus': '6.0',
#   'win_shares_percentage': '.156'},
#  {'name': 'Dean Wade',
#   'team': 'CLE',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '10.6',
#   'true_shooting': '.605',
#   'plus_minus': '-1.0',
#   'win_shares_percentage': '.077'},
#  {'name': 'Moritz Wagner',
#   'team': 'WAS',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '15.6',
#   'true_shooting': '.607',
#   'plus_minus': '-0.4',
#   'win_shares_percentage': '.126'},
#  {'name': 'Kemba Walker',
#   'team': 'BOS',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '16.5',
#   'true_shooting': '.530',
#   'plus_minus': '1.3',
#   'win_shares_percentage': '.081'},
#  {'name': 'Lonnie Walker',
#   'team': 'SAS',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '9.0',
#   'true_shooting': '.513',
#   'plus_minus': '-4.2',
#   'win_shares_percentage': '.014'},
#  {'name': 'John Wall',
#   'team': 'HOU',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '16.5',
#   'true_shooting': '.524',
#   'plus_minus': '0.2',
#   'win_shares_percentage': '.030'},
#  {'name': 'Brad Wanamaker',
#   'team': 'GSW',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '9.2',
#   'true_shooting': '.478',
#   'plus_minus': '-3.7',
#   'win_shares_percentage': '.049'},
#  {'name': 'T.J. Warren',
#   'team': 'IND',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '11.9',
#   'true_shooting': '.560',
#   'plus_minus': '-5.5',
#   'win_shares_percentage': '.050'},
#  {'name': 'P.J. Washington',
#   'team': 'CHO',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '14.1',
#   'true_shooting': '.560',
#   'plus_minus': '-0.6',
#   'win_shares_percentage': '.083'},
#  {'name': 'Yuta Watanabe',
#   'team': 'TOR',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '9.5',
#   'true_shooting': '.472',
#   'plus_minus': '-3.3',
#   'win_shares_percentage': '.063'},
#  {'name': 'Tremont Waters',
#   'team': 'BOS',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '11.7',
#   'true_shooting': '.478',
#   'plus_minus': '-1.3',
#   'win_shares_percentage': '.021'},
#  {'name': 'Paul Watson',
#   'team': 'TOR',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '12.7',
#   'true_shooting': '.725',
#   'plus_minus': '-0.6',
#   'win_shares_percentage': '.131'},
#  {'name': 'Quinndary Weatherspoon',
#   'team': 'SAS',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '-10.3',
#   'true_shooting': '.340',
#   'plus_minus': '-22.2',
#   'win_shares_percentage': '-0.317'},
#  {'name': 'Russell Westbrook',
#   'team': 'WAS',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '16.2',
#   'true_shooting': '.485',
#   'plus_minus': '-0.1',
#   'win_shares_percentage': '.001'},
#  {'name': 'Coby White',
#   'team': 'CHI',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '12.1',
#   'true_shooting': '.538',
#   'plus_minus': '-3.3',
#   'win_shares_percentage': '.051'},
#  {'name': 'Derrick White',
#   'team': 'SAS',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '12.7',
#   'true_shooting': '.488',
#   'plus_minus': '-0.8',
#   'win_shares_percentage': '.050'},
#  {'name': 'Hassan Whiteside',
#   'team': 'SAC',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '20.9',
#   'true_shooting': '.586',
#   'plus_minus': '-1.1',
#   'win_shares_percentage': '.091'},
#  {'name': 'Greg Whittington',
#   'team': 'DEN',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '-10.2',
#   'true_shooting': '.000',
#   'plus_minus': '-16.5',
#   'win_shares_percentage': '-0.264'},
#  {'name': 'Andrew Wiggins',
#   'team': 'GSW',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '13.1',
#   'true_shooting': '.547',
#   'plus_minus': '-2.1',
#   'win_shares_percentage': '.051'},
#  {'name': 'Grant Williams',
#   'team': 'BOS',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '8.5',
#   'true_shooting': '.583',
#   'plus_minus': '-3.7',
#   'win_shares_percentage': '.057'},
#  {'name': 'Kenrich Williams',
#   'team': 'OKC',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '13.8',
#   'true_shooting': '.622',
#   'plus_minus': '-0.2',
#   'win_shares_percentage': '.125'},
#  {'name': 'Lou Williams',
#   'team': 'LAC',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '15.7',
#   'true_shooting': '.526',
#   'plus_minus': '-2.0',
#   'win_shares_percentage': '.078'},
#  {'name': 'Patrick Williams',
#   'team': 'CHI',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '10.3',
#   'true_shooting': '.566',
#   'plus_minus': '-3.5',
#   'win_shares_percentage': '.053'},
#  {'name': 'Robert Williams',
#   'team': 'BOS',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '25.6',
#   'true_shooting': '.722',
#   'plus_minus': '5.4',
#   'win_shares_percentage': '.244'},
#  {'name': 'Zion Williamson',
#   'team': 'NOP',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '26.8',
#   'true_shooting': '.650',
#   'plus_minus': '4.2',
#   'win_shares_percentage': '.198'},
#  {'name': 'D.J. Wilson',
#   'team': 'MIL',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '8.2',
#   'true_shooting': '.478',
#   'plus_minus': '-5.7',
#   'win_shares_percentage': '.013'},
#  {'name': 'Dylan Windler',
#   'team': 'CLE',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '12.7',
#   'true_shooting': '.603',
#   'plus_minus': '-0.3',
#   'win_shares_percentage': '.088'},
#  {'name': 'Justise Winslow',
#   'team': 'MEM',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '6.1',
#   'true_shooting': '.401',
#   'plus_minus': '-7.2',
#   'win_shares_percentage': '-0.075'},
#  {'name': 'Cassius Winston',
#   'team': 'WAS',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '9.8',
#   'true_shooting': '.597',
#   'plus_minus': '-4.0',
#   'win_shares_percentage': '.088'},
#  {'name': 'James Wiseman',
#   'team': 'GSW',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '14.2',
#   'true_shooting': '.551',
#   'plus_minus': '-4.5',
#   'win_shares_percentage': '.057'},
#  {'name': 'Christian Wood',
#   'team': 'HOU',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '24.2',
#   'true_shooting': '.634',
#   'plus_minus': '4.0',
#   'win_shares_percentage': '.165'},
#  {'name': 'Robert Woodard',
#   'team': 'SAC',
#   'year': 2021,
#   'position': 'SF',
#   'player_efficiency': '22.9',
#   'true_shooting': '.547',
#   'plus_minus': '-2.0',
#   'win_shares_percentage': '.003'},
#  {'name': 'Delon Wright',
#   'team': 'DET',
#   'year': 2021,
#   'position': 'SG',
#   'player_efficiency': '17.0',
#   'true_shooting': '.575',
#   'plus_minus': '3.2',
#   'win_shares_percentage': '.144'},
#  {'name': 'Thaddeus Young',
#   'team': 'CHI',
#   'year': 2021,
#   'position': 'PF',
#   'player_efficiency': '20.7',
#   'true_shooting': '.615',
#   'plus_minus': '3.4',
#   'win_shares_percentage': '.173'},
#  {'name': 'Trae Young',
#   'team': 'ATL',
#   'year': 2021,
#   'position': 'PG',
#   'player_efficiency': '22.9',
#   'true_shooting': '.595',
#   'plus_minus': '4.1',
#   'win_shares_percentage': '.165'},
#  {'name': 'Cody Zeller',
#   'team': 'CHO',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '17.0',
#   'true_shooting': '.556',
#   'plus_minus': '0.1',
#   'win_shares_percentage': '.137'},
#  {'name': 'Ivica Zubac',
#   'team': 'LAC',
#   'year': 2021,
#   'position': 'C',
#   'player_efficiency': '20.2',
#   'true_shooting': '.707',
#   'plus_minus': '0.6',
#   'win_shares_percentage': '.217'}]

# %% [markdown]
# Saving to a dataframe:

# %%
df_2021_advanced = pd.DataFrame(players_2021_advanced)
df_2021_advanced
# Out:
#                   name team  year position player_efficiency true_shooting  \
# 0     Precious Achiuwa  MIA  2021       PF              15.4          .587
# 1         Jaylen Adams  MIL  2021       PG              -6.6          .125
# 2         Steven Adams  NOP  2021        C              16.0          .597
# 3          Bam Adebayo  MIA  2021        C              22.0          .631
# 4    LaMarcus Aldridge  SAS  2021        C              15.0          .545
# ..                 ...  ...   ...      ...               ...           ...
# 487       Delon Wright  DET  2021       SG              17.0          .575
# 488     Thaddeus Young  CHI  2021       PF              20.7          .615
# 489         Trae Young  ATL  2021       PG              22.9          .595
# 490        Cody Zeller  CHO  2021        C              17.0          .556
# 491        Ivica Zubac  LAC  2021        C              20.2          .707
#
#     plus_minus win_shares_percentage
# 0         -2.7                  .111
# 1        -19.8                -0.250
# 2         -0.9                  .110
# 3          4.4                  .193
# 4         -1.2                  .074
# ..         ...                   ...
# 487        3.2                  .144
# 488        3.4                  .173
# 489        4.1                  .165
# 490        0.1                  .137
# 491        0.6                  .217
#
# [492 rows x 8 columns]

# %% [markdown]
# Now we will want to merge the dataframes into one to allow us to build our models. We will perform an inner join and will join on 3 selected common columns. Using these multiple columns allows us to avoid the issue of repeating joins, since a player will likely appear multiple times (due to playing multiple years), so additionally joining on year and time will ensure we are joinging the right corresponding advanced stats for a player for the correct year of their career.

# %%
df_m = pd.merge(df_basic, df_advanced, how='inner', on =['name', 'year', 'team'])
df_m
# Out:
#                            name team  year games_played   mpg   fg% 3pfg%  \
# 0                  Steven Adams  OKC  2020           63  26.7  .592  .333
# 1                   Bam Adebayo  MIA  2020           72  33.6  .557  .143
# 2             LaMarcus Aldridge  SAS  2020           53  33.1  .493  .389
# 3                Kyle Alexander  MIA  2020            2   6.5  .500
# 4      Nickeil Alexander-Walker  NOP  2020           47  12.6  .368  .346
# ...                         ...  ...   ...          ...   ...   ...   ...
# 13940         Orlando Woolridge  LAL  1990           62  22.9  .556  .000
# 13941          Haywoode Workman  ATL  1990            6   2.7  .667
# 13942             James Worthy*  LAL  1990           80  37.0  .548  .306
# 13943               Danny Young  POR  1990           82  17.0  .421  .271
# 13944             Michael Young  LAC  1990           45  10.2  .474  .308
#
#       rebounds assists steals blocks points_per_game position  \
# 0          9.3     2.3    0.8    1.1            10.9        C
# 1         10.2     5.1    1.1    1.3            15.9       PF
# 2          7.4     2.4    0.7    1.6            18.9        C
# 3          1.5     0.0    0.0    0.0             1.0        C
# 4          1.8     1.9    0.4    0.2             5.7       SG
# ...        ...     ...    ...    ...             ...      ...
# 13940      3.0     1.5    0.6    0.7            12.7       SF
# 13941      0.5     0.3    0.5    0.0             1.0       PG
# 13942      6.0     3.6    1.2    0.6            21.1       SF
# 13943      1.5     2.8    1.0    0.0             4.7       PG
# 13944      1.9     0.5    0.6    0.1             4.9       SF
#
#       player_efficiency true_shooting plus_minus win_shares_percentage  \
# 0                  20.5          .604        2.9                  .185
# 1                  20.3          .598        3.4                  .168
# 2                  19.7          .571        1.4                  .122
# 3                   4.7          .500       -9.6                -0.003
# 4                   8.9          .473       -4.6                -0.020
# ...                 ...           ...        ...                   ...
# 13940              17.6          .601        1.5                  .161
# 13941              26.1          .773       13.6                  .357
# 13942              19.8          .586        3.8                  .172
# 13943              11.5          .508        0.9                  .103
# 13944              16.0          .520        0.4                  .119
#
#        in_playoff
# 0               1
# 1               1
# 2               0
# 3               1
# 4               0
# ...           ...
# 13940           1
# 13941           0
# 13942           1
# 13943           1
# 13944           0
#
# [13945 rows x 18 columns]

# %% [markdown]
# Same method for the 2021 players:

# %%
df_m_2021 = pd.merge(df_2021_basic, df_2021_advanced, how='inner', on =['name', 'year', 'team'])
df_m_2021
# Out:
#                   name team  year games_played   mpg   fg% 3pfg% rebounds  \
# 0     Precious Achiuwa  MIA  2021           35  14.0  .579            4.0
# 1         Jaylen Adams  MIL  2021            7   2.6  .125  .000      0.4
# 2         Steven Adams  NOP  2021           33  27.8  .615  .000      8.9
# 3          Bam Adebayo  MIA  2021           33  33.9  .563  .333      9.5
# 4    LaMarcus Aldridge  SAS  2021           21  25.9  .464  .360      4.5
# ..                 ...  ...   ...          ...   ...   ...   ...      ...
# 487       Delon Wright  DET  2021           29  29.2  .468  .384      4.6
# 488     Thaddeus Young  CHI  2021           30  25.3  .609  .227      5.9
# 489         Trae Young  ATL  2021           34  34.8  .430  .378      4.2
# 490        Cody Zeller  CHO  2021           18  23.4  .514  .158      7.6
# 491        Ivica Zubac  LAC  2021           38  19.8  .659  .000      7.0
#
#     assists steals blocks points_per_game position player_efficiency  \
# 0       0.6    0.4    0.5             6.1       PF              15.4
# 1       0.3    0.0    0.0             0.3       PG              -6.6
# 2       2.1    0.9    0.6             8.0        C              16.0
# 3       5.4    0.9    1.0            19.2        C              22.0
# 4       1.7    0.4    0.9            13.7        C              15.0
# ..      ...    ...    ...             ...      ...               ...
# 487     4.9    1.4    0.5            10.7       SG              17.0
# 488     4.4    1.4    0.6            12.1       PF              20.7
# 489     9.4    0.9    0.2            26.4       PG              22.9
# 490     2.4    0.6    0.6             9.7        C              17.0
# 491     1.1    0.4    0.8             8.2        C              20.2
#
#     true_shooting plus_minus win_shares_percentage
# 0            .587       -2.7                  .111
# 1            .125      -19.8                -0.250
# 2            .597       -0.9                  .110
# 3            .631        4.4                  .193
# 4            .545       -1.2                  .074
# ..            ...        ...                   ...
# 487          .575        3.2                  .144
# 488          .615        3.4                  .173
# 489          .595        4.1                  .165
# 490          .556        0.1                  .137
# 491          .707        0.6                  .217
#
# [492 rows x 17 columns]

# %% [markdown]
# Since the website presents players who have been traded as a combined year of their two teams, we should sort out the players traded by selecting team as 'TOT' (total) and substituting their correct current team

# %%
df_m_2021[df_m_2021['team'] == 'TOT']
# Out:
#                  name team  year games_played   mpg   fg% 3pfg% rebounds  \
# 8       Jarrett Allen  TOT  2021           35  27.9  .669  .500      9.9
# 181      James Harden  TOT  2021           31  37.8  .484  .401      7.8
# 237      Damian Jones  TOT  2021           17   7.4  .619  .000      1.4
# 254    Rodions Kurucs  TOT  2021           16   5.7  .250  .176      0.9
# 262          Alex Len  TOT  2021           27  13.1  .621  .300      3.0
# 350    Victor Oladipo  TOT  2021           24  32.8  .399  .331      5.2
# 364      Norvel Pelle  TOT  2021            4   8.0  .375            2.0
# 378    Taurean Prince  TOT  2021           29  21.4  .380  .386      3.6
# 398      Derrick Rose  TOT  2021           25  23.5  .430  .377      2.2
# 419  Dennis Smith Jr.  TOT  2021           15  18.3  .385  .318      2.7
#
#     assists steals blocks points_per_game position player_efficiency  \
# 8       1.7    0.5    1.7            13.5        C              23.6
# 181    11.1    1.2    0.7            25.3    PG-SG              24.8
# 237     0.2    0.1    0.5             2.0        C              10.3
# 254     0.4    0.4    0.3             1.0    SF-PF               2.1
# 262     0.9    0.3    1.2             5.1        C              15.3
# 350     4.5    1.5    0.5            20.0       SG              15.0
# 364     0.3    0.0    0.8             2.3        C               5.6
# 378     1.7    0.7    0.7             8.3       PF              11.3
# 398     4.5    1.2    0.4            13.5       PG              17.1
# 419     3.3    1.2    0.5             7.3       PG              14.3
#
#     true_shooting plus_minus win_shares_percentage
# 8            .714        3.4                  .219
# 181          .642        6.6                  .222
# 237          .636       -3.7                  .116
# 254          .322       -7.0                -0.117
# 262          .654       -0.4                  .105
# 350          .501       -0.5                  .032
# 364          .461       -8.3                -0.015
# 378          .523       -2.2                  .051
# 398          .519        0.5                  .071
# 419          .473        0.2                  .061

# %% [markdown]
# I set a new teams list based on what was listed on their profile as current team and we can use .loc to select these items and save over their current unlisted team with the correct teams laid out in our 'new_teams' list variable:

# %%
new_teams = ['CLE', 'BRK', 'LAL', 'HOU', 'WAS', 'HOU', 'SAC', 'CLE', 'NYK', 'DET']

# %%
df_m_2021[df_m_2021['team'] == 'TOT'].index
# Out:
# Int64Index([8, 181, 237, 254, 262, 350, 364, 378, 398, 419], dtype='int64')

# %%
df_m_2021.loc[df_m_2021[df_m_2021['team'] == 'TOT'].index, 'team'] = new_teams

# %%
df_m_2021.loc[[8, 181, 237, 254, 262, 350, 364, 378, 398, 419]]['team']
# Out:
# 8      CLE
# 181    BRK
# 237    LAL
# 254    HOU
# 262    WAS
# 350    HOU
# 364    SAC
# 378    CLE
# 398    NYK
# 419    DET
# Name: team, dtype: object

# %%
#double checking (should be blank):
df_m_2021[df_m_2021['team'] == 'TOT']
# Out:
# Empty DataFrame
# Columns: [name, team, year, games_played, mpg, fg%, 3pfg%, rebounds, assists, steals, blocks, points_per_game, position, player_efficiency, true_shooting, plus_minus, win_shares_percentage]
# Index: []

# %%
#checking to make sure the new current teams replacement method worked:
df_m_2021.loc[[8, 181, 237, 254, 262, 350, 364, 378, 398, 419]]
# Out:
#                  name team  year games_played   mpg   fg% 3pfg% rebounds  \
# 8       Jarrett Allen  CLE  2021           35  27.9  .669  .500      9.9
# 181      James Harden  BRK  2021           31  37.8  .484  .401      7.8
# 237      Damian Jones  LAL  2021           17   7.4  .619  .000      1.4
# 254    Rodions Kurucs  HOU  2021           16   5.7  .250  .176      0.9
# 262          Alex Len  WAS  2021           27  13.1  .621  .300      3.0
# 350    Victor Oladipo  HOU  2021           24  32.8  .399  .331      5.2
# 364      Norvel Pelle  SAC  2021            4   8.0  .375            2.0
# 378    Taurean Prince  CLE  2021           29  21.4  .380  .386      3.6
# 398      Derrick Rose  NYK  2021           25  23.5  .430  .377      2.2
# 419  Dennis Smith Jr.  DET  2021           15  18.3  .385  .318      2.7
#
#     assists steals blocks points_per_game position player_efficiency  \
# 8       1.7    0.5    1.7            13.5        C              23.6
# 181    11.1    1.2    0.7            25.3    PG-SG              24.8
# 237     0.2    0.1    0.5             2.0        C              10.3
# 254     0.4    0.4    0.3             1.0    SF-PF               2.1
# 262     0.9    0.3    1.2             5.1        C              15.3
# 350     4.5    1.5    0.5            20.0       SG              15.0
# 364     0.3    0.0    0.8             2.3        C               5.6
# 378     1.7    0.7    0.7             8.3       PF              11.3
# 398     4.5    1.2    0.4            13.5       PG              17.1
# 419     3.3    1.2    0.5             7.3       PG              14.3
#
#     true_shooting plus_minus win_shares_percentage
# 8            .714        3.4                  .219
# 181          .642        6.6                  .222
# 237          .636       -3.7                  .116
# 254          .322       -7.0                -0.117
# 262          .654       -0.4                  .105
# 350          .501       -0.5                  .032
# 364          .461       -8.3                -0.015
# 378          .523       -2.2                  .051
# 398          .519        0.5                  .071
# 419          .473        0.2                  .061

# %% [markdown]
# Now let's save these dataframes to csv for EDA/Data Cleaning and then our modeling purposes:

# %%
df_m.to_csv('data/players_all.csv')

# %%
df_m_2021.to_csv('data/players_2021.csv')
